# %% [markdown]
# # Multimodal Deepfake Detection on the Full Dataset
#
# This notebook runs end-to-end training on the full dataset, uses subject_id-level splitting to avoid leakage, streams subprocess output live so cells do not look frozen, and packages the video, audio, and fusion artifacts for download.
#
# ## 1. Set Up Notebook Environment

# %%
import json
import os
import random
import shutil
import subprocess
import time
from pathlib import Path

import numpy as np
import torch

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)
    torch.backends.cudnn.benchmark = True

# Kaggle-safe video profile: keep the backbone, but reduce loader pressure.
FREE_TIER_MODE = False
T4_OPTIMIZED_MODE = True

# Use full dataset by default (no sampling). Splits are done by subject_id to avoid leakage.
USE_SAMPLED_SUBSET = False
TARGET_SAMPLED_VIDEOS = 960

CONFIG = {
    "dataset_root": "/kaggle/input/datasets/mahirashab/fakebdteen",
    "working_dir": "/kaggle/working",
    "script_name": "train_mobilevit_video_deepfake.py",
    "output_dir": "/kaggle/working/outputs",
    "epochs": 10,
    "batch_size": 8,
    "lr": 1e-4,
    "weight_decay": 1e-2,
    "num_workers": 2,
    "num_frames": 8,
    "image_size": 224,
    "clip_seconds": 6,
    "train_ratio": 0.75,
    "val_ratio": 0.125,
    "max_train_samples": 0,
    "max_val_samples": 0,
    "max_test_samples": 0,
    "force_retrain": False,
}

def run_streaming_command(cmd, cwd=None, extra_env=None):
    env = os.environ.copy()
    env["PYTHONUNBUFFERED"] = "1"
    env["PYTHONIOENCODING"] = "utf-8"
    if extra_env:
        env.update(extra_env)

    printable = " ".join(str(part) for part in cmd)
    print("Running:", printable, flush=True)
    started = time.perf_counter()
    process = subprocess.Popen(
        cmd,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        bufsize=1,
        cwd=cwd,
        env=env,
    )
    assert process.stdout is not None
    for line in process.stdout:
        print(line, end="")
    return_code = process.wait()
    elapsed = time.perf_counter() - started
    print(f"Command finished in {elapsed:.1f}s with exit code {return_code}", flush=True)
    if return_code != 0:
        raise subprocess.CalledProcessError(return_code, cmd)

print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
    print("Capability:", torch.cuda.get_device_capability(0))
print("FREE_TIER_MODE:", FREE_TIER_MODE)
print("T4_OPTIMIZED_MODE:", T4_OPTIMIZED_MODE)
print("USE_SAMPLED_SUBSET:", USE_SAMPLED_SUBSET)
print("Split strategy: subject_id-level split (train/val/test stay separate by subject).")
if USE_SAMPLED_SUBSET:
    print("TARGET_SAMPLED_VIDEOS:", TARGET_SAMPLED_VIDEOS)
print(json.dumps(CONFIG, indent=2))
# Out:
# CUDA available: True
# GPU: Tesla T4
# Capability: (7, 5)
# FREE_TIER_MODE: False
# T4_OPTIMIZED_MODE: True
# TARGET_SAMPLED_VIDEOS: 970
# {
#   "dataset_root": "/kaggle/input/datasets/mahirashab/fakebdteen",
#   "working_dir": "/kaggle/working",
#   "script_name": "train_mobilevit_video_deepfake.py",
#   "output_dir": "/kaggle/working/outputs",
#   "epochs": 10,
#   "batch_size": 8,
#   "lr": 0.0001,
#   "weight_decay": 0.01,
#   "num_workers": 2,
#   "num_frames": 8,
#   "image_size": 224,
#   "clip_seconds": 6,
#   "train_ratio": 0.75,
#   "val_ratio": 0.125,
#   "max_train_samples": 0,
#   "max_val_samples": 0,
#   "max_test_samples": 0,
#   "force_retrain": false
# }

# %%
from collections import Counter, defaultdict
import shutil

RAW_DATASET_ROOT = Path(CONFIG["dataset_root"])
SAMPLED_DATASET_ROOT = Path(CONFIG["working_dir"]) / f"sampled_uniform_{TARGET_SAMPLED_VIDEOS}_videos"
SAMPLED_MANIFEST_PATH = SAMPLED_DATASET_ROOT / "sample_manifest.json"


def build_distributed_video_subset(raw_root: Path, target_total: int, seed: int):
    rng = random.Random(seed)
    folder_to_videos = defaultdict(list)

    for ext in ("*.mp4", "*.MP4"):
        for video_path in raw_root.rglob(ext):
            folder_to_videos[video_path.parent].append(video_path)

    if not folder_to_videos:
        raise RuntimeError(f"No videos found under {raw_root}")

    folders = sorted(folder_to_videos, key=lambda p: str(p).lower())
    base_quota = target_total // len(folders)
    quotas = {folder: min(len(folder_to_videos[folder]), base_quota) for folder in folders}
    remaining = target_total - sum(quotas.values())

    shuffled_folders = folders[:]
    rng.shuffle(shuffled_folders)
    while remaining > 0:
        progressed = False
        for folder in shuffled_folders:
            if remaining == 0:
                break
            if quotas[folder] < len(folder_to_videos[folder]):
                quotas[folder] += 1
                remaining -= 1
                progressed = True
        if not progressed:
            break

    if remaining > 0:
        raise RuntimeError(
            f"Could not reach target of {target_total} clips; only {target_total - remaining} are available after balancing."
        )

    selected_files = []
    folder_stats = []
    for folder in folders:
        videos = sorted(folder_to_videos[folder], key=lambda p: p.name.lower())
        chosen = rng.sample(videos, quotas[folder])
        chosen = sorted(chosen, key=lambda p: p.name.lower())
        selected_files.extend(chosen)
        folder_stats.append(
            {
                "folder": str(folder.relative_to(raw_root)),
                "available": len(videos),
                "selected": len(chosen),
            }
        )

    rng.shuffle(selected_files)
    return selected_files, folder_stats


def materialize_subset(selected_files, raw_root: Path, sampled_root: Path):
    if sampled_root.exists():
        shutil.rmtree(sampled_root)
    sampled_root.mkdir(parents=True, exist_ok=True)

    for src in selected_files:
        dst = sampled_root / src.relative_to(raw_root)
        dst.parent.mkdir(parents=True, exist_ok=True)
        try:
            os.symlink(src, dst)
        except OSError:
            shutil.copy2(src, dst)


if USE_SAMPLED_SUBSET:
    selected_files, folder_stats = build_distributed_video_subset(
        RAW_DATASET_ROOT, TARGET_SAMPLED_VIDEOS, SEED
    )
    materialize_subset(selected_files, RAW_DATASET_ROOT, SAMPLED_DATASET_ROOT)
    CONFIG["dataset_root"] = str(SAMPLED_DATASET_ROOT)

    sample_manifest = [
        {
            "relative_path": str(src.relative_to(RAW_DATASET_ROOT)),
            "folder": str(src.parent.relative_to(RAW_DATASET_ROOT)),
        }
        for src in selected_files
    ]
    SAMPLED_MANIFEST_PATH.write_text(json.dumps(sample_manifest, indent=2))

    folder_summary = Counter(item["folder"].split("/")[0] for item in folder_stats)
    selected_counts = [item["selected"] for item in folder_stats]
    print("Raw dataset root:", RAW_DATASET_ROOT)
    print("Sampled dataset root:", SAMPLED_DATASET_ROOT)
    print("Folders discovered:", len(folder_stats))
    print("Videos selected:", len(selected_files))
    print("Base quota per folder:", TARGET_SAMPLED_VIDEOS // len(folder_stats))
    print("Per-top-level-folder counts:", dict(folder_summary))
    print("Selected per-folder range:", min(selected_counts), "to", max(selected_counts))
    print("Sample manifest saved to:", SAMPLED_MANIFEST_PATH)
    print("Downstream training cells will now use the sampled subset only.")
else:
    print("Sampling disabled; using full dataset.")
    print("Split strategy: subject_id-level split (train/val/test stay separate by subject).")
    print("Dataset root:", RAW_DATASET_ROOT)
    if SAMPLED_MANIFEST_PATH.exists():
        SAMPLED_MANIFEST_PATH.unlink()
# Out:
# Raw dataset root: /kaggle/input/datasets/mahirashab/fakebdteen
# Sampled dataset root: /kaggle/working/sampled_uniform_970_videos
# Folders discovered: 240
# Videos selected: 970
# Base quota per folder: 4
# Per-top-level-folder counts: {'FakeBDTeen': 240}
# Selected per-folder range: 4 to 5
# Sample manifest saved to: /kaggle/working/sampled_uniform_970_videos/sample_manifest.json
# Downstream training cells will now use the sampled subset only.

# %%
# Install dependencies (run once per Kaggle session)
# %pip install -q transformers opencv-python-headless
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 2. Load Input Data
#
# Locate the sampled dataset root, detect nested folder structure, and inspect discovered MP4 files.

# %%
dataset_root = Path(CONFIG["dataset_root"])

if not dataset_root.exists():
    raise FileNotFoundError(f"Dataset root not found: {dataset_root}")

candidate_roots = [dataset_root] + [p for p in dataset_root.iterdir() if p.is_dir()]
resolved_root = None
for root in candidate_roots:
    has_mp4 = any(root.rglob("*.mp4")) or any(root.rglob("*.MP4"))
    if has_mp4:
        resolved_root = root
        break

if resolved_root is None:
    raise RuntimeError(f"No mp4 files found under {dataset_root}")

mp4_files = list(resolved_root.rglob("*.mp4")) + list(resolved_root.rglob("*.MP4"))
print("Resolved dataset root:", resolved_root)
print("Discovered videos:", len(mp4_files))
print("Sample files:")
for p in mp4_files[:5]:
    print(" -", p.name)
# Out:
# Resolved dataset root: /kaggle/working/sampled_uniform_970_videos
# Discovered videos: 970
# Sample files:
#  - RF1B07_06.mp4
#  - RF1B07_08.mp4
#  - RF1B07_09.mp4
#  - RF1B07_01.mp4
#  - RF1B00_05.mp4

# %% [markdown]
# ## 3. Validate and Clean Data
#
# Parse filename schema and validate expected codes before training.

# %%
from collections import Counter

valid_av = {"FF", "FR", "RF", "RR"}
valid_lang = {"0", "1"}
valid_gender = {"B", "G"}

meta_rows = []
invalid = []

for p in mp4_files:
    stem = p.stem
    if len(stem) < 6:
        invalid.append((p.name, "short_name"))
        continue
    av = stem[0:2].upper()
    lg = stem[2]
    gd = stem[3].upper()
    sid = stem[4:6]
    if av not in valid_av or lg not in valid_lang or gd not in valid_gender or not sid.isdigit():
        invalid.append((p.name, "schema_mismatch"))
        continue
    meta_rows.append((av, lg, gd, sid, p.name))

print("Valid files:", len(meta_rows))
print("Invalid files:", len(invalid))
if invalid[:5]:
    print("First invalid examples:", invalid[:5])

assert len(meta_rows) > 0, "No valid videos found after schema validation."
# Out:
# Valid files: 970
# Invalid files: 0

# %% [markdown]
# ## 4. Exploratory Analysis with Plots
#
# Show class distribution from filename metadata.

# %%
import matplotlib.pyplot as plt

av_counts = Counter([r[0] for r in meta_rows])
lang_counts = Counter(["English" if r[1] == "0" else "Bangla" for r in meta_rows])
gender_counts = Counter(["Boy" if r[2] == "B" else "Girl" for r in meta_rows])

fig, axes = plt.subplots(1, 3, figsize=(14, 4))
axes[0].bar(list(av_counts.keys()), list(av_counts.values()))
axes[0].set_title("AV Type Distribution")
axes[0].set_xlabel("Type")
axes[0].set_ylabel("Count")

axes[1].bar(list(lang_counts.keys()), list(lang_counts.values()))
axes[1].set_title("Language Distribution")

axes[2].bar(list(gender_counts.keys()), list(gender_counts.values()))
axes[2].set_title("Gender Distribution")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Build and Run Core Processing Logic
#
# Ensure training script exists in Kaggle working directory and launch training.

# %%
import shutil

working_script = Path(CONFIG["working_dir"]) / CONFIG["script_name"]

script_candidates = list(Path("/kaggle/input").rglob(CONFIG["script_name"]))
if script_candidates:
    latest_script = max(script_candidates, key=lambda p: p.stat().st_mtime)
    shutil.copy2(latest_script, working_script)
    print("Refreshed script from:", latest_script)
elif not working_script.exists():
    raise FileNotFoundError(
        f"{CONFIG['script_name']} not found in /kaggle/input. "
        f"Upload the script as a dataset file or add a notebook cell to write it first."
    )

print("Training script path:", working_script)
print("Script exists:", working_script.exists())
# Out:
# Refreshed script from: /kaggle/input/datasets/mahirashab/essential-scripts/train_mobilevit_video_deepfake.py
# Training script path: /kaggle/working/train_mobilevit_video_deepfake.py
# Script exists: True

# %%
video_done = (Path(CONFIG["output_dir"]) / "train_embeddings.pt").exists() and (Path(CONFIG["output_dir"]) / "metrics.pt").exists()
if video_done and not CONFIG.get("force_retrain", False):
    print("Video artifacts already found. Skipping training cell.")
else:
    video_cmd = [
        "python", "-u", "/kaggle/working/train_mobilevit_video_deepfake.py",
        "--dataset-root", CONFIG["dataset_root"],
        "--output-dir", CONFIG["output_dir"],
        "--epochs", str(CONFIG["epochs"]),
        "--batch-size", str(CONFIG["batch_size"]),
        "--lr", str(CONFIG["lr"]),
        "--weight-decay", str(CONFIG["weight_decay"]),
        "--num-workers", str(CONFIG["num_workers"]),
        "--num-frames", str(CONFIG["num_frames"]),
        "--image-size", str(CONFIG["image_size"]),
        "--clip-seconds", str(CONFIG["clip_seconds"]),
        "--train-ratio", str(CONFIG["train_ratio"]),
        "--val-ratio", str(CONFIG["val_ratio"]),
        "--max-train-samples", str(CONFIG["max_train_samples"]),
        "--max-val-samples", str(CONFIG["max_val_samples"]),
        "--max-test-samples", str(CONFIG["max_test_samples"]),
    ]
    run_streaming_command(video_cmd)
# Out:
# Running: python -u /kaggle/working/train_mobilevit_video_deepfake.py --dataset-root /kaggle/working/sampled_uniform_970_videos --output-dir /kaggle/working/outputs --epochs 10 --batch-size 8 --lr 0.0001 --weight-decay 0.01 --num-workers 2 --num-frames 8 --image-size 224 --clip-seconds 6 --train-ratio 0.75 --val-ratio 0.125 --max-train-samples 0 --max-val-samples 0 --max-test-samples 0
# Using dataset root: /kaggle/working/sampled_uniform_970_videos
# Total videos: 970
# Split sizes -> train: 726, val: 120, test: 124
# Label counts (0=real video [RF/RR], 1=fake video [FF/FR]): train=[364, 362], val=[60, 60], test=[62, 62]
# Downloading: "https://download.pytorch.org/models/convnext_tiny-983f1562.pth" to /root/.cache/torch/hub/checkpoints/convnext_tiny-983f1562.pth
#
#   0%|          | 0.00/109M [00:00<?, ?B/s]
#  12%|█▏        | 13.1M/109M [00:00<00:00, 137MB/s]
#  28%|██▊       | 30.9M/109M [00:00<00:00, 166MB/s]
#  45%|████▍     | 48.6M/109M [00:00<00:00, 175MB/s]
#  61%|██████    | 66.6M/109M [00:00<00:00, 180MB/s]
#  77%|███████▋  | 84.5M/109M [00:00<00:00, 182MB/s]
#  94%|█████████▎| 102M/109M [00:00<00:00, 183MB/s]
# 100%|██████████| 109M/109M [00:00<00:00, 180MB/s]
# /kaggle/working/train_mobilevit_video_deepfake.py:540: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler(enabled=device.type == "cuda")
#
# Train:   0%|          | 0/91 [00:00<?, ?it/s]/kaggle/working/train_mobilevit_video_deepfake.py:296: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/91 [00:32<?, ?it/s, acc=0.5, loss=0.701]Train step 1/91 | loss=0.7005 | acc=0.5000
#
# Train:   1%|          | 1/91 [00:32<49:18, 32.87s/it, acc=0.5, loss=0.701]
# Train:   1%|          | 1/91 [00:33<49:18, 32.87s/it, acc=0.438, loss=0.737]
# Train:   2%|▏         | 2/91 [00:33<20:16, 13.67s/it, acc=0.438, loss=0.737]
# Train:   2%|▏         | 2/91 [00:33<20:16, 13.67s/it, acc=0.333, loss=0.775]
# Train:   3%|▎         | 3/91 [00:33<11:00,  7.51s/it, acc=0.333, loss=0.775]
# Train:   3%|▎         | 3/91 [00:33<11:00,  7.51s/it, acc=0.344, loss=0.721]
# Train:   4%|▍         | 4/91 [00:33<06:41,  4.61s/it, acc=0.344, loss=0.721]
# Train:   4%|▍         | 4/91 [00:42<06:41,  4.61s/it, acc=0.4, loss=0.702]
# Train:   5%|▌         | 5/91 [00:42<08:50,  6.16s/it, acc=0.4, loss=0.702]
# Train:   5%|▌         | 5/91 [00:50<08:50,  6.16s/it, acc=0.396, loss=0.719]
# Train:   7%|▋         | 6/91 [00:50<09:31,  6.72s/it, acc=0.396, loss=0.719]
# Train:   7%|▋         | 6/91 [00:59<09:31,  6.72s/it, acc=0.393, loss=0.717]
# Train:   8%|▊         | 7/91 [00:59<10:28,  7.48s/it, acc=0.393, loss=0.717]
# Train:   8%|▊         | 7/91 [01:02<10:28,  7.48s/it, acc=0.406, loss=0.701]
# Train:   9%|▉         | 8/91 [01:02<08:24,  6.07s/it, acc=0.406, loss=0.701]
# Train:   9%|▉         | 8/91 [01:14<08:24,  6.07s/it, acc=0.417, loss=0.704]
# Train:  10%|▉         | 9/91 [01:14<11:08,  8.15s/it, acc=0.417, loss=0.704]
# Train:  10%|▉         | 9/91 [01:15<11:08,  8.15s/it, acc=0.438, loss=0.659]Train step 10/91 | loss=0.6591 | acc=0.4375
#
# Train:  11%|█         | 10/91 [01:15<07:59,  5.92s/it, acc=0.438, loss=0.659]
# Train:  11%|█         | 10/91 [01:33<07:59,  5.92s/it, acc=0.432, loss=0.718]
# Train:  12%|█▏        | 11/91 [01:33<12:29,  9.37s/it, acc=0.432, loss=0.718]
# Train:  12%|█▏        | 11/91 [01:33<12:29,  9.37s/it, acc=0.448, loss=0.637]
# Train:  13%|█▎        | 12/91 [01:33<08:39,  6.57s/it, acc=0.448, loss=0.637]
# Train:  13%|█▎        | 12/91 [01:44<08:39,  6.57s/it, acc=0.433, loss=0.702]
# Train:  14%|█▍        | 13/91 [01:44<10:11,  7.84s/it, acc=0.433, loss=0.702]
# Train:  14%|█▍        | 13/91 [01:44<10:11,  7.84s/it, acc=0.438, loss=0.689]
# Train:  15%|█▌        | 14/91 [01:44<07:05,  5.53s/it, acc=0.438, loss=0.689]
# Train:  15%|█▌        | 14/91 [01:58<07:05,  5.53s/it, acc=0.45, loss=0.6]
# Train:  16%|█▋        | 15/91 [01:58<10:23,  8.21s/it, acc=0.45, loss=0.6]
# Train:  16%|█▋        | 15/91 [01:58<10:23,  8.21s/it, acc=0.453, loss=0.652]
# Train:  18%|█▊        | 16/91 [01:58<07:14,  5.79s/it, acc=0.453, loss=0.652]
# Train:  18%|█▊        | 16/91 [02:11<07:14,  5.79s/it, acc=0.478, loss=0.576]
# Train:  19%|█▊        | 17/91 [02:11<09:45,  7.91s/it, acc=0.478, loss=0.576]
# Train:  19%|█▊        | 17/91 [02:11<09:45,  7.91s/it, acc=0.479, loss=0.69]
# Train:  20%|█▉        | 18/91 [02:11<06:47,  5.59s/it, acc=0.479, loss=0.69]
# Train:  20%|█▉        | 18/91 [02:24<06:47,  5.59s/it, acc=0.493, loss=0.641]
# Train:  21%|██        | 19/91 [02:24<09:22,  7.81s/it, acc=0.493, loss=0.641]
# Train:  21%|██        | 19/91 [02:24<09:22,  7.81s/it, acc=0.487, loss=0.801]Train step 20/91 | loss=0.8008 | acc=0.4875
#
# Train:  22%|██▏       | 20/91 [02:24<06:31,  5.52s/it, acc=0.487, loss=0.801]
# Train:  22%|██▏       | 20/91 [02:39<06:31,  5.52s/it, acc=0.482, loss=0.797]
# Train:  23%|██▎       | 21/91 [02:39<09:28,  8.12s/it, acc=0.482, loss=0.797]
# Train:  23%|██▎       | 21/91 [02:39<09:28,  8.12s/it, acc=0.5, loss=0.626]
# Train:  24%|██▍       | 22/91 [02:39<06:36,  5.75s/it, acc=0.5, loss=0.626]
# Train:  24%|██▍       | 22/91 [02:54<06:36,  5.75s/it, acc=0.5, loss=0.767]
# Train:  25%|██▌       | 23/91 [02:54<09:38,  8.50s/it, acc=0.5, loss=0.767]
# Train:  25%|██▌       | 23/91 [02:54<09:38,  8.50s/it, acc=0.5, loss=0.877]
# Train:  26%|██▋       | 24/91 [02:54<06:42,  6.01s/it, acc=0.5, loss=0.877]
# Train:  26%|██▋       | 24/91 [03:04<06:42,  6.01s/it, acc=0.5, loss=0.752]
# Train:  27%|██▋       | 25/91 [03:04<08:01,  7.30s/it, acc=0.5, loss=0.752]
# Train:  27%|██▋       | 25/91 [03:05<08:01,  7.30s/it, acc=0.5, loss=0.715]
# Train:  29%|██▊       | 26/91 [03:05<05:35,  5.17s/it, acc=0.5, loss=0.715]
# Train:  29%|██▊       | 26/91 [03:19<05:35,  5.17s/it, acc=0.486, loss=0.775]
# Train:  30%|██▉       | 27/91 [03:19<08:23,  7.87s/it, acc=0.486, loss=0.775]
# Train:  30%|██▉       | 27/91 [03:19<08:23,  7.87s/it, acc=0.487, loss=0.728]
# Train:  31%|███       | 28/91 [03:19<05:50,  5.56s/it, acc=0.487, loss=0.728]
# Train:  31%|███       | 28/91 [03:30<05:50,  5.56s/it, acc=0.496, loss=0.659]
# Train:  32%|███▏      | 29/91 [03:30<07:22,  7.13s/it, acc=0.496, loss=0.659]
# Train:  32%|███▏      | 29/91 [03:30<07:22,  7.13s/it, acc=0.5, loss=0.614]  Train step 30/91 | loss=0.6144 | acc=0.5000
#
# Train:  40%|███▉      | 36/91 [04:09<04:42,  5.14s/it, acc=0.497, loss=0.694]
# Train:  40%|███▉      | 36/91 [04:20<04:42,  5.14s/it, acc=0.5, loss=0.658]
# Train:  41%|████      | 37/91 [04:20<06:24,  7.12s/it, acc=0.5, loss=0.658]
# Train:  41%|████      | 37/91 [04:20<06:24,  7.12s/it, acc=0.5, loss=0.693]
# Train:  42%|████▏     | 38/91 [04:20<04:26,  5.04s/it, acc=0.5, loss=0.693]
# Train:  42%|████▏     | 38/91 [04:30<04:26,  5.04s/it, acc=0.494, loss=0.748]
# Train:  43%|████▎     | 39/91 [04:30<05:26,  6.28s/it, acc=0.494, loss=0.748]
# Train:  43%|████▎     | 39/91 [04:30<05:26,  6.28s/it, acc=0.497, loss=0.608]Train step 40/91 | loss=0.6077 | acc=0.4969
#
# Train:  44%|████▍     | 40/91 [04:30<03:47,  4.45s/it, acc=0.497, loss=0.608]
# Train:  44%|████▍     | 40/91 [04:41<03:47,  4.45s/it, acc=0.5, loss=0.602]
# Train:  45%|████▌     | 41/91 [04:41<05:19,  6.39s/it, acc=0.5, loss=0.602]
# Train:  45%|████▌     | 41/91 [04:41<05:19,  6.39s/it, acc=0.503, loss=0.693]
# Train:  46%|████▌     | 42/91 [04:41<03:43,  4.57s/it, acc=0.503, loss=0.693]
# Train:  46%|████▌     | 42/91 [04:54<03:43,  4.57s/it, acc=0.509, loss=0.616]
# Train:  47%|████▋     | 43/91 [04:54<05:41,  7.12s/it, acc=0.509, loss=0.616]
# Train:  47%|████▋     | 43/91 [04:54<05:41,  7.12s/it, acc=0.514, loss=0.584]
# Train:  48%|████▊     | 44/91 [04:54<03:57,  5.05s/it, acc=0.514, loss=0.584]
# Train:  48%|████▊     | 44/91 [05:07<03:57,  5.05s/it, acc=0.511, loss=0.795]
# Train:  49%|████▉     | 45/91 [05:07<05:34,  7.28s/it, acc=0.511, loss=0.795]
# Train:  49%|████▉     | 45/91 [05:08<05:34,  7.28s/it, acc=0.505, loss=0.942]
# Train:  51%|█████     | 46/91 [05:08<04:00,  5.35s/it, acc=0.505, loss=0.942]
# Train:  51%|█████     | 46/91 [05:19<04:00,  5.35s/it, acc=0.505, loss=0.757]
# Train:  52%|█████▏    | 47/91 [05:19<05:18,  7.23s/it, acc=0.505, loss=0.757]
# Train:  52%|█████▏    | 47/91 [05:21<05:18,  7.23s/it, acc=0.508, loss=0.682]
# Train:  53%|█████▎    | 48/91 [05:21<04:00,  5.60s/it, acc=0.508, loss=0.682]
# Train:  53%|█████▎    | 48/91 [05:33<04:00,  5.60s/it, acc=0.508, loss=0.693]
# Train:  54%|█████▍    | 49/91 [05:33<05:15,  7.51s/it, acc=0.508, loss=0.693]
# Train:  54%|█████▍    | 49/91 [05:33<05:15,  7.51s/it, acc=0.505, loss=0.714]Train step 50/91 | loss=0.7143 | acc=0.5050
#
# Train:  55%|█████▍    | 50/91 [05:33<03:37,  5.31s/it, acc=0.505, loss=0.714]
# Train:  55%|█████▍    | 50/91 [05:47<03:37,  5.31s/it, acc=0.502, loss=0.668]
# Train:  56%|█████▌    | 51/91 [05:47<05:11,  7.79s/it, acc=0.502, loss=0.668]
# Train:  56%|█████▌    | 51/91 [05:47<05:11,  7.79s/it, acc=0.498, loss=0.754]
# Train:  57%|█████▋    | 52/91 [05:47<03:34,  5.51s/it, acc=0.498, loss=0.754]
# Train:  57%|█████▋    | 52/91 [06:03<03:34,  5.51s/it, acc=0.5, loss=0.691]
# Train:  58%|█████▊    | 53/91 [06:03<05:33,  8.77s/it, acc=0.5, loss=0.691]
# Train:  58%|█████▊    | 53/91 [06:04<05:33,  8.77s/it, acc=0.502, loss=0.705]
# Train:  59%|█████▉    | 54/91 [06:04<03:49,  6.19s/it, acc=0.502, loss=0.705]
# Train:  59%|█████▉    | 54/91 [06:16<03:49,  6.19s/it, acc=0.5, loss=0.725]
# Train:  60%|██████    | 55/91 [06:16<04:46,  7.97s/it, acc=0.5, loss=0.725]
# Train:  60%|██████    | 55/91 [06:16<04:46,  7.97s/it, acc=0.509, loss=0.617]
# Train:  62%|██████▏   | 56/91 [06:16<03:17,  5.63s/it, acc=0.509, loss=0.617]
# Train:  62%|██████▏   | 56/91 [06:29<03:17,  5.63s/it, acc=0.513, loss=0.682]
# Train:  63%|██████▎   | 57/91 [06:29<04:29,  7.92s/it, acc=0.513, loss=0.682]
# Train:  63%|██████▎   | 57/91 [06:29<04:29,  7.92s/it, acc=0.511, loss=0.7]
# Train:  64%|██████▎   | 58/91 [06:29<03:04,  5.60s/it, acc=0.511, loss=0.7]
# Train:  64%|██████▎   | 58/91 [06:43<03:04,  5.60s/it, acc=0.513, loss=0.662]
# Train:  65%|██████▍   | 59/91 [06:43<04:16,  8.01s/it, acc=0.513, loss=0.662]
# Train:  65%|██████▍   | 59/91 [06:43<04:16,  8.01s/it, acc=0.512, loss=0.72] Train step 60/91 | loss=0.7202 | acc=0.5125
#
# Train:  66%|██████▌   | 60/91 [06:43<02:56,  5.71s/it, acc=0.512, loss=0.72]
# Train:  66%|██████▌   | 60/91 [06:55<02:56,  5.71s/it, acc=0.506, loss=0.793]
# Train:  67%|██████▋   | 61/91 [06:55<03:41,  7.37s/it, acc=0.506, loss=0.793]
# Train:  67%|██████▋   | 61/91 [06:55<03:41,  7.37s/it, acc=0.51, loss=0.651]
# Train:  68%|██████▊   | 62/91 [06:55<02:31,  5.22s/it, acc=0.51, loss=0.651]
# Train:  68%|██████▊   | 62/91 [07:08<02:31,  5.22s/it, acc=0.508, loss=0.673]
# Train:  69%|██████▉   | 63/91 [07:08<03:33,  7.63s/it, acc=0.508, loss=0.673]
# Train:  69%|██████▉   | 63/91 [07:10<03:33,  7.63s/it, acc=0.514, loss=0.648]
# Train:  70%|███████   | 64/91 [07:10<02:37,  5.84s/it, acc=0.514, loss=0.648]
# Train:  70%|███████   | 64/91 [07:22<02:37,  5.84s/it, acc=0.512, loss=0.699]
# Train:  71%|███████▏  | 65/91 [07:22<03:26,  7.93s/it, acc=0.512, loss=0.699]
# Train:  71%|███████▏  | 65/91 [07:23<03:26,  7.93s/it, acc=0.511, loss=0.698]
# Train:  73%|███████▎  | 66/91 [07:23<02:23,  5.73s/it, acc=0.511, loss=0.698]
# Train:  73%|███████▎  | 66/91 [07:36<02:23,  5.73s/it, acc=0.515, loss=0.705]
# Train:  74%|███████▎  | 67/91 [07:36<03:10,  7.92s/it, acc=0.515, loss=0.705]
# Train:  74%|███████▎  | 67/91 [07:38<03:10,  7.92s/it, acc=0.513, loss=0.678]
# Train:  75%|███████▍  | 68/91 [07:38<02:19,  6.06s/it, acc=0.513, loss=0.678]
# Train:  75%|███████▍  | 68/91 [07:47<02:19,  6.06s/it, acc=0.516, loss=0.641]
# Train:  76%|███████▌  | 69/91 [07:47<02:33,  6.99s/it, acc=0.516, loss=0.641]
# Train:  76%|███████▌  | 69/91 [07:50<02:33,  6.99s/it, acc=0.516, loss=0.698]Train step 70/91 | loss=0.6983 | acc=0.5161
#
# Train:  77%|███████▋  | 70/91 [07:50<02:04,  5.93s/it, acc=0.516, loss=0.698]
# Train:  77%|███████▋  | 70/91 [08:02<02:04,  5.93s/it, acc=0.519, loss=0.678]
# Train:  78%|███████▊  | 71/91 [08:02<02:32,  7.64s/it, acc=0.519, loss=0.678]
# Train:  78%|███████▊  | 71/91 [08:05<02:32,  7.64s/it, acc=0.526, loss=0.656]
# Train:  79%|███████▉  | 72/91 [08:05<01:58,  6.24s/it, acc=0.526, loss=0.656]
# Train:  79%|███████▉  | 72/91 [08:17<01:58,  6.24s/it, acc=0.526, loss=0.692]
# Train:  80%|████████  | 73/91 [08:17<02:25,  8.08s/it, acc=0.526, loss=0.692]
# Train:  80%|████████  | 73/91 [08:18<02:25,  8.08s/it, acc=0.527, loss=0.649]
# Train:  81%|████████▏ | 74/91 [08:18<01:37,  5.71s/it, acc=0.527, loss=0.649]
# Train:  81%|████████▏ | 74/91 [08:33<01:37,  5.71s/it, acc=0.528, loss=0.666]
# Train:  82%|████████▏ | 75/91 [08:33<02:16,  8.55s/it, acc=0.528, loss=0.666]
# Train:  82%|████████▏ | 75/91 [08:33<02:16,  8.55s/it, acc=0.528, loss=0.675]
# Train:  84%|████████▎ | 76/91 [08:33<01:30,  6.04s/it, acc=0.528, loss=0.675]
# Train:  84%|████████▎ | 76/91 [08:43<01:30,  6.04s/it, acc=0.529, loss=0.685]
# Train:  85%|████████▍ | 77/91 [08:43<01:43,  7.39s/it, acc=0.529, loss=0.685]
# Train:  85%|████████▍ | 77/91 [08:44<01:43,  7.39s/it, acc=0.53, loss=0.662]
# Train:  86%|████████▌ | 78/91 [08:44<01:07,  5.22s/it, acc=0.53, loss=0.662]
# Train:  86%|████████▌ | 78/91 [08:58<01:07,  5.22s/it, acc=0.533, loss=0.64]
# Train:  87%|████████▋ | 79/91 [08:58<01:37,  8.09s/it, acc=0.533, loss=0.64]
# Train:  87%|████████▋ | 79/91 [08:59<01:37,  8.09s/it, acc=0.534, loss=0.629]Train step 80/91 | loss=0.6287 | acc=0.5344
#
# Train:  88%|████████▊ | 80/91 [08:59<01:02,  5.72s/it, acc=0.534, loss=0.629]
# Train:  88%|████████▊ | 80/91 [09:10<01:02,  5.72s/it, acc=0.534, loss=0.707]
# Train:  89%|████████▉ | 81/91 [09:10<01:14,  7.46s/it, acc=0.534, loss=0.707]
# Train:  89%|████████▉ | 81/91 [09:10<01:14,  7.46s/it, acc=0.535, loss=0.646]
# Train:  97%|█████████▋| 88/91 [09:51<00:17,  5.86s/it, acc=0.537, loss=0.656]
# Train:  97%|█████████▋| 88/91 [10:02<00:17,  5.86s/it, acc=0.538, loss=0.599]
# Train:  98%|█████████▊| 89/91 [10:02<00:15,  7.55s/it, acc=0.538, loss=0.599]
# Train:  98%|█████████▊| 89/91 [10:03<00:15,  7.55s/it, acc=0.54, loss=0.518] Train step 90/91 | loss=0.5178 | acc=0.5403
#
# Train:  99%|█████████▉| 90/91 [10:03<00:05,  5.34s/it, acc=0.54, loss=0.518]
# Train:  99%|█████████▉| 90/91 [10:18<00:05,  5.34s/it, acc=0.543, loss=0.465]Train step 91/91 | loss=0.4648 | acc=0.5427
#
# Train: 100%|██████████| 91/91 [10:18<00:00,  8.28s/it, acc=0.543, loss=0.465]
#
#
# Val:   0%|          | 0/15 [00:00<?, ?it/s]/kaggle/working/train_mobilevit_video_deepfake.py:340: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
# Val step 1/15 | loss=0.6971 | acc=0.3750
#
# Val:   7%|▋         | 1/15 [00:14<03:21, 14.37s/it]
# Val:  13%|█▎        | 2/15 [00:16<01:36,  7.42s/it]
# Val:  20%|██        | 3/15 [00:29<01:58,  9.84s/it]
# Val:  27%|██▋       | 4/15 [00:29<01:06,  6.00s/it]
# Val:  33%|███▎      | 5/15 [00:39<01:14,  7.41s/it]
# Val:  40%|████      | 6/15 [00:43<00:55,  6.18s/it]
# Val:  47%|████▋     | 7/15 [00:51<00:53,  6.71s/it]
# Val:  53%|█████▎    | 8/15 [00:59<00:50,  7.19s/it]
# Val:  60%|██████    | 9/15 [01:07<00:43,  7.31s/it]Val step 10/15 | loss=0.6055 | acc=0.5500
#
# Val:  67%|██████▋   | 10/15 [01:16<00:39,  7.90s/it]
# Val:  73%|███████▎  | 11/15 [01:21<00:28,  7.07s/it]
# Val:  80%|████████  | 12/15 [01:29<00:22,  7.45s/it]
# Val:  87%|████████▋ | 13/15 [01:35<00:13,  6.81s/it]
# Val:  93%|█████████▎| 14/15 [01:43<00:07,  7.22s/it]Val step 15/15 | loss=0.5026 | acc=0.5667
#
# Val: 100%|██████████| 15/15 [01:45<00:00,  5.84s/it]
#
# Epoch 01/10 | Train Loss: 0.6861 | Train Acc: 0.5427 | Val Loss: 0.6130 | Val Acc: 0.5667
# Saved new best checkpoint to: /kaggle/working/outputs/convnext_tiny_deepfake_best.pt
#
# Train:   0%|          | 0/91 [00:00<?, ?it/s]
# Train:   0%|          | 0/91 [00:16<?, ?it/s, acc=0.375, loss=0.687]Train step 1/91 | loss=0.6868 | acc=0.3750
#
# Train:   1%|          | 1/91 [00:16<25:11, 16.79s/it, acc=0.375, loss=0.687]
# Train:   1%|          | 1/91 [00:16<25:11, 16.79s/it, acc=0.5, loss=0.637]
# Train:   2%|▏         | 2/91 [00:16<10:24,  7.02s/it, acc=0.5, loss=0.637]
# Train:   2%|▏         | 2/91 [00:30<10:24,  7.02s/it, acc=0.625, loss=0.419]
# Train:   3%|▎         | 3/91 [00:30<14:48, 10.09s/it, acc=0.625, loss=0.419]
# Train:   3%|▎         | 3/91 [00:30<14:48, 10.09s/it, acc=0.625, loss=0.637]
# Train:   4%|▍         | 4/91 [00:30<08:58,  6.19s/it, acc=0.625, loss=0.637]
# Train:   4%|▍         | 4/91 [00:43<08:58,  6.19s/it, acc=0.675, loss=0.452]
# Train:   5%|▌         | 5/91 [00:43<12:02,  8.40s/it, acc=0.675, loss=0.452]
# Train:   5%|▌         | 5/91 [00:43<12:02,  8.40s/it, acc=0.708, loss=0.467]
# Train:   7%|▋         | 6/91 [00:43<07:56,  5.60s/it, acc=0.708, loss=0.467]
# Train:   7%|▋         | 6/91 [00:57<07:56,  5.60s/it, acc=0.696, loss=0.682]
# Train:   8%|▊         | 7/91 [00:57<11:48,  8.43s/it, acc=0.696, loss=0.682]
# Train:   8%|▊         | 7/91 [00:57<11:48,  8.43s/it, acc=0.734, loss=0.303]
# Train:   9%|▉         | 8/91 [00:57<08:01,  5.81s/it, acc=0.734, loss=0.303]
# Train:   9%|▉         | 8/91 [01:10<08:01,  5.81s/it, acc=0.722, loss=0.5]
# Train:  10%|▉         | 9/91 [01:10<10:42,  7.83s/it, acc=0.722, loss=0.5]
# Train:  10%|▉         | 9/91 [01:10<10:42,  7.83s/it, acc=0.75, loss=0.333]Train step 10/91 | loss=0.3335 | acc=0.7500
#
# Train:  11%|█         | 10/91 [01:10<07:22,  5.47s/it, acc=0.75, loss=0.333]
# Train:  11%|█         | 10/91 [01:24<07:22,  5.47s/it, acc=0.761, loss=0.295]
# Train:  12%|█▏        | 11/91 [01:24<10:53,  8.17s/it, acc=0.761, loss=0.295]
# Train:  12%|█▏        | 11/91 [01:24<10:53,  8.17s/it, acc=0.75, loss=0.674]
# Train:  13%|█▎        | 12/91 [01:24<07:33,  5.74s/it, acc=0.75, loss=0.674]
# Train:  13%|█▎        | 12/91 [01:39<07:33,  5.74s/it, acc=0.76, loss=0.429]
# Train:  14%|█▍        | 13/91 [01:39<10:52,  8.37s/it, acc=0.76, loss=0.429]
# Train:  14%|█▍        | 13/91 [01:39<10:52,  8.37s/it, acc=0.759, loss=0.44]
# Train:  15%|█▌        | 14/91 [01:39<07:34,  5.90s/it, acc=0.759, loss=0.44]
# Train:  15%|█▌        | 14/91 [01:50<07:34,  5.90s/it, acc=0.758, loss=0.319]
# Train:  16%|█▋        | 15/91 [01:50<09:29,  7.49s/it, acc=0.758, loss=0.319]
# Train:  16%|█▋        | 15/91 [01:50<09:29,  7.49s/it, acc=0.758, loss=0.402]
# Train:  18%|█▊        | 16/91 [01:50<06:36,  5.29s/it, acc=0.758, loss=0.402]
# Train:  18%|█▊        | 16/91 [01:59<06:36,  5.29s/it, acc=0.765, loss=0.372]
# Train:  19%|█▊        | 17/91 [01:59<07:52,  6.38s/it, acc=0.765, loss=0.372]
# Train:  19%|█▊        | 17/91 [01:59<07:52,  6.38s/it, acc=0.764, loss=0.318]
# Train:  20%|█▉        | 18/91 [01:59<05:29,  4.52s/it, acc=0.764, loss=0.318]
# Train:  20%|█▉        | 18/91 [02:14<05:29,  4.52s/it, acc=0.776, loss=0.17]
# Train:  21%|██        | 19/91 [02:14<09:07,  7.60s/it, acc=0.776, loss=0.17]
# Train:  21%|██        | 19/91 [02:14<09:07,  7.60s/it, acc=0.781, loss=0.398]Train step 20/91 | loss=0.3976 | acc=0.7812
#
# Train:  22%|██▏       | 20/91 [02:14<06:21,  5.38s/it, acc=0.781, loss=0.398]
# Train:  22%|██▏       | 20/91 [02:24<06:21,  5.38s/it, acc=0.792, loss=0.154]
# Train:  23%|██▎       | 21/91 [02:24<07:45,  6.64s/it, acc=0.792, loss=0.154]
# Train:  23%|██▎       | 21/91 [02:25<07:45,  6.64s/it, acc=0.801, loss=0.0961]
# Train:  24%|██▍       | 22/91 [02:25<05:53,  5.12s/it, acc=0.801, loss=0.0961]
# Train:  24%|██▍       | 22/91 [02:39<05:53,  5.12s/it, acc=0.81, loss=0.13]
# Train:  25%|██▌       | 23/91 [02:39<08:33,  7.55s/it, acc=0.81, loss=0.13]
# Train:  25%|██▌       | 23/91 [02:39<08:33,  7.55s/it, acc=0.818, loss=0.0549]
# Train:  26%|██▋       | 24/91 [02:39<05:57,  5.34s/it, acc=0.818, loss=0.0549]
# Train:  26%|██▋       | 24/91 [02:51<05:57,  5.34s/it, acc=0.82, loss=0.318]
# Train:  27%|██▋       | 25/91 [02:51<08:09,  7.42s/it, acc=0.82, loss=0.318]
# Train:  27%|██▋       | 25/91 [02:51<08:09,  7.42s/it, acc=0.827, loss=0.0348]
# Train:  29%|██▊       | 26/91 [02:51<05:41,  5.25s/it, acc=0.827, loss=0.0348]
# Train:  29%|██▊       | 26/91 [03:05<05:41,  5.25s/it, acc=0.829, loss=0.384]
# Train:  30%|██▉       | 27/91 [03:05<08:12,  7.69s/it, acc=0.829, loss=0.384]
# Train:  30%|██▉       | 27/91 [03:05<08:12,  7.69s/it, acc=0.835, loss=0.102]
# Train:  31%|███       | 28/91 [03:05<05:42,  5.44s/it, acc=0.835, loss=0.102]
# Train:  31%|███       | 28/91 [03:16<05:42,  5.44s/it, acc=0.832, loss=0.529]
# Train:  32%|███▏      | 29/91 [03:16<07:25,  7.18s/it, acc=0.832, loss=0.529]
# Train:  32%|███▏      | 29/91 [03:17<07:25,  7.18s/it, acc=0.833, loss=0.183]Train step 30/91 | loss=0.1828 | acc=0.8333
#
# Train:  33%|███▎      | 30/91 [03:17<05:14,  5.16s/it, acc=0.833, loss=0.183]
# Train:  33%|███▎      | 30/91 [03:30<05:14,  5.16s/it, acc=0.835, loss=0.242]
# Train:  34%|███▍      | 31/91 [03:30<07:39,  7.66s/it, acc=0.835, loss=0.242]
# Train:  34%|███▍      | 31/91 [03:31<07:39,  7.66s/it, acc=0.836, loss=0.295]
# Train:  35%|███▌      | 32/91 [03:31<05:38,  5.73s/it, acc=0.836, loss=0.295]
# Train:  35%|███▌      | 32/91 [03:41<05:38,  5.73s/it, acc=0.837, loss=0.221]
# Train:  36%|███▋      | 33/91 [03:41<06:43,  6.95s/it, acc=0.837, loss=0.221]
# Train:  36%|███▋      | 33/91 [03:45<06:43,  6.95s/it, acc=0.842, loss=0.0955]
# Train:  37%|███▋      | 34/91 [03:45<05:42,  6.01s/it, acc=0.842, loss=0.0955]
# Train:  37%|███▋      | 34/91 [03:57<05:42,  6.01s/it, acc=0.846, loss=0.044]
# Train:  38%|███▊      | 35/91 [03:57<07:20,  7.86s/it, acc=0.846, loss=0.044]
# Train:  38%|███▊      | 35/91 [03:58<07:20,  7.86s/it, acc=0.851, loss=0.0509]
# Train:  40%|███▉      | 36/91 [03:58<05:20,  5.82s/it, acc=0.851, loss=0.0509]
# Train:  40%|███▉      | 36/91 [04:10<05:20,  5.82s/it, acc=0.855, loss=0.125]
# Train:  41%|████      | 37/91 [04:10<06:48,  7.57s/it, acc=0.855, loss=0.125]
# Train:  41%|████      | 37/91 [04:10<06:48,  7.57s/it, acc=0.859, loss=0.0321]
# Train:  42%|████▏     | 38/91 [04:10<04:43,  5.35s/it, acc=0.859, loss=0.0321]
# Train:  42%|████▏     | 38/91 [04:25<04:43,  5.35s/it, acc=0.862, loss=0.0704]
# Train:  43%|████▎     | 39/91 [04:25<07:03,  8.15s/it, acc=0.862, loss=0.0704]
# Train:  43%|████▎     | 39/91 [04:25<07:03,  8.15s/it, acc=0.863, loss=0.333] Train step 40/91 | loss=0.3328 | acc=0.8625
#
# Train:  44%|████▍     | 40/91 [04:25<04:53,  5.76s/it, acc=0.863, loss=0.333]
# Train:  44%|████▍     | 40/91 [04:37<04:53,  5.76s/it, acc=0.866, loss=0.111]
# Train:  45%|████▌     | 41/91 [04:37<06:21,  7.63s/it, acc=0.866, loss=0.111]
# Train:  45%|████▌     | 41/91 [04:37<06:21,  7.63s/it, acc=0.869, loss=0.0137]
# Train:  46%|████▌     | 42/91 [04:37<04:24,  5.40s/it, acc=0.869, loss=0.0137]
# Train:  46%|████▌     | 42/91 [04:47<04:24,  5.40s/it, acc=0.869, loss=0.302]
# Train:  47%|████▋     | 43/91 [04:47<05:26,  6.81s/it, acc=0.869, loss=0.302]
# Train:  47%|████▋     | 43/91 [04:47<05:26,  6.81s/it, acc=0.869, loss=0.27]
# Train:  48%|████▊     | 44/91 [04:47<03:46,  4.82s/it, acc=0.869, loss=0.27]
# Train:  48%|████▊     | 44/91 [04:58<03:46,  4.82s/it, acc=0.872, loss=0.164]
# Train:  49%|████▉     | 45/91 [04:58<04:58,  6.49s/it, acc=0.872, loss=0.164]
# Train:  49%|████▉     | 45/91 [04:59<04:58,  6.49s/it, acc=0.875, loss=0.0581]
# Train:  51%|█████     | 46/91 [04:59<03:37,  4.84s/it, acc=0.875, loss=0.0581]
# Train:  51%|█████     | 46/91 [05:13<03:37,  4.84s/it, acc=0.875, loss=0.265]
# Train:  52%|█████▏    | 47/91 [05:13<05:43,  7.80s/it, acc=0.875, loss=0.265]
# Train:  52%|█████▏    | 47/91 [05:14<05:43,  7.80s/it, acc=0.878, loss=0.0705]
# Train:  53%|█████▎    | 48/91 [05:14<03:57,  5.51s/it, acc=0.878, loss=0.0705]
# Train:  53%|█████▎    | 48/91 [05:27<03:57,  5.51s/it, acc=0.88, loss=0.06]
# Train:  54%|█████▍    | 49/91 [05:27<05:29,  7.85s/it, acc=0.88, loss=0.06]
# Train:  54%|█████▍    | 49/91 [05:28<05:29,  7.85s/it, acc=0.882, loss=0.128]Train step 50/91 | loss=0.1281 | acc=0.8825
#
# Train:  55%|█████▍    | 50/91 [05:28<03:53,  5.70s/it, acc=0.882, loss=0.128]
# Train:  55%|█████▍    | 50/91 [05:39<03:53,  5.70s/it, acc=0.885, loss=0.0149]
# Train:  56%|█████▌    | 51/91 [05:39<04:51,  7.28s/it, acc=0.885, loss=0.0149]
# Train:  56%|█████▌    | 51/91 [05:42<04:51,  7.28s/it, acc=0.887, loss=0.0276]
# Train:  57%|█████▋    | 52/91 [05:42<04:01,  6.18s/it, acc=0.887, loss=0.0276]
# Train:  57%|█████▋    | 52/91 [05:54<04:01,  6.18s/it, acc=0.887, loss=0.276]
# Train:  58%|█████▊    | 53/91 [05:54<05:01,  7.93s/it, acc=0.887, loss=0.276]
# Train:  58%|█████▊    | 53/91 [05:55<05:01,  7.93s/it, acc=0.889, loss=0.136]
# Train:  59%|█████▉    | 54/91 [05:55<03:35,  5.83s/it, acc=0.889, loss=0.136]
# Train:  59%|█████▉    | 54/91 [06:08<03:35,  5.83s/it, acc=0.891, loss=0.0634]
# Train:  60%|██████    | 55/91 [06:08<04:44,  7.91s/it, acc=0.891, loss=0.0634]
# Train:  60%|██████    | 55/91 [06:08<04:44,  7.91s/it, acc=0.888, loss=0.267]
# Train:  62%|██████▏   | 56/91 [06:08<03:15,  5.59s/it, acc=0.888, loss=0.267]
# Train:  62%|██████▏   | 56/91 [06:24<03:15,  5.59s/it, acc=0.89, loss=0.0641]
# Train:  63%|██████▎   | 57/91 [06:24<04:52,  8.61s/it, acc=0.89, loss=0.0641]
# Train:  63%|██████▎   | 57/91 [06:24<04:52,  8.61s/it, acc=0.892, loss=0.0302]
# Train:  64%|██████▎   | 58/91 [06:24<03:20,  6.08s/it, acc=0.892, loss=0.0302]
# Train:  64%|██████▎   | 58/91 [06:39<03:20,  6.08s/it, acc=0.894, loss=0.0206]
# Train:  65%|██████▍   | 59/91 [06:39<04:36,  8.65s/it, acc=0.894, loss=0.0206]
# Train:  65%|██████▍   | 59/91 [06:39<04:36,  8.65s/it, acc=0.896, loss=0.0484]Train step 60/91 | loss=0.0484 | acc=0.8958
#
# Train:  66%|██████▌   | 60/91 [06:39<03:09,  6.11s/it, acc=0.896, loss=0.0484]
# Train:  66%|██████▌   | 60/91 [06:50<03:09,  6.11s/it, acc=0.898, loss=0.00858]
# Train:  67%|██████▋   | 61/91 [06:50<03:52,  7.74s/it, acc=0.898, loss=0.00858]
# Train:  67%|██████▋   | 61/91 [06:50<03:52,  7.74s/it, acc=0.899, loss=0.0164]
# Train:  68%|██████▊   | 62/91 [06:50<02:38,  5.48s/it, acc=0.899, loss=0.0164]
# Train:  68%|██████▊   | 62/91 [07:05<02:38,  5.48s/it, acc=0.901, loss=0.0078]
# Train:  69%|██████▉   | 63/91 [07:05<03:48,  8.15s/it, acc=0.901, loss=0.0078]
# Train:  69%|██████▉   | 63/91 [07:05<03:48,  8.15s/it, acc=0.9, loss=0.438]
# Train:  70%|███████   | 64/91 [07:05<02:35,  5.76s/it, acc=0.9, loss=0.438]
# Train:  70%|███████   | 64/91 [07:18<02:35,  5.76s/it, acc=0.902, loss=0.00964]
# Train:  71%|███████▏  | 65/91 [07:18<03:29,  8.06s/it, acc=0.902, loss=0.00964]
# Train:  71%|███████▏  | 65/91 [07:19<03:29,  8.06s/it, acc=0.903, loss=0.0775]
# Train:  73%|███████▎  | 66/91 [07:19<02:22,  5.70s/it, acc=0.903, loss=0.0775]
# Train:  73%|███████▎  | 66/91 [07:33<02:22,  5.70s/it, acc=0.905, loss=0.0654]
# Train:  74%|███████▎  | 67/91 [07:33<03:21,  8.38s/it, acc=0.905, loss=0.0654]
# Train:  74%|███████▎  | 67/91 [07:33<03:21,  8.38s/it, acc=0.906, loss=0.0073]
# Train:  75%|███████▍  | 68/91 [07:33<02:16,  5.92s/it, acc=0.906, loss=0.0073]
# Train:  75%|███████▍  | 68/91 [07:47<02:16,  5.92s/it, acc=0.908, loss=0.00841]
# Train:  76%|███████▌  | 69/91 [07:47<03:02,  8.30s/it, acc=0.908, loss=0.00841]
# Train:  76%|███████▌  | 69/91 [07:47<03:02,  8.30s/it, acc=0.905, loss=0.619]  Train step 70/91 | loss=0.6187 | acc=0.9054
#
# Train:  77%|███████▋  | 70/91 [07:47<02:03,  5.86s/it, acc=0.905, loss=0.619]
# Train:  77%|███████▋  | 70/91 [08:00<02:03,  5.86s/it, acc=0.905, loss=0.486]
# Train:  78%|███████▊  | 71/91 [08:00<02:37,  7.87s/it, acc=0.905, loss=0.486]
# Train:  78%|███████▊  | 71/91 [08:00<02:37,  7.87s/it, acc=0.906, loss=0.00874]
# Train:  79%|███████▉  | 72/91 [08:00<01:45,  5.57s/it, acc=0.906, loss=0.00874]
# Train:  79%|███████▉  | 72/91 [08:12<01:45,  5.57s/it, acc=0.908, loss=0.014]
# Train:  80%|████████  | 73/91 [08:12<02:11,  7.30s/it, acc=0.908, loss=0.014]
# Train:  80%|████████  | 73/91 [08:12<02:11,  7.30s/it, acc=0.907, loss=0.127]
# Train:  81%|████████▏ | 74/91 [08:12<01:27,  5.17s/it, acc=0.907, loss=0.127]
# Train:  81%|████████▏ | 74/91 [08:26<01:27,  5.17s/it, acc=0.908, loss=0.0254]
# Train:  82%|████████▏ | 75/91 [08:26<02:04,  7.80s/it, acc=0.908, loss=0.0254]
# Train:  82%|████████▏ | 75/91 [08:26<02:04,  7.80s/it, acc=0.91, loss=0.00881]
# Train:  84%|████████▎ | 76/91 [08:26<01:22,  5.52s/it, acc=0.91, loss=0.00881]
# Train:  84%|████████▎ | 76/91 [08:37<01:22,  5.52s/it, acc=0.911, loss=0.0376]
# Train:  85%|████████▍ | 77/91 [08:37<01:39,  7.11s/it, acc=0.911, loss=0.0376]
# Train:  85%|████████▍ | 77/91 [08:37<01:39,  7.11s/it, acc=0.912, loss=0.0232]
# Train:  86%|████████▌ | 78/91 [08:37<01:05,  5.04s/it, acc=0.912, loss=0.0232]
# Train:  86%|████████▌ | 78/91 [08:49<01:05,  5.04s/it, acc=0.91, loss=0.721]
# Train:  87%|████████▋ | 79/91 [08:49<01:27,  7.26s/it, acc=0.91, loss=0.721]
# Train:  87%|████████▋ | 79/91 [08:50<01:27,  7.26s/it, acc=0.911, loss=0.0153]Train step 80/91 | loss=0.0153 | acc=0.9109
#
# Train:  88%|████████▊ | 80/91 [08:50<00:56,  5.13s/it, acc=0.911, loss=0.0153]
# Train:  88%|████████▊ | 80/91 [09:02<00:56,  5.13s/it, acc=0.912, loss=0.00733]
# Train:  89%|████████▉ | 81/91 [09:02<01:13,  7.31s/it, acc=0.912, loss=0.00733]
# Train:  89%|████████▉ | 81/91 [09:02<01:13,  7.31s/it, acc=0.912, loss=0.146]
# Train:  90%|█████████ | 82/91 [09:02<00:46,  5.18s/it, acc=0.912, loss=0.146]
# Train:  90%|█████████ | 82/91 [09:13<00:46,  5.18s/it, acc=0.913, loss=0.0142]
# Train:  91%|█████████ | 83/91 [09:13<00:56,  7.02s/it, acc=0.913, loss=0.0142]
# Train:  91%|█████████ | 83/91 [09:14<00:56,  7.02s/it, acc=0.914, loss=0.015]
# Train:  92%|█████████▏| 84/91 [09:14<00:34,  4.97s/it, acc=0.914, loss=0.015]
# Train:  92%|█████████▏| 84/91 [09:28<00:34,  4.97s/it, acc=0.913, loss=0.288]
# Train:  93%|█████████▎| 85/91 [09:28<00:45,  7.64s/it, acc=0.913, loss=0.288]
# Train:  93%|█████████▎| 85/91 [09:28<00:45,  7.64s/it, acc=0.914, loss=0.0108]
# Train:  95%|█████████▍| 86/91 [09:28<00:27,  5.41s/it, acc=0.914, loss=0.0108]
# Train:  95%|█████████▍| 86/91 [09:41<00:27,  5.41s/it, acc=0.915, loss=0.02]
# Train:  96%|█████████▌| 87/91 [09:41<00:31,  7.92s/it, acc=0.915, loss=0.02]
# Train:  96%|█████████▌| 87/91 [09:42<00:31,  7.92s/it, acc=0.916, loss=0.0437]
# Train:  97%|█████████▋| 88/91 [09:42<00:16,  5.60s/it, acc=0.916, loss=0.0437]
# Train:  97%|█████████▋| 88/91 [09:51<00:16,  5.60s/it, acc=0.917, loss=0.0305]
# Train:  98%|█████████▊| 89/91 [09:51<00:13,  6.75s/it, acc=0.917, loss=0.0305]
# Train:  98%|█████████▊| 89/91 [09:51<00:13,  6.75s/it, acc=0.918, loss=0.0141]Train step 90/91 | loss=0.0141 | acc=0.9181
#
# Train:  99%|█████████▉| 90/91 [09:51<00:04,  4.78s/it, acc=0.918, loss=0.0141]
# Train:  99%|█████████▉| 90/91 [09:58<00:04,  4.78s/it, acc=0.919, loss=0.0103]Train step 91/91 | loss=0.0103 | acc=0.9187
#
# Train: 100%|██████████| 91/91 [09:58<00:00,  5.41s/it, acc=0.919, loss=0.0103]
#
#
# Val:   0%|          | 0/15 [00:00<?, ?it/s]Val step 1/15 | loss=0.0493 | acc=1.0000
#
# Val:   7%|▋         | 1/15 [00:14<03:24, 14.61s/it]
# Val:  13%|█▎        | 2/15 [00:16<01:36,  7.41s/it]
# Val:  20%|██        | 3/15 [00:29<01:59,  9.97s/it]
# Val:  27%|██▋       | 4/15 [00:30<01:06,  6.07s/it]
# Val:  33%|███▎      | 5/15 [00:40<01:15,  7.53s/it]
# Val:  40%|████      | 6/15 [00:42<00:53,  5.90s/it]
# Val:  47%|████▋     | 7/15 [00:52<00:55,  6.95s/it]
# Val:  53%|█████▎    | 8/15 [00:58<00:48,  6.92s/it]
# Val:  60%|██████    | 9/15 [01:07<00:45,  7.60s/it]Val step 10/15 | loss=0.0560 | acc=0.9500
#
# Val:  67%|██████▋   | 10/15 [01:15<00:38,  7.63s/it]
# Val:  73%|███████▎  | 11/15 [01:22<00:29,  7.40s/it]
# Val:  80%|████████  | 12/15 [01:29<00:21,  7.22s/it]
# Val:  87%|████████▋ | 13/15 [01:35<00:14,  7.01s/it]
# Val:  93%|█████████▎| 14/15 [01:42<00:07,  7.03s/it]Val step 15/15 | loss=0.1521 | acc=0.9417
#
# Val: 100%|██████████| 15/15 [01:46<00:00,  5.86s/it]
#
# Epoch 02/10 | Train Loss: 0.1999 | Train Acc: 0.9187 | Val Loss: 0.1844 | Val Acc: 0.9417
# Saved new best checkpoint to: /kaggle/working/outputs/convnext_tiny_deepfake_best.pt
#
# Train:   0%|          | 0/91 [00:00<?, ?it/s]
# Train:   0%|          | 0/91 [00:15<?, ?it/s, acc=0.875, loss=0.147]Train step 1/91 | loss=0.1467 | acc=0.8750
#
# Train:   1%|          | 1/91 [00:15<22:43, 15.15s/it, acc=0.875, loss=0.147]
# Train:   1%|          | 1/91 [00:15<22:43, 15.15s/it, acc=0.938, loss=0.055]
# Train:   2%|▏         | 2/91 [00:15<09:33,  6.44s/it, acc=0.938, loss=0.055]
# Train:   2%|▏         | 2/91 [00:31<09:33,  6.44s/it, acc=0.958, loss=0.0214]
# Train:   3%|▎         | 3/91 [00:31<15:47, 10.77s/it, acc=0.958, loss=0.0214]
# Train:   3%|▎         | 3/91 [00:31<15:47, 10.77s/it, acc=0.969, loss=0.0411]
# Train:   4%|▍         | 4/91 [00:31<09:33,  6.59s/it, acc=0.969, loss=0.0411]
# Train:   4%|▍         | 4/91 [00:47<09:33,  6.59s/it, acc=0.975, loss=0.00867]
# Train:   5%|▌         | 5/91 [00:47<14:00,  9.77s/it, acc=0.975, loss=0.00867]
# Train:   5%|▌         | 5/91 [00:47<14:00,  9.77s/it, acc=0.979, loss=0.0121]
# Train:   7%|▋         | 6/91 [00:47<09:13,  6.51s/it, acc=0.979, loss=0.0121]
# Train:   7%|▋         | 6/91 [00:58<09:13,  6.51s/it, acc=0.982, loss=0.011]
# Train:   8%|▊         | 7/91 [00:58<11:08,  7.95s/it, acc=0.982, loss=0.011]
# Train:   8%|▊         | 7/91 [00:58<11:08,  7.95s/it, acc=0.984, loss=0.0614]
# Train:   9%|▉         | 8/91 [00:58<07:34,  5.48s/it, acc=0.984, loss=0.0614]
# Train:   9%|▉         | 8/91 [01:12<07:34,  5.48s/it, acc=0.986, loss=0.0199]
# Train:  10%|▉         | 9/91 [01:12<11:12,  8.20s/it, acc=0.986, loss=0.0199]
# Train:  10%|▉         | 9/91 [01:12<11:12,  8.20s/it, acc=0.988, loss=0.00585]Train step 10/91 | loss=0.0059 | acc=0.9875
#
# Train:  11%|█         | 10/91 [01:12<07:43,  5.73s/it, acc=0.988, loss=0.00585]
# Train:  11%|█         | 10/91 [01:27<07:43,  5.73s/it, acc=0.977, loss=0.156]
# Train:  12%|█▏        | 11/91 [01:27<11:28,  8.61s/it, acc=0.977, loss=0.156]
# Train:  12%|█▏        | 11/91 [01:28<11:28,  8.61s/it, acc=0.979, loss=0.00741]
# Train:  13%|█▎        | 12/91 [01:28<07:57,  6.05s/it, acc=0.979, loss=0.00741]
# Train:  13%|█▎        | 12/91 [01:41<07:57,  6.05s/it, acc=0.981, loss=0.00563]
# Train:  14%|█▍        | 13/91 [01:41<10:36,  8.15s/it, acc=0.981, loss=0.00563]
# Train:  14%|█▍        | 13/91 [01:41<10:36,  8.15s/it, acc=0.982, loss=0.00613]
# Train:  15%|█▌        | 14/91 [01:41<07:22,  5.75s/it, acc=0.982, loss=0.00613]
# Train:  15%|█▌        | 14/91 [01:52<07:22,  5.75s/it, acc=0.983, loss=0.0114]
# Train:  16%|█▋        | 15/91 [01:52<09:21,  7.39s/it, acc=0.983, loss=0.0114]
# Train:  16%|█▋        | 15/91 [01:52<09:21,  7.39s/it, acc=0.984, loss=0.00454]
# Train:  18%|█▊        | 16/91 [01:52<06:31,  5.22s/it, acc=0.984, loss=0.00454]
# Train:  18%|█▊        | 16/91 [02:01<06:31,  5.22s/it, acc=0.985, loss=0.00884]
# Train:  19%|█▊        | 17/91 [02:01<07:52,  6.39s/it, acc=0.985, loss=0.00884]
# Train:  19%|█▊        | 17/91 [02:01<07:52,  6.39s/it, acc=0.986, loss=0.0072]
# Train:  20%|█▉        | 18/91 [02:01<05:30,  4.52s/it, acc=0.986, loss=0.0072]
# Train:  20%|█▉        | 18/91 [02:12<05:30,  4.52s/it, acc=0.987, loss=0.00548]
# Train:  21%|██        | 19/91 [02:12<07:40,  6.40s/it, acc=0.987, loss=0.00548]
# Train:  21%|██        | 19/91 [02:12<07:40,  6.40s/it, acc=0.988, loss=0.00863]Train step 20/91 | loss=0.0086 | acc=0.9875
#
# Train:  22%|██▏       | 20/91 [02:12<05:22,  4.54s/it, acc=0.988, loss=0.00863]
# Train:  22%|██▏       | 20/91 [02:27<05:22,  4.54s/it, acc=0.988, loss=0.0443]
# Train:  23%|██▎       | 21/91 [02:27<08:56,  7.67s/it, acc=0.988, loss=0.0443]
# Train:  23%|██▎       | 21/91 [02:27<08:56,  7.67s/it, acc=0.989, loss=0.00332]
# Train:  24%|██▍       | 22/91 [02:27<06:14,  5.42s/it, acc=0.989, loss=0.00332]
# Train:  24%|██▍       | 22/91 [02:40<06:14,  5.42s/it, acc=0.989, loss=0.00499]
# Train:  25%|██▌       | 23/91 [02:40<08:28,  7.48s/it, acc=0.989, loss=0.00499]
# Train:  25%|██▌       | 23/91 [02:40<08:28,  7.48s/it, acc=0.984, loss=0.205]
# Train:  26%|██▋       | 24/91 [02:40<05:54,  5.29s/it, acc=0.984, loss=0.205]
# Train:  26%|██▋       | 24/91 [02:55<05:54,  5.29s/it, acc=0.985, loss=0.00349]
# Train:  27%|██▋       | 25/91 [02:55<08:58,  8.16s/it, acc=0.985, loss=0.00349]
# Train:  27%|██▋       | 25/91 [02:55<08:58,  8.16s/it, acc=0.986, loss=0.00307]
# Train:  29%|██▊       | 26/91 [02:55<06:14,  5.76s/it, acc=0.986, loss=0.00307]
# Train:  29%|██▊       | 26/91 [03:11<06:14,  5.76s/it, acc=0.986, loss=0.0262]
# Train:  30%|██▉       | 27/91 [03:11<09:19,  8.74s/it, acc=0.986, loss=0.0262]
# Train:  30%|██▉       | 27/91 [03:11<09:19,  8.74s/it, acc=0.987, loss=0.0303]
# Train:  31%|███       | 28/91 [03:11<06:28,  6.17s/it, acc=0.987, loss=0.0303]
# Train:  31%|███       | 28/91 [03:22<06:28,  6.17s/it, acc=0.983, loss=0.127]
# Train:  32%|███▏      | 29/91 [03:22<08:02,  7.79s/it, acc=0.983, loss=0.127]
# Train:  32%|███▏      | 29/91 [03:23<08:02,  7.79s/it, acc=0.975, loss=0.87] Train step 30/91 | loss=0.8697 | acc=0.9750
#
# Train:  33%|███▎      | 30/91 [03:23<05:35,  5.51s/it, acc=0.975, loss=0.87]
# Train:  33%|███▎      | 30/91 [03:36<05:35,  5.51s/it, acc=0.976, loss=0.00289]
# Train:  34%|███▍      | 31/91 [03:36<08:01,  8.02s/it, acc=0.976, loss=0.00289]
# Train:  34%|███▍      | 31/91 [03:37<08:01,  8.02s/it, acc=0.977, loss=0.112]
# Train:  35%|███▌      | 32/91 [03:37<05:34,  5.67s/it, acc=0.977, loss=0.112]
# Train:  35%|███▌      | 32/91 [03:50<05:34,  5.67s/it, acc=0.977, loss=0.0062]
# Train:  36%|███▋      | 33/91 [03:50<07:45,  8.03s/it, acc=0.977, loss=0.0062]
# Train:  36%|███▋      | 33/91 [03:50<07:45,  8.03s/it, acc=0.978, loss=0.0474]
# Train:  37%|███▋      | 34/91 [03:50<05:23,  5.68s/it, acc=0.978, loss=0.0474]
# Train:  37%|███▋      | 34/91 [04:01<05:23,  5.68s/it, acc=0.968, loss=0.98]
# Train:  38%|███▊      | 35/91 [04:01<06:38,  7.11s/it, acc=0.968, loss=0.98]
# Train:  38%|███▊      | 35/91 [04:01<06:38,  7.11s/it, acc=0.962, loss=1.2]
# Train:  40%|███▉      | 36/91 [04:01<04:36,  5.03s/it, acc=0.962, loss=1.2]
# Train:  40%|███▉      | 36/91 [04:13<04:36,  5.03s/it, acc=0.953, loss=1.37]
# Train:  41%|████      | 37/91 [04:13<06:21,  7.06s/it, acc=0.953, loss=1.37]
# Train:  41%|████      | 37/91 [04:13<06:21,  7.06s/it, acc=0.951, loss=0.184]
# Train:  42%|████▏     | 38/91 [04:13<04:24,  5.00s/it, acc=0.951, loss=0.184]
# Train:  42%|████▏     | 38/91 [04:25<04:24,  5.00s/it, acc=0.952, loss=0.0101]
# Train:  43%|████▎     | 39/91 [04:25<06:05,  7.03s/it, acc=0.952, loss=0.0101]
# Train:  43%|████▎     | 39/91 [04:25<06:05,  7.03s/it, acc=0.95, loss=0.17]   Train step 40/91 | loss=0.1699 | acc=0.9500
#
# Train:  44%|████▍     | 40/91 [04:25<04:13,  4.98s/it, acc=0.95, loss=0.17]
# Train:  44%|████▍     | 40/91 [04:38<04:13,  4.98s/it, acc=0.948, loss=0.122]
# Train:  45%|████▌     | 41/91 [04:38<06:10,  7.42s/it, acc=0.948, loss=0.122]
# Train:  45%|████▌     | 41/91 [04:38<06:10,  7.42s/it, acc=0.949, loss=0.0341]
# Train:  46%|████▌     | 42/91 [04:38<04:17,  5.25s/it, acc=0.949, loss=0.0341]
# Train:  46%|████▌     | 42/91 [04:51<04:17,  5.25s/it, acc=0.945, loss=0.767]
# Train:  47%|████▋     | 43/91 [04:51<06:04,  7.59s/it, acc=0.945, loss=0.767]
# Train:  47%|████▋     | 43/91 [04:51<06:04,  7.59s/it, acc=0.94, loss=0.816]
# Train:  48%|████▊     | 44/91 [04:51<04:12,  5.37s/it, acc=0.94, loss=0.816]
# Train:  48%|████▊     | 44/91 [05:06<04:12,  5.37s/it, acc=0.942, loss=0.089]
# Train:  49%|████▉     | 45/91 [05:06<06:09,  8.04s/it, acc=0.942, loss=0.089]
# Train:  49%|████▉     | 45/91 [05:06<06:09,  8.04s/it, acc=0.943, loss=0.0566]
# Train:  51%|█████     | 46/91 [05:06<04:15,  5.69s/it, acc=0.943, loss=0.0566]
# Train:  51%|█████     | 46/91 [05:19<04:15,  5.69s/it, acc=0.944, loss=0.0317]
# Train:  52%|█████▏    | 47/91 [05:19<05:50,  7.96s/it, acc=0.944, loss=0.0317]
# Train:  52%|█████▏    | 47/91 [05:19<05:50,  7.96s/it, acc=0.945, loss=0.0172]
# Train:  53%|█████▎    | 48/91 [05:19<04:01,  5.62s/it, acc=0.945, loss=0.0172]
# Train:  53%|█████▎    | 48/91 [05:28<04:01,  5.62s/it, acc=0.944, loss=0.134]
# Train:  54%|█████▍    | 49/91 [05:28<04:30,  6.44s/it, acc=0.944, loss=0.134]
# Train:  54%|█████▍    | 49/91 [05:28<04:30,  6.44s/it, acc=0.945, loss=0.0997]Train step 50/91 | loss=0.0997 | acc=0.9450
#
# Train:  55%|█████▍    | 50/91 [05:28<03:07,  4.57s/it, acc=0.945, loss=0.0997]
# Train:  55%|█████▍    | 50/91 [05:44<03:07,  4.57s/it, acc=0.944, loss=0.219]
# Train:  56%|█████▌    | 51/91 [05:44<05:26,  8.16s/it, acc=0.944, loss=0.219]
# Train:  56%|█████▌    | 51/91 [05:45<05:26,  8.16s/it, acc=0.942, loss=0.275]
# Train:  57%|█████▋    | 52/91 [05:45<03:44,  5.77s/it, acc=0.942, loss=0.275]
# Train:  57%|█████▋    | 52/91 [05:59<03:44,  5.77s/it, acc=0.943, loss=0.0692]
# Train:  58%|█████▊    | 53/91 [05:59<05:18,  8.39s/it, acc=0.943, loss=0.0692]
# Train:  58%|█████▊    | 53/91 [05:59<05:18,  8.39s/it, acc=0.944, loss=0.213]
# Train:  59%|█████▉    | 54/91 [05:59<03:39,  5.93s/it, acc=0.944, loss=0.213]
# Train:  59%|█████▉    | 54/91 [06:14<03:39,  5.93s/it, acc=0.945, loss=0.0585]
# Train:  60%|██████    | 55/91 [06:14<05:09,  8.59s/it, acc=0.945, loss=0.0585]
# Train:  60%|██████    | 55/91 [06:14<05:09,  8.59s/it, acc=0.946, loss=0.0272]
# Train:  62%|██████▏   | 56/91 [06:14<03:32,  6.06s/it, acc=0.946, loss=0.0272]
# Train:  62%|██████▏   | 56/91 [06:25<03:32,  6.06s/it, acc=0.947, loss=0.0565]
# Train:  63%|██████▎   | 57/91 [06:25<04:09,  7.33s/it, acc=0.947, loss=0.0565]
# Train:  63%|██████▎   | 57/91 [06:25<04:09,  7.33s/it, acc=0.948, loss=0.0383]
# Train:  64%|██████▎   | 58/91 [06:25<02:51,  5.18s/it, acc=0.948, loss=0.0383]
# Train:  64%|██████▎   | 58/91 [06:33<02:51,  5.18s/it, acc=0.949, loss=0.0993]
# Train:  65%|██████▍   | 59/91 [06:33<03:15,  6.11s/it, acc=0.949, loss=0.0993]
# Train:  65%|██████▍   | 59/91 [06:33<03:15,  6.11s/it, acc=0.948, loss=0.272] Train step 60/91 | loss=0.2719 | acc=0.9479
#
# Train:  66%|██████▌   | 60/91 [06:33<02:14,  4.33s/it, acc=0.948, loss=0.272]
# Train:  66%|██████▌   | 60/91 [06:48<02:14,  4.33s/it, acc=0.949, loss=0.118]
# Train:  67%|██████▋   | 61/91 [06:48<03:44,  7.49s/it, acc=0.949, loss=0.118]
# Train:  67%|██████▋   | 61/91 [06:48<03:44,  7.49s/it, acc=0.95, loss=0.0173]
# Train:  68%|██████▊   | 62/91 [06:48<02:33,  5.29s/it, acc=0.95, loss=0.0173]
# Train:  68%|██████▊   | 62/91 [07:00<02:33,  5.29s/it, acc=0.95, loss=0.0271]
# Train:  69%|██████▉   | 63/91 [07:00<03:21,  7.18s/it, acc=0.95, loss=0.0271]
# Train:  69%|██████▉   | 63/91 [07:00<03:21,  7.18s/it, acc=0.951, loss=0.0905]
# Train:  70%|███████   | 64/91 [07:00<02:17,  5.09s/it, acc=0.951, loss=0.0905]
# Train:  70%|███████   | 64/91 [07:12<02:17,  5.09s/it, acc=0.952, loss=0.0429]
# Train:  71%|███████▏  | 65/91 [07:12<03:04,  7.09s/it, acc=0.952, loss=0.0429]
# Train:  71%|███████▏  | 65/91 [07:12<03:04,  7.09s/it, acc=0.953, loss=0.0759]
# Train:  73%|███████▎  | 66/91 [07:12<02:05,  5.02s/it, acc=0.953, loss=0.0759]
# Train:  73%|███████▎  | 66/91 [07:25<02:05,  5.02s/it, acc=0.953, loss=0.0147]
# Train:  74%|███████▎  | 67/91 [07:25<02:59,  7.46s/it, acc=0.953, loss=0.0147]
# Train:  74%|███████▎  | 67/91 [07:25<02:59,  7.46s/it, acc=0.954, loss=0.017]
# Train:  75%|███████▍  | 68/91 [07:25<02:01,  5.28s/it, acc=0.954, loss=0.017]
# Train:  75%|███████▍  | 68/91 [07:37<02:01,  5.28s/it, acc=0.955, loss=0.0237]
# Train:  76%|███████▌  | 69/91 [07:37<02:39,  7.25s/it, acc=0.955, loss=0.0237]
# Train:  76%|███████▌  | 69/91 [07:37<02:39,  7.25s/it, acc=0.955, loss=0.0232]Train step 70/91 | loss=0.0232 | acc=0.9554
#
# Train:  77%|███████▋  | 70/91 [07:37<01:47,  5.13s/it, acc=0.955, loss=0.0232]
# Train:  77%|███████▋  | 70/91 [07:50<01:47,  5.13s/it, acc=0.956, loss=0.0164]
# Train:  78%|███████▊  | 71/91 [07:50<02:25,  7.30s/it, acc=0.956, loss=0.0164]
# Train:  78%|███████▊  | 71/91 [07:50<02:25,  7.30s/it, acc=0.955, loss=0.126]
# Train:  79%|███████▉  | 72/91 [07:50<01:38,  5.16s/it, acc=0.955, loss=0.126]
# Train:  79%|███████▉  | 72/91 [08:03<01:38,  5.16s/it, acc=0.955, loss=0.0155]
# Train:  80%|████████  | 73/91 [08:03<02:16,  7.58s/it, acc=0.955, loss=0.0155]
# Train:  80%|████████  | 73/91 [08:03<02:16,  7.58s/it, acc=0.956, loss=0.0519]
# Train:  81%|████████▏ | 74/91 [08:03<01:31,  5.37s/it, acc=0.956, loss=0.0519]
# Train:  81%|████████▏ | 74/91 [08:17<01:31,  5.37s/it, acc=0.957, loss=0.0146]
# Train:  82%|████████▏ | 75/91 [08:17<02:07,  7.98s/it, acc=0.957, loss=0.0146]
# Train:  82%|████████▏ | 75/91 [08:18<02:07,  7.98s/it, acc=0.957, loss=0.0802]
# Train:  84%|████████▎ | 76/91 [08:18<01:24,  5.64s/it, acc=0.957, loss=0.0802]
# Train:  84%|████████▎ | 76/91 [08:29<01:24,  5.64s/it, acc=0.956, loss=0.171]
# Train:  85%|████████▍ | 77/91 [08:29<01:44,  7.45s/it, acc=0.956, loss=0.171]
# Train:  85%|████████▍ | 77/91 [08:29<01:44,  7.45s/it, acc=0.957, loss=0.00927]
# Train:  86%|████████▌ | 78/91 [08:29<01:08,  5.28s/it, acc=0.957, loss=0.00927]
# Train:  86%|████████▌ | 78/91 [08:46<01:08,  5.28s/it, acc=0.957, loss=0.0311]
# Train:  87%|████████▋ | 79/91 [08:46<01:42,  8.51s/it, acc=0.957, loss=0.0311]
# Train:  87%|████████▋ | 79/91 [08:46<01:42,  8.51s/it, acc=0.958, loss=0.00806]Train step 80/91 | loss=0.0081 | acc=0.9578
#
# Train:  88%|████████▊ | 80/91 [08:46<01:06,  6.02s/it, acc=0.958, loss=0.00806]
# Train:  88%|████████▊ | 80/91 [08:59<01:06,  6.02s/it, acc=0.958, loss=0.00385]
# Train:  89%|████████▉ | 81/91 [08:59<01:22,  8.21s/it, acc=0.958, loss=0.00385]
# Train:  89%|████████▉ | 81/91 [08:59<01:22,  8.21s/it, acc=0.959, loss=0.0145]
# Train:  90%|█████████ | 82/91 [08:59<00:52,  5.80s/it, acc=0.959, loss=0.0145]
# Train:  90%|█████████ | 82/91 [09:13<00:52,  5.80s/it, acc=0.959, loss=0.0117]
# Train:  91%|█████████ | 83/91 [09:13<01:05,  8.22s/it, acc=0.959, loss=0.0117]
# Train:  91%|█████████ | 83/91 [09:13<01:05,  8.22s/it, acc=0.96, loss=0.0153]
# Train:  92%|█████████▏| 84/91 [09:13<00:40,  5.81s/it, acc=0.96, loss=0.0153]
# Train:  92%|█████████▏| 84/91 [09:27<00:40,  5.81s/it, acc=0.96, loss=0.0102]
# Train:  93%|█████████▎| 85/91 [09:27<00:48,  8.13s/it, acc=0.96, loss=0.0102]
# Train:  93%|█████████▎| 85/91 [09:27<00:48,  8.13s/it, acc=0.961, loss=0.0105]
# Train:  95%|█████████▍| 86/91 [09:27<00:28,  5.75s/it, acc=0.961, loss=0.0105]
# Train:  95%|█████████▍| 86/91 [09:40<00:28,  5.75s/it, acc=0.961, loss=0.0046]
# Train:  96%|█████████▌| 87/91 [09:40<00:31,  7.92s/it, acc=0.961, loss=0.0046]
# Train:  96%|█████████▌| 87/91 [09:40<00:31,  7.92s/it, acc=0.962, loss=0.00658]
# Train:  97%|█████████▋| 88/91 [09:40<00:16,  5.60s/it, acc=0.962, loss=0.00658]
# Train:  97%|█████████▋| 88/91 [09:51<00:16,  5.60s/it, acc=0.961, loss=0.295]
# Train:  98%|█████████▊| 89/91 [09:51<00:14,  7.32s/it, acc=0.961, loss=0.295]
# Train:  98%|█████████▊| 89/91 [09:52<00:14,  7.32s/it, acc=0.96, loss=0.17]  Train step 90/91 | loss=0.1701 | acc=0.9597
#
# Train:  99%|█████████▉| 90/91 [09:52<00:05,  5.17s/it, acc=0.96, loss=0.17]
# Train:  99%|█████████▉| 90/91 [09:57<00:05,  5.17s/it, acc=0.96, loss=0.0151]Train step 91/91 | loss=0.0151 | acc=0.9601
#
# Train: 100%|██████████| 91/91 [09:57<00:00,  5.21s/it, acc=0.96, loss=0.0151]
#
#
# Val:   0%|          | 0/15 [00:00<?, ?it/s]Val step 1/15 | loss=0.0058 | acc=1.0000
#
# Val:   7%|▋         | 1/15 [00:15<03:30, 15.00s/it]
# Val:  13%|█▎        | 2/15 [00:16<01:33,  7.20s/it]
# Val:  20%|██        | 3/15 [00:30<02:01, 10.15s/it]
# Val:  27%|██▋       | 4/15 [00:30<01:08,  6.19s/it]
# Val:  33%|███▎      | 5/15 [00:40<01:16,  7.60s/it]
# Val:  40%|████      | 6/15 [00:42<00:51,  5.67s/it]
# Val:  47%|████▋     | 7/15 [00:52<00:56,  7.02s/it]
# Val:  53%|█████▎    | 8/15 [00:58<00:47,  6.75s/it]
# Val:  60%|██████    | 9/15 [01:08<00:47,  7.87s/it]Val step 10/15 | loss=0.0068 | acc=1.0000
#
# Val:  67%|██████▋   | 10/15 [01:15<00:37,  7.41s/it]
# Val:  73%|███████▎  | 11/15 [01:23<00:30,  7.63s/it]
# Val:  80%|████████  | 12/15 [01:28<00:20,  6.92s/it]
# Val:  87%|████████▋ | 13/15 [01:36<00:14,  7.30s/it]
# Val:  93%|█████████▎| 14/15 [01:42<00:06,  6.75s/it]Val step 15/15 | loss=0.0040 | acc=0.9833
#
# Val: 100%|██████████| 15/15 [01:46<00:00,  5.94s/it]
#
# Epoch 03/10 | Train Loss: 0.1216 | Train Acc: 0.9601 | Val Loss: 0.0464 | Val Acc: 0.9833
# ...
# Train:  64%|██████▎   | 58/91 [06:28<03:10,  5.76s/it, acc=1, loss=0.000302]
# Train:  64%|██████▎   | 58/91 [06:40<03:10,  5.76s/it, acc=1, loss=0.000201]
# Train:  65%|██████▍   | 59/91 [06:40<04:07,  7.73s/it, acc=1, loss=0.000201]
# Train:  65%|██████▍   | 59/91 [06:41<04:07,  7.73s/it, acc=1, loss=0.000306]Train step 60/91 | loss=0.0003 | acc=1.0000
#
# Train:  66%|██████▌   | 60/91 [06:41<02:49,  5.46s/it, acc=1, loss=0.000306]
# Train:  66%|██████▌   | 60/91 [06:52<02:49,  5.46s/it, acc=1, loss=0.000163]
# Train:  67%|██████▋   | 61/91 [06:52<03:39,  7.30s/it, acc=1, loss=0.000163]
# Train:  67%|██████▋   | 61/91 [06:56<03:39,  7.30s/it, acc=1, loss=0.000127]
# Train:  68%|██████▊   | 62/91 [06:56<03:04,  6.38s/it, acc=1, loss=0.000127]
# Train:  68%|██████▊   | 62/91 [07:09<03:04,  6.38s/it, acc=1, loss=0.000172]
# Train:  69%|██████▉   | 63/91 [07:09<03:49,  8.20s/it, acc=1, loss=0.000172]
# Train:  69%|██████▉   | 63/91 [07:09<03:49,  8.20s/it, acc=1, loss=0.000221]
# Train:  70%|███████   | 64/91 [07:09<02:36,  5.79s/it, acc=1, loss=0.000221]
# Train:  70%|███████   | 64/91 [07:21<02:36,  5.79s/it, acc=1, loss=0.000156]
# Train:  71%|███████▏  | 65/91 [07:21<03:15,  7.53s/it, acc=1, loss=0.000156]
# Train:  71%|███████▏  | 65/91 [07:21<03:15,  7.53s/it, acc=1, loss=0.000133]
# Train:  73%|███████▎  | 66/91 [07:21<02:13,  5.33s/it, acc=1, loss=0.000133]
# Train:  73%|███████▎  | 66/91 [07:34<02:13,  5.33s/it, acc=1, loss=0.000179]
# Train:  74%|███████▎  | 67/91 [07:34<03:02,  7.60s/it, acc=1, loss=0.000179]
# Train:  74%|███████▎  | 67/91 [07:35<03:02,  7.60s/it, acc=1, loss=0.000177]
# Train:  75%|███████▍  | 68/91 [07:35<02:12,  5.77s/it, acc=1, loss=0.000177]
# Train:  75%|███████▍  | 68/91 [07:47<02:12,  5.77s/it, acc=1, loss=0.000191]
# Train:  76%|███████▌  | 69/91 [07:47<02:45,  7.52s/it, acc=1, loss=0.000191]
# Train:  76%|███████▌  | 69/91 [07:50<02:45,  7.52s/it, acc=1, loss=0.000205]Train step 70/91 | loss=0.0002 | acc=1.0000
#
# Train:  77%|███████▋  | 70/91 [07:50<02:10,  6.22s/it, acc=1, loss=0.000205]
# Train:  77%|███████▋  | 70/91 [07:58<02:10,  6.22s/it, acc=1, loss=0.000148]
# Train:  78%|███████▊  | 71/91 [07:58<02:16,  6.83s/it, acc=1, loss=0.000148]
# Train:  78%|███████▊  | 71/91 [08:02<02:16,  6.83s/it, acc=1, loss=0.000172]
# Train:  79%|███████▉  | 72/91 [08:02<01:53,  5.97s/it, acc=1, loss=0.000172]
# Train:  79%|███████▉  | 72/91 [08:16<01:53,  5.97s/it, acc=1, loss=0.000108]
# Train:  80%|████████  | 73/91 [08:16<02:31,  8.44s/it, acc=1, loss=0.000108]
# Train:  80%|████████  | 73/91 [08:17<02:31,  8.44s/it, acc=1, loss=0.000201]
# Train:  81%|████████▏ | 74/91 [08:17<01:42,  6.01s/it, acc=1, loss=0.000201]
# Train:  81%|████████▏ | 74/91 [08:29<01:42,  6.01s/it, acc=1, loss=0.000316]
# Train:  82%|████████▏ | 75/91 [08:29<02:05,  7.87s/it, acc=1, loss=0.000316]
# Train:  82%|████████▏ | 75/91 [08:29<02:05,  7.87s/it, acc=1, loss=0.000222]
# Train:  84%|████████▎ | 76/91 [08:29<01:23,  5.57s/it, acc=1, loss=0.000222]
# Train:  84%|████████▎ | 76/91 [08:40<01:23,  5.57s/it, acc=1, loss=0.000238]
# Train:  85%|████████▍ | 77/91 [08:40<01:39,  7.08s/it, acc=1, loss=0.000238]
# Train:  85%|████████▍ | 77/91 [08:41<01:39,  7.08s/it, acc=1, loss=0.000183]
# Train:  86%|████████▌ | 78/91 [08:41<01:09,  5.36s/it, acc=1, loss=0.000183]
# Train:  86%|████████▌ | 78/91 [08:56<01:09,  5.36s/it, acc=1, loss=0.000103]
# Train:  87%|████████▋ | 79/91 [08:56<01:39,  8.26s/it, acc=1, loss=0.000103]
# Train:  87%|████████▋ | 79/91 [08:56<01:39,  8.26s/it, acc=1, loss=0.000176]Train step 80/91 | loss=0.0002 | acc=1.0000
#
# Train:  88%|████████▊ | 80/91 [08:56<01:04,  5.84s/it, acc=1, loss=0.000176]
# Train:  88%|████████▊ | 80/91 [09:05<01:04,  5.84s/it, acc=1, loss=0.000262]
# Train:  89%|████████▉ | 81/91 [09:05<01:08,  6.82s/it, acc=1, loss=0.000262]
# Train:  89%|████████▉ | 81/91 [09:06<01:08,  6.82s/it, acc=1, loss=0.000124]
# Train:  90%|█████████ | 82/91 [09:06<00:43,  4.83s/it, acc=1, loss=0.000124]
# Train:  90%|█████████ | 82/91 [09:21<00:43,  4.83s/it, acc=1, loss=0.000203]
# Train:  91%|█████████ | 83/91 [09:21<01:03,  7.92s/it, acc=1, loss=0.000203]
# Train:  91%|█████████ | 83/91 [09:21<01:03,  7.92s/it, acc=1, loss=0.000162]
# Train:  92%|█████████▏| 84/91 [09:21<00:39,  5.61s/it, acc=1, loss=0.000162]
# Train:  92%|█████████▏| 84/91 [09:33<00:39,  5.61s/it, acc=1, loss=0.000129]
# Train:  93%|█████████▎| 85/91 [09:33<00:45,  7.57s/it, acc=1, loss=0.000129]
# Train:  93%|█████████▎| 85/91 [09:33<00:45,  7.57s/it, acc=1, loss=0.000342]
# Train:  95%|█████████▍| 86/91 [09:33<00:26,  5.35s/it, acc=1, loss=0.000342]
# Train:  95%|█████████▍| 86/91 [09:46<00:26,  5.35s/it, acc=1, loss=0.00022]
# Train:  96%|█████████▌| 87/91 [09:46<00:29,  7.49s/it, acc=1, loss=0.00022]
# Train:  96%|█████████▌| 87/91 [09:46<00:29,  7.49s/it, acc=1, loss=0.000169]
# Train:  97%|█████████▋| 88/91 [09:46<00:15,  5.29s/it, acc=1, loss=0.000169]
# Train:  97%|█████████▋| 88/91 [09:52<00:15,  5.29s/it, acc=1, loss=0.00016]
# Train:  98%|█████████▊| 89/91 [09:52<00:11,  5.56s/it, acc=1, loss=0.00016]
# Train:  98%|█████████▊| 89/91 [09:52<00:11,  5.56s/it, acc=1, loss=0.000214]Train step 90/91 | loss=0.0002 | acc=1.0000
#
# Train:  99%|█████████▉| 90/91 [09:52<00:03,  3.95s/it, acc=1, loss=0.000214]
# Train:  99%|█████████▉| 90/91 [09:59<00:03,  3.95s/it, acc=1, loss=0.000223]Train step 91/91 | loss=0.0002 | acc=1.0000
#
# Train: 100%|██████████| 91/91 [09:59<00:00,  4.64s/it, acc=1, loss=0.000223]
#
#
# Val:   0%|          | 0/15 [00:00<?, ?it/s]Val step 1/15 | loss=0.0001 | acc=1.0000
#
# Val:   7%|▋         | 1/15 [00:14<03:21, 14.42s/it]
# Val:  13%|█▎        | 2/15 [00:17<01:39,  7.62s/it]
# Val:  20%|██        | 3/15 [00:30<01:59,  9.95s/it]
# Val:  27%|██▋       | 4/15 [00:30<01:06,  6.06s/it]
# Val:  33%|███▎      | 5/15 [00:40<01:14,  7.50s/it]
# Val:  40%|████      | 6/15 [00:43<00:54,  6.00s/it]
# Val:  47%|████▋     | 7/15 [00:51<00:55,  6.88s/it]
# Val:  53%|█████▎    | 8/15 [00:58<00:48,  6.88s/it]
# Val:  60%|██████    | 9/15 [01:08<00:46,  7.74s/it]Val step 10/15 | loss=0.0001 | acc=1.0000
#
# Val:  67%|██████▋   | 10/15 [01:15<00:37,  7.54s/it]
# Val:  73%|███████▎  | 11/15 [01:22<00:29,  7.46s/it]
# Val:  80%|████████  | 12/15 [01:29<00:21,  7.08s/it]
# Val:  87%|████████▋ | 13/15 [01:36<00:14,  7.07s/it]
# Val:  93%|█████████▎| 14/15 [01:42<00:06,  6.89s/it]Val step 15/15 | loss=0.0001 | acc=1.0000
#
# Val: 100%|██████████| 15/15 [01:45<00:00,  5.85s/it]
#
# Epoch 10/10 | Train Loss: 0.0002 | Train Acc: 1.0000 | Val Loss: 0.0002 | Val Acc: 1.0000
# Best validation accuracy: 1.0000
#
# Export train_embeddings:   0%|          | 0/91 [00:00<?, ?it/s]
# Export train_embeddings:   1%|          | 1/91 [00:18<27:10, 18.11s/it]
# Export train_embeddings:   2%|▏         | 2/91 [00:18<11:17,  7.61s/it]
# Export train_embeddings:   3%|▎         | 3/91 [00:28<12:35,  8.58s/it]
# Export train_embeddings:   4%|▍         | 4/91 [00:28<07:40,  5.29s/it]
# Export train_embeddings:   5%|▌         | 5/91 [00:43<12:25,  8.67s/it]
# Export train_embeddings:   7%|▋         | 6/91 [00:43<08:13,  5.81s/it]
# Export train_embeddings:   8%|▊         | 7/91 [00:59<12:46,  9.12s/it]
# Export train_embeddings:   9%|▉         | 8/91 [00:59<08:42,  6.30s/it]
# Export train_embeddings:  10%|▉         | 9/91 [01:11<10:55,  7.99s/it]
# Export train_embeddings:  11%|█         | 10/91 [01:11<07:33,  5.60s/it]
# Export train_embeddings:  12%|█▏        | 11/91 [01:20<08:59,  6.74s/it]
# Export train_embeddings:  13%|█▎        | 12/91 [01:21<06:16,  4.77s/it]
# Export train_embeddings:  14%|█▍        | 13/91 [01:34<09:32,  7.34s/it]
# Export train_embeddings:  15%|█▌        | 14/91 [01:34<06:40,  5.20s/it]
# Export train_embeddings:  16%|█▋        | 15/91 [01:46<09:02,  7.14s/it]
# Export train_embeddings:  18%|█▊        | 16/91 [01:46<06:24,  5.13s/it]
# Export train_embeddings:  19%|█▊        | 17/91 [01:58<08:47,  7.13s/it]
# Export train_embeddings:  20%|█▉        | 18/91 [02:00<06:40,  5.49s/it]
# Export train_embeddings:  21%|██        | 19/91 [02:13<09:22,  7.81s/it]
# Export train_embeddings:  22%|██▏       | 20/91 [02:13<06:33,  5.54s/it]
# Export train_embeddings:  23%|██▎       | 21/91 [02:23<07:58,  6.83s/it]
# Export train_embeddings:  24%|██▍       | 22/91 [02:25<06:14,  5.43s/it]
# Export train_embeddings:  25%|██▌       | 23/91 [02:37<08:21,  7.37s/it]
# Export train_embeddings:  26%|██▋       | 24/91 [02:37<05:50,  5.23s/it]
# Export train_embeddings:  27%|██▋       | 25/91 [02:49<07:57,  7.24s/it]
# Export train_embeddings:  29%|██▊       | 26/91 [02:49<05:34,  5.14s/it]
# Export train_embeddings:  30%|██▉       | 27/91 [03:03<08:03,  7.56s/it]
# Export train_embeddings:  31%|███       | 28/91 [03:03<05:38,  5.38s/it]
# Export train_embeddings:  32%|███▏      | 29/91 [03:15<07:32,  7.30s/it]
# Export train_embeddings:  33%|███▎      | 30/91 [03:15<05:16,  5.19s/it]
# Export train_embeddings:  34%|███▍      | 31/91 [03:26<06:59,  6.99s/it]
# Export train_embeddings:  35%|███▌      | 32/91 [03:26<04:53,  4.97s/it]
# Export train_embeddings:  36%|███▋      | 33/91 [03:37<06:29,  6.72s/it]
# Export train_embeddings:  37%|███▋      | 34/91 [03:39<05:05,  5.35s/it]
# Export train_embeddings:  38%|███▊      | 35/91 [03:51<06:49,  7.32s/it]
# Export train_embeddings:  40%|███▉      | 36/91 [03:51<04:45,  5.20s/it]
# Export train_embeddings:  41%|████      | 37/91 [04:02<06:12,  6.90s/it]
# Export train_embeddings:  42%|████▏     | 38/91 [04:04<04:42,  5.33s/it]
# Export train_embeddings:  43%|████▎     | 39/91 [04:13<05:40,  6.55s/it]
# Export train_embeddings:  44%|████▍     | 40/91 [04:21<05:45,  6.77s/it]
# Export train_embeddings:  45%|████▌     | 41/91 [04:28<05:49,  7.00s/it]
# Export train_embeddings:  46%|████▌     | 42/91 [04:33<05:17,  6.48s/it]
# Export train_embeddings:  47%|████▋     | 43/91 [04:42<05:42,  7.13s/it]
# Export train_embeddings:  48%|████▊     | 44/91 [04:47<05:09,  6.58s/it]
# Export train_embeddings:  49%|████▉     | 45/91 [04:55<05:10,  6.75s/it]
# Export train_embeddings:  51%|█████     | 46/91 [04:57<04:00,  5.34s/it]
# Export train_embeddings:  52%|█████▏    | 47/91 [05:10<05:38,  7.69s/it]
# Export train_embeddings:  53%|█████▎    | 48/91 [05:10<03:54,  5.46s/it]
# Export train_embeddings:  54%|█████▍    | 49/91 [05:25<05:46,  8.25s/it]
# Export train_embeddings:  55%|█████▍    | 50/91 [05:25<03:59,  5.85s/it]
# Export train_embeddings:  56%|█████▌    | 51/91 [05:36<04:53,  7.33s/it]
# Export train_embeddings:  57%|█████▋    | 52/91 [05:37<03:33,  5.47s/it]
# Export train_embeddings:  58%|█████▊    | 53/91 [05:48<04:31,  7.14s/it]
# Export train_embeddings:  59%|█████▉    | 54/91 [05:51<03:32,  5.75s/it]
# Export train_embeddings:  60%|██████    | 55/91 [06:04<04:46,  7.95s/it]
# Export train_embeddings:  62%|██████▏   | 56/91 [06:04<03:17,  5.64s/it]
# Export train_embeddings:  63%|██████▎   | 57/91 [06:19<04:44,  8.38s/it]
# Export train_embeddings:  64%|██████▎   | 58/91 [06:19<03:15,  5.94s/it]
# Export train_embeddings:  65%|██████▍   | 59/91 [06:29<03:53,  7.29s/it]
# Export train_embeddings:  66%|██████▌   | 60/91 [06:30<02:40,  5.18s/it]
# Export train_embeddings:  67%|██████▋   | 61/91 [06:46<04:17,  8.58s/it]
# Export train_embeddings:  68%|██████▊   | 62/91 [06:46<02:56,  6.08s/it]
# Export train_embeddings:  69%|██████▉   | 63/91 [07:01<04:05,  8.78s/it]
# Export train_embeddings:  70%|███████   | 64/91 [07:02<02:48,  6.22s/it]
# Export train_embeddings:  71%|███████▏  | 65/91 [07:16<03:42,  8.55s/it]
# Export train_embeddings:  73%|███████▎  | 66/91 [07:16<02:31,  6.06s/it]
# Export train_embeddings:  74%|███████▎  | 67/91 [07:29<03:12,  8.04s/it]
# Export train_embeddings:  75%|███████▍  | 68/91 [07:29<02:11,  5.70s/it]
# Export train_embeddings:  76%|███████▌  | 69/91 [07:41<02:48,  7.66s/it]
# Export train_embeddings:  77%|███████▋  | 70/91 [07:41<01:54,  5.44s/it]
# Export train_embeddings:  78%|███████▊  | 71/91 [07:58<02:57,  8.89s/it]
# Export train_embeddings:  79%|███████▉  | 72/91 [07:58<01:59,  6.30s/it]
# Export train_embeddings:  80%|████████  | 73/91 [08:12<02:34,  8.57s/it]
# Export train_embeddings:  81%|████████▏ | 74/91 [08:13<01:43,  6.07s/it]
# Export train_embeddings:  82%|████████▏ | 75/91 [08:27<02:18,  8.64s/it]
# Export train_embeddings:  84%|████████▎ | 76/91 [08:27<01:31,  6.12s/it]
# Export train_embeddings:  85%|████████▍ | 77/91 [08:38<01:43,  7.41s/it]
# Export train_embeddings:  86%|████████▌ | 78/91 [08:38<01:08,  5.26s/it]
# Export train_embeddings:  87%|████████▋ | 79/91 [08:53<01:36,  8.00s/it]
# Export train_embeddings:  88%|████████▊ | 80/91 [08:53<01:02,  5.67s/it]
# Export train_embeddings:  89%|████████▉ | 81/91 [09:03<01:10,  7.08s/it]
# Export train_embeddings:  90%|█████████ | 82/91 [09:03<00:45,  5.03s/it]
# Export train_embeddings:  91%|█████████ | 83/91 [09:17<01:01,  7.67s/it]
# Export train_embeddings:  92%|█████████▏| 84/91 [09:17<00:38,  5.44s/it]
# Export train_embeddings:  93%|█████████▎| 85/91 [09:31<00:47,  7.93s/it]
# Export train_embeddings:  95%|█████████▍| 86/91 [09:31<00:28,  5.63s/it]
# Export train_embeddings:  96%|█████████▌| 87/91 [09:41<00:26,  6.73s/it]
# Export train_embeddings:  97%|█████████▋| 88/91 [09:41<00:14,  4.79s/it]
# Export train_embeddings:  98%|█████████▊| 89/91 [09:52<00:13,  6.74s/it]
# Export train_embeddings:  99%|█████████▉| 90/91 [09:53<00:04,  4.79s/it]
# Export train_embeddings: 100%|██████████| 91/91 [10:01<00:00,  5.77s/it]
#
#
# Export val_embeddings:   0%|          | 0/15 [00:00<?, ?it/s]
# Export val_embeddings:   7%|▋         | 1/15 [00:14<03:26, 14.75s/it]
# Export val_embeddings:  13%|█▎        | 2/15 [00:16<01:35,  7.36s/it]
# Export val_embeddings:  20%|██        | 3/15 [00:30<02:03, 10.32s/it]
# Export val_embeddings:  27%|██▋       | 4/15 [00:31<01:09,  6.35s/it]
# Export val_embeddings:  33%|███▎      | 5/15 [00:41<01:16,  7.66s/it]
# Export val_embeddings:  40%|████      | 6/15 [00:43<00:53,  5.93s/it]
# Export val_embeddings:  47%|████▋     | 7/15 [00:52<00:55,  6.96s/it]
# Export val_embeddings:  53%|█████▎    | 8/15 [00:59<00:49,  7.01s/it]
# Export val_embeddings:  60%|██████    | 9/15 [01:08<00:45,  7.58s/it]
# Export val_embeddings:  67%|██████▋   | 10/15 [01:16<00:38,  7.72s/it]
# Export val_embeddings:  73%|███████▎  | 11/15 [01:23<00:29,  7.30s/it]
# Export val_embeddings:  80%|████████  | 12/15 [01:29<00:21,  7.21s/it]
# Export val_embeddings:  87%|████████▋ | 13/15 [01:36<00:13,  6.98s/it]
# Export val_embeddings:  93%|█████████▎| 14/15 [01:43<00:06,  6.96s/it]
# Export val_embeddings: 100%|██████████| 15/15 [01:46<00:00,  5.83s/it]
#
#
# Export test_embeddings:   0%|          | 0/16 [00:00<?, ?it/s]
# Export test_embeddings:   6%|▋         | 1/16 [00:15<03:51, 15.43s/it]
# Export test_embeddings:  12%|█▎        | 2/16 [00:15<01:31,  6.50s/it]
# Export test_embeddings:  19%|█▉        | 3/16 [00:30<02:12, 10.19s/it]
# Export test_embeddings:  25%|██▌       | 4/16 [00:30<01:15,  6.27s/it]
# Export test_embeddings:  31%|███▏      | 5/16 [00:40<01:25,  7.74s/it]
# Export test_embeddings:  38%|███▊      | 6/16 [00:42<00:57,  5.72s/it]
# Export test_embeddings:  44%|████▍     | 7/16 [00:53<01:07,  7.49s/it]
# Export test_embeddings:  50%|█████     | 8/16 [00:56<00:48,  6.11s/it]
# Export test_embeddings:  56%|█████▋    | 9/16 [01:06<00:49,  7.10s/it]
# Export test_embeddings:  62%|██████▎   | 10/16 [01:06<00:29,  4.98s/it]
# Export test_embeddings:  69%|██████▉   | 11/16 [01:20<00:39,  7.81s/it]
# Export test_embeddings:  75%|███████▌  | 12/16 [01:20<00:22,  5.51s/it]
# Export test_embeddings:  81%|████████▏ | 13/16 [01:32<00:21,  7.26s/it]
# Export test_embeddings:  88%|████████▊ | 14/16 [01:32<00:10,  5.14s/it]
# Export test_embeddings:  94%|█████████▍| 15/16 [01:43<00:06,  6.90s/it]
# Export test_embeddings: 100%|██████████| 16/16 [01:45<00:00,  5.40s/it]
#
# Saved metrics to: /kaggle/working/outputs/metrics.pt
# Command finished in 7863.8s with exit code 0

# %% [markdown]
# ## 6. Evaluate Results with Metrics
#
# Inspect generated outputs and report best validation accuracy.

# %%
out_dir = Path(CONFIG["output_dir"])
print("Output dir exists:", out_dir.exists())
if out_dir.exists():
    for p in sorted(out_dir.glob("*")):
        print(" -", p.name)

metrics_path = out_dir / "metrics.pt"
if metrics_path.exists():
    metrics = torch.load(metrics_path, map_location="cpu")
    print("\nBest validation accuracy:", metrics.get("best_val_acc"))
    print("Split sizes:", {k: metrics.get(k) for k in ["num_train", "num_val", "num_test"]})
else:
    print("metrics.pt not found")
# Out:
# Output dir exists: True
#  - convnext_tiny_deepfake_best.pt
#  - metrics.pt
#  - test_embeddings.pt
#  - train_embeddings.pt
#  - val_embeddings.pt
#
# Best validation accuracy: 1.0
# Split sizes: {'num_train': 726, 'num_val': 120, 'num_test': 124}

# %% [markdown]
# ## 7. Save Outputs and Reusable Artifacts
#
# Zip model checkpoint, embeddings, and metrics so they can be downloaded from Kaggle output.

# %%
def zip_directory(source_dir: Path, zip_path: Path) -> Path:
    source_dir = Path(source_dir)
    zip_path = Path(zip_path)
    if not source_dir.exists():
        raise FileNotFoundError(f"Source directory not found: {source_dir}")
    if zip_path.exists():
        zip_path.unlink()
    archive_base = zip_path.with_suffix("")
    shutil.make_archive(str(archive_base), "zip", root_dir=source_dir.parent, base_dir=source_dir.name)
    return zip_path


zip_path = Path(CONFIG["working_dir"]) / "mobilevit_outputs.zip"
if out_dir.exists():
    zip_directory(out_dir, zip_path)
    print("Created zip:", zip_path)
else:
    print("Output directory not found; run training cell first.")
# Out:
# Created zip: /kaggle/working/mobilevit_outputs.zip

# %% [markdown]
# ---
#
# # Wav2Vec2-Base Audio Deepfake Detection
#
# This section trains a frozen Wav2Vec2-Base backbone with a trainable classification head on extracted audio from the same video dataset.
#
# ## Setup Audio Config
#
# Free-tier mode is enabled by default to keep the pipeline within Kaggle session limits. Set FREE_TIER_MODE=False for full training.

# %%
AUDIO_CONFIG = {
    "dataset_root": CONFIG["dataset_root"],
    "working_dir": CONFIG["working_dir"],
    "script_name": "train_wav2vec2_audio_deepfake.py",
    "output_dir": Path(CONFIG["working_dir"]) / "outputs_audio",
    "epochs": 12,
    "batch_size": 12,
    "lr": 1e-4,
    "weight_decay": 1e-2,
    "num_workers": 2,
    "ffmpeg_timeout": 45,
    "force_cpu": False,
    "train_ratio": 0.75,
    "val_ratio": 0.125,
    "max_train_samples": 0,
    "max_val_samples": 0,
    "max_test_samples": 0,
    "force_retrain": False,
}

print("Audio training config:")
print(json.dumps({k: str(v) if isinstance(v, Path) else v for k, v in AUDIO_CONFIG.items()}, indent=2))
# Out:
# Audio training config:
# {
#   "dataset_root": "/kaggle/working/sampled_uniform_970_videos",
#   "working_dir": "/kaggle/working",
#   "script_name": "train_wav2vec2_audio_deepfake.py",
#   "output_dir": "/kaggle/working/outputs_audio",
#   "epochs": 12,
#   "batch_size": 12,
#   "lr": 0.0001,
#   "weight_decay": 0.01,
#   "num_workers": 2,
#   "ffmpeg_timeout": 45,
#   "force_cpu": false,
#   "train_ratio": 0.75,
#   "val_ratio": 0.125,
#   "max_train_samples": 0,
#   "max_val_samples": 0,
#   "max_test_samples": 0,
#   "force_retrain": false
# }

# %%
audio_working_script = Path(AUDIO_CONFIG["working_dir"]) / AUDIO_CONFIG["script_name"]

audio_script_candidates = list(Path("/kaggle/input").rglob(AUDIO_CONFIG["script_name"]))
if audio_script_candidates:
    latest_script = max(audio_script_candidates, key=lambda p: p.stat().st_mtime)
    shutil.copy2(latest_script, audio_working_script)
    print("Refreshed audio script from:", latest_script)
elif not audio_working_script.exists():
    raise FileNotFoundError(f"{AUDIO_CONFIG['script_name']} not found in /kaggle/input or /kaggle/working")

print("Audio training script path:", audio_working_script)
print("Script exists:", audio_working_script.exists())
# Out:
# Refreshed audio script from: /kaggle/input/datasets/mahirashab/essential-scripts/train_wav2vec2_audio_deepfake.py
# Audio training script path: /kaggle/working/train_wav2vec2_audio_deepfake.py
# Script exists: True

# %%
# Install ffmpeg for audio extraction (required for audio training)
# !apt-get update && apt-get install -y ffmpeg > /dev/null 2>&1
print("ffmpeg installed.")
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [95.6 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:9 https://cli.github.com/packages stable/main amd64 Packages [356 B]
# Get:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,646 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:12 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,955 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [77.8 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [7,084 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,295 kB]
# Hit:17 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:18 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [10.2 MB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [7,355 kB]
# Hit:20 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [86.4 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,602 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [4,294 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [35.6 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [82.8 kB]
# Get:26 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [38.9 kB]
# Get:27 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [3,020 kB]
# Fetched 42.3 MB in 3s (14.8 MB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# ffmpeg installed.

# %%
audio_done = (Path(AUDIO_CONFIG["output_dir"]) / "train_embeddings.pt").exists() and (Path(AUDIO_CONFIG["output_dir"]) / "metrics.pt").exists()
if audio_done and not AUDIO_CONFIG.get("force_retrain", False):
    print("Audio artifacts already found. Skipping training cell.")
else:
    audio_cmd = [
        "python", "-u", "/kaggle/working/train_wav2vec2_audio_deepfake.py",
        "--dataset-root", str(AUDIO_CONFIG["dataset_root"]),
        "--output-dir", str(AUDIO_CONFIG["output_dir"]),
        "--epochs", str(AUDIO_CONFIG["epochs"]),
        "--batch-size", str(AUDIO_CONFIG["batch_size"]),
        "--lr", str(AUDIO_CONFIG["lr"]),
        "--weight-decay", str(AUDIO_CONFIG["weight_decay"]),
        "--num-workers", str(AUDIO_CONFIG["num_workers"]),
        "--ffmpeg-timeout", str(AUDIO_CONFIG["ffmpeg_timeout"]),
        "--train-ratio", str(AUDIO_CONFIG["train_ratio"]),
        "--val-ratio", str(AUDIO_CONFIG["val_ratio"]),
        "--max-train-samples", str(AUDIO_CONFIG["max_train_samples"]),
        "--max-val-samples", str(AUDIO_CONFIG["max_val_samples"]),
        "--max-test-samples", str(AUDIO_CONFIG["max_test_samples"]),
    ]
    if AUDIO_CONFIG.get("force_cpu", False):
        audio_cmd.append("--force-cpu")

    run_streaming_command(audio_cmd)
# Out:
# Running: python -u /kaggle/working/train_wav2vec2_audio_deepfake.py --dataset-root /kaggle/working/sampled_uniform_970_videos --output-dir /kaggle/working/outputs_audio --epochs 12 --batch-size 12 --lr 0.0001 --weight-decay 0.01 --num-workers 2 --ffmpeg-timeout 45 --train-ratio 0.75 --val-ratio 0.125 --max-train-samples 0 --max-val-samples 0 --max-test-samples 0
# Using device: cuda
# Using dataset root: /kaggle/working/sampled_uniform_970_videos
# Total videos: 970
# Split sizes -> train: 726, val: 120, test: 124
# Label counts (0=real audio [FR/RR], 1=fake audio [FF/RF]): train=[363, 363], val=[60, 60], test=[62, 62]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# Loading weights:   0%|          | 0/211 [00:00<?, ?it/s]
# Loading weights:   0%|          | 1/211 [00:00<00:00, 12122.27it/s, Materializing param=encoder.layer_norm.bias]
# Loading weights:   0%|          | 1/211 [00:00<00:00, 4328.49it/s, Materializing param=encoder.layer_norm.bias]
# Loading weights:   1%|          | 2/211 [00:00<00:00, 3739.91it/s, Materializing param=encoder.layer_norm.weight]
# Loading weights:   1%|          | 2/211 [00:00<00:00, 3243.85it/s, Materializing param=encoder.layer_norm.weight]
# Loading weights:   1%|▏         | 3/211 [00:00<00:00, 3656.76it/s, Materializing param=encoder.layers.0.attention.k_proj.bias]
# Loading weights:   1%|▏         | 3/211 [00:00<00:00, 2275.80it/s, Materializing param=encoder.layers.0.attention.k_proj.bias]
# Loading weights:   2%|▏         | 4/211 [00:00<00:00, 1758.62it/s, Materializing param=encoder.layers.0.attention.k_proj.weight]
# Loading weights:   2%|▏         | 4/211 [00:00<00:00, 1677.05it/s, Materializing param=encoder.layers.0.attention.k_proj.weight]
# Loading weights:   2%|▏         | 5/211 [00:00<00:00, 1908.93it/s, Materializing param=encoder.layers.0.attention.out_proj.bias]
# Loading weights:   2%|▏         | 5/211 [00:00<00:00, 1838.32it/s, Materializing param=encoder.layers.0.attention.out_proj.bias]
# Loading weights:   3%|▎         | 6/211 [00:00<00:00, 1699.02it/s, Materializing param=encoder.layers.0.attention.out_proj.weight]
# Loading weights:   3%|▎         | 6/211 [00:00<00:00, 1646.01it/s, Materializing param=encoder.layers.0.attention.out_proj.weight]
# Loading weights:   3%|▎         | 7/211 [00:00<00:00, 1811.46it/s, Materializing param=encoder.layers.0.attention.q_proj.bias]
# Loading weights:   3%|▎         | 7/211 [00:00<00:00, 1603.15it/s, Materializing param=encoder.layers.0.attention.q_proj.bias]
# Loading weights:   4%|▍         | 8/211 [00:00<00:00, 1163.51it/s, Materializing param=encoder.layers.0.attention.q_proj.weight]
# Loading weights:   4%|▍         | 8/211 [00:00<00:00, 1144.69it/s, Materializing param=encoder.layers.0.attention.q_proj.weight]
# Loading weights:   4%|▍         | 9/211 [00:00<00:00, 1173.34it/s, Materializing param=encoder.layers.0.attention.v_proj.bias]
# Loading weights:   4%|▍         | 9/211 [00:00<00:00, 1158.29it/s, Materializing param=encoder.layers.0.attention.v_proj.bias]
# Loading weights:   5%|▍         | 10/211 [00:00<00:00, 1254.05it/s, Materializing param=encoder.layers.0.attention.v_proj.weight]
# Loading weights:   5%|▍         | 10/211 [00:00<00:00, 1238.46it/s, Materializing param=encoder.layers.0.attention.v_proj.weight]
# Loading weights:   5%|▌         | 11/211 [00:00<00:00, 1321.12it/s, Materializing param=encoder.layers.0.feed_forward.intermediate_dense.bias]
# Loading weights:   5%|▌         | 11/211 [00:00<00:00, 1196.97it/s, Materializing param=encoder.layers.0.feed_forward.intermediate_dense.bias]
# Loading weights:   6%|▌         | 12/211 [00:00<00:00, 1208.91it/s, Materializing param=encoder.layers.0.feed_forward.intermediate_dense.weight]
# Loading weights:   6%|▌         | 12/211 [00:00<00:00, 1196.01it/s, Materializing param=encoder.layers.0.feed_forward.intermediate_dense.weight]
# Loading weights:   6%|▌         | 13/211 [00:00<00:00, 1163.32it/s, Materializing param=encoder.layers.0.feed_forward.output_dense.bias]
# Loading weights:   6%|▌         | 13/211 [00:00<00:00, 1135.15it/s, Materializing param=encoder.layers.0.feed_forward.output_dense.bias]
# Loading weights:   7%|▋         | 14/211 [00:00<00:00, 1154.50it/s, Materializing param=encoder.layers.0.feed_forward.output_dense.weight]
# Loading weights:   7%|▋         | 14/211 [00:00<00:00, 1143.46it/s, Materializing param=encoder.layers.0.feed_forward.output_dense.weight]
# Loading weights:   7%|▋         | 15/211 [00:00<00:00, 1210.24it/s, Materializing param=encoder.layers.0.final_layer_norm.bias]
# Loading weights:   7%|▋         | 15/211 [00:00<00:00, 1204.06it/s, Materializing param=encoder.layers.0.final_layer_norm.bias]
# Loading weights:   8%|▊         | 16/211 [00:00<00:00, 1273.65it/s, Materializing param=encoder.layers.0.final_layer_norm.weight]
# Loading weights:   8%|▊         | 16/211 [00:00<00:00, 1268.02it/s, Materializing param=encoder.layers.0.final_layer_norm.weight]
# Loading weights:   8%|▊         | 17/211 [00:00<00:00, 1337.27it/s, Materializing param=encoder.layers.0.layer_norm.bias]
# Loading weights:   8%|▊         | 17/211 [00:00<00:00, 1331.77it/s, Materializing param=encoder.layers.0.layer_norm.bias]
# Loading weights:   9%|▊         | 18/211 [00:00<00:00, 1400.07it/s, Materializing param=encoder.layers.0.layer_norm.weight]
# Loading weights:   9%|▊         | 18/211 [00:00<00:00, 1394.72it/s, Materializing param=encoder.layers.0.layer_norm.weight]
# Loading weights:   9%|▉         | 19/211 [00:00<00:00, 1462.40it/s, Materializing param=encoder.layers.1.attention.k_proj.bias]
# Loading weights:   9%|▉         | 19/211 [00:00<00:00, 1456.91it/s, Materializing param=encoder.layers.1.attention.k_proj.bias]
# Loading weights:   9%|▉         | 20/211 [00:00<00:00, 1522.93it/s, Materializing param=encoder.layers.1.attention.k_proj.weight]
# Loading weights:   9%|▉         | 20/211 [00:00<00:00, 1517.09it/s, Materializing param=encoder.layers.1.attention.k_proj.weight]
# Loading weights:  10%|▉         | 21/211 [00:00<00:00, 1572.50it/s, Materializing param=encoder.layers.1.attention.out_proj.bias]
# Loading weights:  10%|▉         | 21/211 [00:00<00:00, 1564.82it/s, Materializing param=encoder.layers.1.attention.out_proj.bias]
# Loading weights:  10%|█         | 22/211 [00:00<00:00, 1627.53it/s, Materializing param=encoder.layers.1.attention.out_proj.weight]
# Loading weights:  10%|█         | 22/211 [00:00<00:00, 1621.39it/s, Materializing param=encoder.layers.1.attention.out_proj.weight]
# Loading weights:  11%|█         | 23/211 [00:00<00:00, 1683.61it/s, Materializing param=encoder.layers.1.attention.q_proj.bias]
# Loading weights:  11%|█         | 23/211 [00:00<00:00, 1677.52it/s, Materializing param=encoder.layers.1.attention.q_proj.bias]
# Loading weights:  11%|█▏        | 24/211 [00:00<00:00, 1738.96it/s, Materializing param=encoder.layers.1.attention.q_proj.weight]
# Loading weights:  11%|█▏        | 24/211 [00:00<00:00, 1732.80it/s, Materializing param=encoder.layers.1.attention.q_proj.weight]
# Loading weights:  12%|█▏        | 25/211 [00:00<00:00, 1793.39it/s, Materializing param=encoder.layers.1.attention.v_proj.bias]
# Loading weights:  12%|█▏        | 25/211 [00:00<00:00, 1787.12it/s, Materializing param=encoder.layers.1.attention.v_proj.bias]
# Loading weights:  12%|█▏        | 26/211 [00:00<00:00, 1846.77it/s, Materializing param=encoder.layers.1.attention.v_proj.weight]
# Loading weights:  12%|█▏        | 26/211 [00:00<00:00, 1840.26it/s, Materializing param=encoder.layers.1.attention.v_proj.weight]
# Loading weights:  13%|█▎        | 27/211 [00:00<00:00, 1896.60it/s, Materializing param=encoder.layers.1.feed_forward.intermediate_dense.bias]
# Loading weights:  13%|█▎        | 27/211 [00:00<00:00, 1889.11it/s, Materializing param=encoder.layers.1.feed_forward.intermediate_dense.bias]
# Loading weights:  13%|█▎        | 28/211 [00:00<00:00, 1944.80it/s, Materializing param=encoder.layers.1.feed_forward.intermediate_dense.weight]
# Loading weights:  13%|█▎        | 28/211 [00:00<00:00, 1937.67it/s, Materializing param=encoder.layers.1.feed_forward.intermediate_dense.weight]
# Loading weights:  14%|█▎        | 29/211 [00:00<00:00, 1993.69it/s, Materializing param=encoder.layers.1.feed_forward.output_dense.bias]
# Loading weights:  14%|█▎        | 29/211 [00:00<00:00, 1986.33it/s, Materializing param=encoder.layers.1.feed_forward.output_dense.bias]
# Loading weights:  14%|█▍        | 30/211 [00:00<00:00, 2041.59it/s, Materializing param=encoder.layers.1.feed_forward.output_dense.weight]
# Loading weights:  14%|█▍        | 30/211 [00:00<00:00, 2034.56it/s, Materializing param=encoder.layers.1.feed_forward.output_dense.weight]
# Loading weights:  15%|█▍        | 31/211 [00:00<00:00, 2089.50it/s, Materializing param=encoder.layers.1.final_layer_norm.bias]
# Loading weights:  15%|█▍        | 31/211 [00:00<00:00, 2082.47it/s, Materializing param=encoder.layers.1.final_layer_norm.bias]
# Loading weights:  15%|█▌        | 32/211 [00:00<00:00, 2137.05it/s, Materializing param=encoder.layers.1.final_layer_norm.weight]
# Loading weights:  15%|█▌        | 32/211 [00:00<00:00, 2130.10it/s, Materializing param=encoder.layers.1.final_layer_norm.weight]
# Loading weights:  16%|█▌        | 33/211 [00:00<00:00, 2183.88it/s, Materializing param=encoder.layers.1.layer_norm.bias]
# Loading weights:  16%|█▌        | 33/211 [00:00<00:00, 2176.84it/s, Materializing param=encoder.layers.1.layer_norm.bias]
# Loading weights:  16%|█▌        | 34/211 [00:00<00:00, 2219.90it/s, Materializing param=encoder.layers.1.layer_norm.weight]
# Loading weights:  16%|█▌        | 34/211 [00:00<00:00, 2210.47it/s, Materializing param=encoder.layers.1.layer_norm.weight]
# Loading weights:  17%|█▋        | 35/211 [00:00<00:00, 2261.50it/s, Materializing param=encoder.layers.2.attention.k_proj.bias]
# Loading weights:  17%|█▋        | 35/211 [00:00<00:00, 2254.34it/s, Materializing param=encoder.layers.2.attention.k_proj.bias]
# Loading weights:  17%|█▋        | 36/211 [00:00<00:00, 2304.56it/s, Materializing param=encoder.layers.2.attention.k_proj.weight]
# Loading weights:  17%|█▋        | 36/211 [00:00<00:00, 2297.23it/s, Materializing param=encoder.layers.2.attention.k_proj.weight]
# Loading weights:  18%|█▊        | 37/211 [00:00<00:00, 2346.16it/s, Materializing param=encoder.layers.2.attention.out_proj.bias]
# Loading weights:  18%|█▊        | 37/211 [00:00<00:00, 2338.98it/s, Materializing param=encoder.layers.2.attention.out_proj.bias]
# Loading weights:  18%|█▊        | 38/211 [00:00<00:00, 2388.77it/s, Materializing param=encoder.layers.2.attention.out_proj.weight]
# Loading weights:  18%|█▊        | 38/211 [00:00<00:00, 2381.35it/s, Materializing param=encoder.layers.2.attention.out_proj.weight]
# Loading weights:  18%|█▊        | 39/211 [00:00<00:00, 2430.36it/s, Materializing param=encoder.layers.2.attention.q_proj.bias]
# Loading weights:  18%|█▊        | 39/211 [00:00<00:00, 2423.02it/s, Materializing param=encoder.layers.2.attention.q_proj.bias]
# Loading weights:  19%|█▉        | 40/211 [00:00<00:00, 2471.74it/s, Materializing param=encoder.layers.2.attention.q_proj.weight]
# Loading weights:  19%|█▉        | 40/211 [00:00<00:00, 2462.13it/s, Materializing param=encoder.layers.2.attention.q_proj.weight]
# Loading weights:  19%|█▉        | 41/211 [00:00<00:00, 2509.36it/s, Materializing param=encoder.layers.2.attention.v_proj.bias]
# Loading weights:  19%|█▉        | 41/211 [00:00<00:00, 2500.86it/s, Materializing param=encoder.layers.2.attention.v_proj.bias]
# Loading weights:  20%|█▉        | 42/211 [00:00<00:00, 2547.96it/s, Materializing param=encoder.layers.2.attention.v_proj.weight]
# Loading weights:  20%|█▉        | 42/211 [00:00<00:00, 2540.46it/s, Materializing param=encoder.layers.2.attention.v_proj.weight]
# Loading weights:  20%|██        | 43/211 [00:00<00:00, 2587.15it/s, Materializing param=encoder.layers.2.feed_forward.intermediate_dense.bias]
# Loading weights:  20%|██        | 43/211 [00:00<00:00, 2579.04it/s, Materializing param=encoder.layers.2.feed_forward.intermediate_dense.bias]
# Loading weights:  21%|██        | 44/211 [00:00<00:00, 2624.72it/s, Materializing param=encoder.layers.2.feed_forward.intermediate_dense.weight]
# Loading weights:  21%|██        | 44/211 [00:00<00:00, 2616.79it/s, Materializing param=encoder.layers.2.feed_forward.intermediate_dense.weight]
# Loading weights:  21%|██▏       | 45/211 [00:00<00:00, 2662.19it/s, Materializing param=encoder.layers.2.feed_forward.output_dense.bias]
# Loading weights:  21%|██▏       | 45/211 [00:00<00:00, 2654.40it/s, Materializing param=encoder.layers.2.feed_forward.output_dense.bias]
# Loading weights:  22%|██▏       | 46/211 [00:00<00:00, 2699.49it/s, Materializing param=encoder.layers.2.feed_forward.output_dense.weight]
# Loading weights:  22%|██▏       | 46/211 [00:00<00:00, 2691.47it/s, Materializing param=encoder.layers.2.feed_forward.output_dense.weight]
# Loading weights:  22%|██▏       | 47/211 [00:00<00:00, 2735.37it/s, Materializing param=encoder.layers.2.final_layer_norm.bias]
# Loading weights:  22%|██▏       | 47/211 [00:00<00:00, 2725.31it/s, Materializing param=encoder.layers.2.final_layer_norm.bias]
# Loading weights:  23%|██▎       | 48/211 [00:00<00:00, 2768.86it/s, Materializing param=encoder.layers.2.final_layer_norm.weight]
# Loading weights:  23%|██▎       | 48/211 [00:00<00:00, 2760.13it/s, Materializing param=encoder.layers.2.final_layer_norm.weight]
# Loading weights:  23%|██▎       | 49/211 [00:00<00:00, 2803.45it/s, Materializing param=encoder.layers.2.layer_norm.bias]
# Loading weights:  23%|██▎       | 49/211 [00:00<00:00, 2795.63it/s, Materializing param=encoder.layers.2.layer_norm.bias]
# Loading weights:  24%|██▎       | 50/211 [00:00<00:00, 2838.59it/s, Materializing param=encoder.layers.2.layer_norm.weight]
# Loading weights:  24%|██▎       | 50/211 [00:00<00:00, 2830.89it/s, Materializing param=encoder.layers.2.layer_norm.weight]
# Loading weights:  24%|██▍       | 51/211 [00:00<00:00, 2873.89it/s, Materializing param=encoder.layers.3.attention.k_proj.bias]
# Loading weights:  24%|██▍       | 51/211 [00:00<00:00, 2866.11it/s, Materializing param=encoder.layers.3.attention.k_proj.bias]
# Loading weights:  25%|██▍       | 52/211 [00:00<00:00, 2907.86it/s, Materializing param=encoder.layers.3.attention.k_proj.weight]
# Loading weights:  25%|██▍       | 52/211 [00:00<00:00, 2899.97it/s, Materializing param=encoder.layers.3.attention.k_proj.weight]
# Loading weights:  25%|██▌       | 53/211 [00:00<00:00, 2941.58it/s, Materializing param=encoder.layers.3.attention.out_proj.bias]
# Loading weights:  25%|██▌       | 53/211 [00:00<00:00, 2933.66it/s, Materializing param=encoder.layers.3.attention.out_proj.bias]
# Loading weights:  26%|██▌       | 54/211 [00:00<00:00, 2974.92it/s, Materializing param=encoder.layers.3.attention.out_proj.weight]
# Loading weights:  26%|██▌       | 54/211 [00:00<00:00, 2961.23it/s, Materializing param=encoder.layers.3.attention.out_proj.weight]
# Loading weights:  26%|██▌       | 55/211 [00:00<00:00, 2993.52it/s, Materializing param=encoder.layers.3.attention.q_proj.bias]
# Loading weights:  26%|██▌       | 55/211 [00:00<00:00, 2984.88it/s, Materializing param=encoder.layers.3.attention.q_proj.bias]
# Loading weights:  27%|██▋       | 56/211 [00:00<00:00, 3024.01it/s, Materializing param=encoder.layers.3.attention.q_proj.weight]
# Loading weights:  27%|██▋       | 56/211 [00:00<00:00, 3015.97it/s, Materializing param=encoder.layers.3.attention.q_proj.weight]
# Loading weights:  27%|██▋       | 57/211 [00:00<00:00, 3055.12it/s, Materializing param=encoder.layers.3.attention.v_proj.bias]
# Loading weights:  27%|██▋       | 57/211 [00:00<00:00, 3047.25it/s, Materializing param=encoder.layers.3.attention.v_proj.bias]
# Loading weights:  27%|██▋       | 58/211 [00:00<00:00, 3086.20it/s, Materializing param=encoder.layers.3.attention.v_proj.weight]
# Loading weights:  27%|██▋       | 58/211 [00:00<00:00, 3078.23it/s, Materializing param=encoder.layers.3.attention.v_proj.weight]
# Loading weights:  28%|██▊       | 59/211 [00:00<00:00, 3116.79it/s, Materializing param=encoder.layers.3.feed_forward.intermediate_dense.bias]
# Loading weights:  28%|██▊       | 59/211 [00:00<00:00, 3108.53it/s, Materializing param=encoder.layers.3.feed_forward.intermediate_dense.bias]
# Loading weights:  28%|██▊       | 60/211 [00:00<00:00, 3146.36it/s, Materializing param=encoder.layers.3.feed_forward.intermediate_dense.weight]
# Loading weights:  28%|██▊       | 60/211 [00:00<00:00, 3138.00it/s, Materializing param=encoder.layers.3.feed_forward.intermediate_dense.weight]
# Loading weights:  29%|██▉       | 61/211 [00:00<00:00, 3172.81it/s, Materializing param=encoder.layers.3.feed_forward.output_dense.bias]
# Loading weights:  29%|██▉       | 61/211 [00:00<00:00, 3163.95it/s, Materializing param=encoder.layers.3.feed_forward.output_dense.bias]
# Loading weights:  29%|██▉       | 62/211 [00:00<00:00, 3199.40it/s, Materializing param=encoder.layers.3.feed_forward.output_dense.weight]
# Loading weights:  29%|██▉       | 62/211 [00:00<00:00, 3191.11it/s, Materializing param=encoder.layers.3.feed_forward.output_dense.weight]
# Loading weights:  30%|██▉       | 63/211 [00:00<00:00, 3227.33it/s, Materializing param=encoder.layers.3.final_layer_norm.bias]
# Loading weights:  30%|██▉       | 63/211 [00:00<00:00, 3219.27it/s, Materializing param=encoder.layers.3.final_layer_norm.bias]
# Loading weights:  30%|███       | 64/211 [00:00<00:00, 3256.09it/s, Materializing param=encoder.layers.3.final_layer_norm.weight]
# Loading weights:  30%|███       | 64/211 [00:00<00:00, 3248.05it/s, Materializing param=encoder.layers.3.final_layer_norm.weight]
# Loading weights:  31%|███       | 65/211 [00:00<00:00, 3284.74it/s, Materializing param=encoder.layers.3.layer_norm.bias]
# Loading weights:  31%|███       | 65/211 [00:00<00:00, 3276.92it/s, Materializing param=encoder.layers.3.layer_norm.bias]
# Loading weights:  31%|███▏      | 66/211 [00:00<00:00, 3313.51it/s, Materializing param=encoder.layers.3.layer_norm.weight]
# Loading weights:  31%|███▏      | 66/211 [00:00<00:00, 3305.64it/s, Materializing param=encoder.layers.3.layer_norm.weight]
# Loading weights:  32%|███▏      | 67/211 [00:00<00:00, 3341.80it/s, Materializing param=encoder.layers.4.attention.k_proj.bias]
# Loading weights:  32%|███▏      | 67/211 [00:00<00:00, 3333.91it/s, Materializing param=encoder.layers.4.attention.k_proj.bias]
# Loading weights:  32%|███▏      | 68/211 [00:00<00:00, 3369.04it/s, Materializing param=encoder.layers.4.attention.k_proj.weight]
# Loading weights:  32%|███▏      | 68/211 [00:00<00:00, 3352.13it/s, Materializing param=encoder.layers.4.attention.k_proj.weight]
# Loading weights:  33%|███▎      | 69/211 [00:00<00:00, 3381.95it/s, Materializing param=encoder.layers.4.attention.out_proj.bias]
# Loading weights:  33%|███▎      | 69/211 [00:00<00:00, 3373.51it/s, Materializing param=encoder.layers.4.attention.out_proj.bias]
# Loading weights:  33%|███▎      | 70/211 [00:00<00:00, 3407.47it/s, Materializing param=encoder.layers.4.attention.out_proj.weight]
# Loading weights:  33%|███▎      | 70/211 [00:00<00:00, 3399.15it/s, Materializing param=encoder.layers.4.attention.out_proj.weight]
# Loading weights:  34%|███▎      | 71/211 [00:00<00:00, 3433.08it/s, Materializing param=encoder.layers.4.attention.q_proj.bias]
# Loading weights:  34%|███▎      | 71/211 [00:00<00:00, 3425.06it/s, Materializing param=encoder.layers.4.attention.q_proj.bias]
# Loading weights:  34%|███▍      | 72/211 [00:00<00:00, 3458.74it/s, Materializing param=encoder.layers.4.attention.q_proj.weight]
# Loading weights:  34%|███▍      | 72/211 [00:00<00:00, 3450.72it/s, Materializing param=encoder.layers.4.attention.q_proj.weight]
# Loading weights:  35%|███▍      | 73/211 [00:00<00:00, 3484.08it/s, Materializing param=encoder.layers.4.attention.v_proj.bias]
# Loading weights:  35%|███▍      | 73/211 [00:00<00:00, 3476.09it/s, Materializing param=encoder.layers.4.attention.v_proj.bias]
# Loading weights:  35%|███▌      | 74/211 [00:00<00:00, 3509.08it/s, Materializing param=encoder.layers.4.attention.v_proj.weight]
# Loading weights:  35%|███▌      | 74/211 [00:00<00:00, 3501.09it/s, Materializing param=encoder.layers.4.attention.v_proj.weight]
# Loading weights:  36%|███▌      | 75/211 [00:00<00:00, 3531.51it/s, Materializing param=encoder.layers.4.feed_forward.intermediate_dense.bias]
# Loading weights:  36%|███▌      | 75/211 [00:00<00:00, 3522.73it/s, Materializing param=encoder.layers.4.feed_forward.intermediate_dense.bias]
# Loading weights:  36%|███▌      | 76/211 [00:00<00:00, 3553.07it/s, Materializing param=encoder.layers.4.feed_forward.intermediate_dense.weight]
# Loading weights:  36%|███▌      | 76/211 [00:00<00:00, 3544.69it/s, Materializing param=encoder.layers.4.feed_forward.intermediate_dense.weight]
# Loading weights:  36%|███▋      | 77/211 [00:00<00:00, 3576.26it/s, Materializing param=encoder.layers.4.feed_forward.output_dense.bias]
# Loading weights:  36%|███▋      | 77/211 [00:00<00:00, 3568.04it/s, Materializing param=encoder.layers.4.feed_forward.output_dense.bias]
# Loading weights:  37%|███▋      | 78/211 [00:00<00:00, 3599.71it/s, Materializing param=encoder.layers.4.feed_forward.output_dense.weight]
# Loading weights:  37%|███▋      | 78/211 [00:00<00:00, 3591.45it/s, Materializing param=encoder.layers.4.feed_forward.output_dense.weight]
# Loading weights:  37%|███▋      | 79/211 [00:00<00:00, 3622.90it/s, Materializing param=encoder.layers.4.final_layer_norm.bias]
# Loading weights:  37%|███▋      | 79/211 [00:00<00:00, 3614.75it/s, Materializing param=encoder.layers.4.final_layer_norm.bias]
# Loading weights:  38%|███▊      | 80/211 [00:00<00:00, 3646.03it/s, Materializing param=encoder.layers.4.final_layer_norm.weight]
# Loading weights:  38%|███▊      | 80/211 [00:00<00:00, 3637.97it/s, Materializing param=encoder.layers.4.final_layer_norm.weight]
# Loading weights:  38%|███▊      | 81/211 [00:00<00:00, 3669.44it/s, Materializing param=encoder.layers.4.layer_norm.bias]
# Loading weights:  38%|███▊      | 81/211 [00:00<00:00, 3661.53it/s, Materializing param=encoder.layers.4.layer_norm.bias]
# Loading weights:  39%|███▉      | 82/211 [00:00<00:00, 3686.87it/s, Materializing param=encoder.layers.4.layer_norm.weight]
# Loading weights:  39%|███▉      | 82/211 [00:00<00:00, 3677.96it/s, Materializing param=encoder.layers.4.layer_norm.weight]
# Loading weights:  39%|███▉      | 83/211 [00:00<00:00, 3706.40it/s, Materializing param=encoder.layers.5.attention.k_proj.bias]
# Loading weights:  39%|███▉      | 83/211 [00:00<00:00, 3697.74it/s, Materializing param=encoder.layers.5.attention.k_proj.bias]
# Loading weights:  40%|███▉      | 84/211 [00:00<00:00, 3725.04it/s, Materializing param=encoder.layers.5.attention.k_proj.weight]
# Loading weights:  40%|███▉      | 84/211 [00:00<00:00, 3713.93it/s, Materializing param=encoder.layers.5.attention.k_proj.weight]
# Loading weights:  40%|████      | 85/211 [00:00<00:00, 3742.67it/s, Materializing param=encoder.layers.5.attention.out_proj.bias]
# Loading weights:  40%|████      | 85/211 [00:00<00:00, 3734.25it/s, Materializing param=encoder.layers.5.attention.out_proj.bias]
# Loading weights:  41%|████      | 86/211 [00:00<00:00, 3762.73it/s, Materializing param=encoder.layers.5.attention.out_proj.weight]
# Loading weights:  41%|████      | 86/211 [00:00<00:00, 3754.07it/s, Materializing param=encoder.layers.5.attention.out_proj.weight]
# Loading weights:  41%|████      | 87/211 [00:00<00:00, 3782.26it/s, Materializing param=encoder.layers.5.attention.q_proj.bias]
# Loading weights:  41%|████      | 87/211 [00:00<00:00, 3773.73it/s, Materializing param=encoder.layers.5.attention.q_proj.bias]
# Loading weights:  42%|████▏     | 88/211 [00:00<00:00, 3801.81it/s, Materializing param=encoder.layers.5.attention.q_proj.weight]
# Loading weights:  42%|████▏     | 88/211 [00:00<00:00, 3784.85it/s, Materializing param=encoder.layers.5.attention.q_proj.weight]
# Loading weights:  42%|████▏     | 89/211 [00:00<00:00, 3806.20it/s, Materializing param=encoder.layers.5.attention.v_proj.bias]
# Loading weights:  42%|████▏     | 89/211 [00:00<00:00, 3797.68it/s, Materializing param=encoder.layers.5.attention.v_proj.bias]
# Loading weights:  43%|████▎     | 90/211 [00:00<00:00, 3825.21it/s, Materializing param=encoder.layers.5.attention.v_proj.weight]
# Loading weights:  43%|████▎     | 90/211 [00:00<00:00, 3817.32it/s, Materializing param=encoder.layers.5.attention.v_proj.weight]
# Loading weights:  43%|████▎     | 91/211 [00:00<00:00, 3844.54it/s, Materializing param=encoder.layers.5.feed_forward.intermediate_dense.bias]
# Loading weights:  43%|████▎     | 91/211 [00:00<00:00, 3836.34it/s, Materializing param=encoder.layers.5.feed_forward.intermediate_dense.bias]
# Loading weights:  44%|████▎     | 92/211 [00:00<00:00, 3864.17it/s, Materializing param=encoder.layers.5.feed_forward.intermediate_dense.weight]
# Loading weights:  44%|████▎     | 92/211 [00:00<00:00, 3856.06it/s, Materializing param=encoder.layers.5.feed_forward.intermediate_dense.weight]
# Loading weights:  44%|████▍     | 93/211 [00:00<00:00, 3883.54it/s, Materializing param=encoder.layers.5.feed_forward.output_dense.bias]
# Loading weights:  44%|████▍     | 93/211 [00:00<00:00, 3875.43it/s, Materializing param=encoder.layers.5.feed_forward.output_dense.bias]
# Loading weights:  45%|████▍     | 94/211 [00:00<00:00, 3902.95it/s, Materializing param=encoder.layers.5.feed_forward.output_dense.weight]
# Loading weights:  45%|████▍     | 94/211 [00:00<00:00, 3894.93it/s, Materializing param=encoder.layers.5.feed_forward.output_dense.weight]
# Loading weights:  45%|████▌     | 95/211 [00:00<00:00, 3919.68it/s, Materializing param=encoder.layers.5.final_layer_norm.bias]
# Loading weights:  45%|████▌     | 95/211 [00:00<00:00, 3911.33it/s, Materializing param=encoder.layers.5.final_layer_norm.bias]
# Loading weights:  45%|████▌     | 96/211 [00:00<00:00, 3934.16it/s, Materializing param=encoder.layers.5.final_layer_norm.weight]
# Loading weights:  45%|████▌     | 96/211 [00:00<00:00, 3925.87it/s, Materializing param=encoder.layers.5.final_layer_norm.weight]
# Loading weights:  46%|████▌     | 97/211 [00:00<00:00, 3952.55it/s, Materializing param=encoder.layers.5.layer_norm.bias]
# Loading weights:  46%|████▌     | 97/211 [00:00<00:00, 3944.81it/s, Materializing param=encoder.layers.5.layer_norm.bias]
# Loading weights:  46%|████▋     | 98/211 [00:00<00:00, 3971.88it/s, Materializing param=encoder.layers.5.layer_norm.weight]
# Loading weights:  46%|████▋     | 98/211 [00:00<00:00, 3964.14it/s, Materializing param=encoder.layers.5.layer_norm.weight]
# Loading weights:  47%|████▋     | 99/211 [00:00<00:00, 3990.81it/s, Materializing param=encoder.layers.6.attention.k_proj.bias]
# Loading weights:  47%|████▋     | 99/211 [00:00<00:00, 3983.00it/s, Materializing param=encoder.layers.6.attention.k_proj.bias]
# Loading weights:  47%|████▋     | 100/211 [00:00<00:00, 4008.85it/s, Materializing param=encoder.layers.6.attention.k_proj.weight]
# Loading weights:  47%|████▋     | 100/211 [00:00<00:00, 4000.90it/s, Materializing param=encoder.layers.6.attention.k_proj.weight]
# Loading weights:  48%|████▊     | 101/211 [00:00<00:00, 4026.51it/s, Materializing param=encoder.layers.6.attention.out_proj.bias]
# Loading weights:  48%|████▊     | 101/211 [00:00<00:00, 4018.56it/s, Materializing param=encoder.layers.6.attention.out_proj.bias]
# Loading weights:  48%|████▊     | 102/211 [00:00<00:00, 4041.67it/s, Materializing param=encoder.layers.6.attention.out_proj.weight]
# Loading weights:  48%|████▊     | 102/211 [00:00<00:00, 4033.44it/s, Materializing param=encoder.layers.6.attention.out_proj.weight]
# Loading weights:  49%|████▉     | 103/211 [00:00<00:00, 4057.57it/s, Materializing param=encoder.layers.6.attention.q_proj.bias]
# Loading weights:  49%|████▉     | 103/211 [00:00<00:00, 4049.73it/s, Materializing param=encoder.layers.6.attention.q_proj.bias]
# Loading weights:  49%|████▉     | 104/211 [00:00<00:00, 4074.99it/s, Materializing param=encoder.layers.6.attention.q_proj.weight]
# Loading weights:  49%|████▉     | 104/211 [00:00<00:00, 4067.28it/s, Materializing param=encoder.layers.6.attention.q_proj.weight]
# Loading weights:  50%|████▉     | 105/211 [00:00<00:00, 4092.54it/s, Materializing param=encoder.layers.6.attention.v_proj.bias]
# Loading weights:  50%|████▉     | 105/211 [00:00<00:00, 4084.64it/s, Materializing param=encoder.layers.6.attention.v_proj.bias]
# Loading weights:  50%|█████     | 106/211 [00:00<00:00, 4109.71it/s, Materializing param=encoder.layers.6.attention.v_proj.weight]
# Loading weights:  50%|█████     | 106/211 [00:00<00:00, 4101.59it/s, Materializing param=encoder.layers.6.attention.v_proj.weight]
# Loading weights:  51%|█████     | 107/211 [00:00<00:00, 4126.39it/s, Materializing param=encoder.layers.6.feed_forward.intermediate_dense.bias]
# Loading weights:  51%|█████     | 107/211 [00:00<00:00, 4117.99it/s, Materializing param=encoder.layers.6.feed_forward.intermediate_dense.bias]
# Loading weights:  51%|█████     | 108/211 [00:00<00:00, 4141.84it/s, Materializing param=encoder.layers.6.feed_forward.intermediate_dense.weight]
# Loading weights:  51%|█████     | 108/211 [00:00<00:00, 4133.71it/s, Materializing param=encoder.layers.6.feed_forward.intermediate_dense.weight]
# Loading weights:  52%|█████▏    | 109/211 [00:00<00:00, 4155.61it/s, Materializing param=encoder.layers.6.feed_forward.output_dense.bias]
# Loading weights:  52%|█████▏    | 109/211 [00:00<00:00, 4147.28it/s, Materializing param=encoder.layers.6.feed_forward.output_dense.bias]
# Loading weights:  52%|█████▏    | 110/211 [00:00<00:00, 4169.51it/s, Materializing param=encoder.layers.6.feed_forward.output_dense.weight]
# Loading weights:  52%|█████▏    | 110/211 [00:00<00:00, 4161.50it/s, Materializing param=encoder.layers.6.feed_forward.output_dense.weight]
# Loading weights:  53%|█████▎    | 111/211 [00:00<00:00, 4185.03it/s, Materializing param=encoder.layers.6.final_layer_norm.bias]
# Loading weights:  53%|█████▎    | 111/211 [00:00<00:00, 4177.33it/s, Materializing param=encoder.layers.6.final_layer_norm.bias]
# Loading weights:  53%|█████▎    | 112/211 [00:00<00:00, 4201.28it/s, Materializing param=encoder.layers.6.final_layer_norm.weight]
# Loading weights:  53%|█████▎    | 112/211 [00:00<00:00, 4193.56it/s, Materializing param=encoder.layers.6.final_layer_norm.weight]
# Loading weights:  54%|█████▎    | 113/211 [00:00<00:00, 4217.52it/s, Materializing param=encoder.layers.6.layer_norm.bias]
# Loading weights:  54%|█████▎    | 113/211 [00:00<00:00, 4209.99it/s, Materializing param=encoder.layers.6.layer_norm.bias]
# Loading weights:  54%|█████▍    | 114/211 [00:00<00:00, 4233.78it/s, Materializing param=encoder.layers.6.layer_norm.weight]
# Loading weights:  54%|█████▍    | 114/211 [00:00<00:00, 4214.97it/s, Materializing param=encoder.layers.6.layer_norm.weight]
# Loading weights:  55%|█████▍    | 115/211 [00:00<00:00, 4233.77it/s, Materializing param=encoder.layers.7.attention.k_proj.bias]
# Loading weights:  55%|█████▍    | 115/211 [00:00<00:00, 4223.95it/s, Materializing param=encoder.layers.7.attention.k_proj.bias]
# Loading weights:  55%|█████▍    | 116/211 [00:00<00:00, 4245.40it/s, Materializing param=encoder.layers.7.attention.k_proj.weight]
# Loading weights:  55%|█████▍    | 116/211 [00:00<00:00, 4236.78it/s, Materializing param=encoder.layers.7.attention.k_proj.weight]
# Loading weights:  55%|█████▌    | 117/211 [00:00<00:00, 4259.21it/s, Materializing param=encoder.layers.7.attention.out_proj.bias]
# Loading weights:  55%|█████▌    | 117/211 [00:00<00:00, 4251.68it/s, Materializing param=encoder.layers.7.attention.out_proj.bias]
# Loading weights:  56%|█████▌    | 118/211 [00:00<00:00, 4274.39it/s, Materializing param=encoder.layers.7.attention.out_proj.weight]
# Loading weights:  56%|█████▌    | 118/211 [00:00<00:00, 4266.69it/s, Materializing param=encoder.layers.7.attention.out_proj.weight]
# Loading weights:  56%|█████▋    | 119/211 [00:00<00:00, 4289.35it/s, Materializing param=encoder.layers.7.attention.q_proj.bias]
# Loading weights:  56%|█████▋    | 119/211 [00:00<00:00, 4281.81it/s, Materializing param=encoder.layers.7.attention.q_proj.bias]
# Loading weights:  57%|█████▋    | 120/211 [00:00<00:00, 4304.43it/s, Materializing param=encoder.layers.7.attention.q_proj.weight]
# Loading weights:  57%|█████▋    | 120/211 [00:00<00:00, 4296.93it/s, Materializing param=encoder.layers.7.attention.q_proj.weight]
# Loading weights:  57%|█████▋    | 121/211 [00:00<00:00, 4319.20it/s, Materializing param=encoder.layers.7.attention.v_proj.bias]
# Loading weights:  57%|█████▋    | 121/211 [00:00<00:00, 4311.64it/s, Materializing param=encoder.layers.7.attention.v_proj.bias]
# Loading weights:  58%|█████▊    | 122/211 [00:00<00:00, 4333.69it/s, Materializing param=encoder.layers.7.attention.v_proj.weight]
# Loading weights:  58%|█████▊    | 122/211 [00:00<00:00, 4326.29it/s, Materializing param=encoder.layers.7.attention.v_proj.weight]
# Loading weights:  58%|█████▊    | 123/211 [00:00<00:00, 4333.40it/s, Materializing param=encoder.layers.7.feed_forward.intermediate_dense.bias]
# Loading weights:  58%|█████▊    | 123/211 [00:00<00:00, 4325.00it/s, Materializing param=encoder.layers.7.feed_forward.intermediate_dense.bias]
# Loading weights:  59%|█████▉    | 124/211 [00:00<00:00, 4345.30it/s, Materializing param=encoder.layers.7.feed_forward.intermediate_dense.weight]
# Loading weights:  59%|█████▉    | 124/211 [00:00<00:00, 4337.19it/s, Materializing param=encoder.layers.7.feed_forward.intermediate_dense.weight]
# Loading weights:  59%|█████▉    | 125/211 [00:00<00:00, 4358.03it/s, Materializing param=encoder.layers.7.feed_forward.output_dense.bias]
# Loading weights:  59%|█████▉    | 125/211 [00:00<00:00, 4350.32it/s, Materializing param=encoder.layers.7.feed_forward.output_dense.bias]
# Loading weights:  60%|█████▉    | 126/211 [00:00<00:00, 4371.45it/s, Materializing param=encoder.layers.7.feed_forward.output_dense.weight]
# Loading weights:  60%|█████▉    | 126/211 [00:00<00:00, 4363.76it/s, Materializing param=encoder.layers.7.feed_forward.output_dense.weight]
# Loading weights:  60%|██████    | 127/211 [00:00<00:00, 4384.67it/s, Materializing param=encoder.layers.7.final_layer_norm.bias]
# Loading weights:  60%|██████    | 127/211 [00:00<00:00, 4377.29it/s, Materializing param=encoder.layers.7.final_layer_norm.bias]
# Loading weights:  61%|██████    | 128/211 [00:00<00:00, 4398.45it/s, Materializing param=encoder.layers.7.final_layer_norm.weight]
# Loading weights:  61%|██████    | 128/211 [00:00<00:00, 4391.08it/s, Materializing param=encoder.layers.7.final_layer_norm.weight]
# Loading weights:  61%|██████    | 129/211 [00:00<00:00, 4410.13it/s, Materializing param=encoder.layers.7.layer_norm.bias]
# Loading weights:  61%|██████    | 129/211 [00:00<00:00, 4402.48it/s, Materializing param=encoder.layers.7.layer_norm.bias]
# Loading weights:  62%|██████▏   | 130/211 [00:00<00:00, 4422.51it/s, Materializing param=encoder.layers.7.layer_norm.weight]
# Loading weights:  62%|██████▏   | 130/211 [00:00<00:00, 4415.20it/s, Materializing param=encoder.layers.7.layer_norm.weight]
# Loading weights:  62%|██████▏   | 131/211 [00:00<00:00, 4436.30it/s, Materializing param=encoder.layers.8.attention.k_proj.bias]
# Loading weights:  62%|██████▏   | 131/211 [00:00<00:00, 4429.11it/s, Materializing param=encoder.layers.8.attention.k_proj.bias]
# Loading weights:  63%|██████▎   | 132/211 [00:00<00:00, 4449.76it/s, Materializing param=encoder.layers.8.attention.k_proj.weight]
# Loading weights:  63%|██████▎   | 132/211 [00:00<00:00, 4442.37it/s, Materializing param=encoder.layers.8.attention.k_proj.weight]
# Loading weights:  63%|██████▎   | 133/211 [00:00<00:00, 4462.88it/s, Materializing param=encoder.layers.8.attention.out_proj.bias]
# Loading weights:  63%|██████▎   | 133/211 [00:00<00:00, 4455.57it/s, Materializing param=encoder.layers.8.attention.out_proj.bias]
# Loading weights:  64%|██████▎   | 134/211 [00:00<00:00, 4476.13it/s, Materializing param=encoder.layers.8.attention.out_proj.weight]
# Loading weights:  64%|██████▎   | 134/211 [00:00<00:00, 4468.77it/s, Materializing param=encoder.layers.8.attention.out_proj.weight]
# Loading weights:  64%|██████▍   | 135/211 [00:00<00:00, 4489.09it/s, Materializing param=encoder.layers.8.attention.q_proj.bias]
# Loading weights:  64%|██████▍   | 135/211 [00:00<00:00, 4481.87it/s, Materializing param=encoder.layers.8.attention.q_proj.bias]
# Loading weights:  64%|██████▍   | 136/211 [00:00<00:00, 4500.33it/s, Materializing param=encoder.layers.8.attention.q_proj.weight]
# Loading weights:  64%|██████▍   | 136/211 [00:00<00:00, 4492.88it/s, Materializing param=encoder.layers.8.attention.q_proj.weight]
# Loading weights:  65%|██████▍   | 137/211 [00:00<00:00, 4511.77it/s, Materializing param=encoder.layers.8.attention.v_proj.bias]
# Loading weights:  65%|██████▍   | 137/211 [00:00<00:00, 4504.35it/s, Materializing param=encoder.layers.8.attention.v_proj.bias]
# Loading weights:  65%|██████▌   | 138/211 [00:00<00:00, 4524.10it/s, Materializing param=encoder.layers.8.attention.v_proj.weight]
# Loading weights:  65%|██████▌   | 138/211 [00:00<00:00, 4516.83it/s, Materializing param=encoder.layers.8.attention.v_proj.weight]
# Loading weights:  66%|██████▌   | 139/211 [00:00<00:00, 4536.50it/s, Materializing param=encoder.layers.8.feed_forward.intermediate_dense.bias]
# Loading weights:  66%|██████▌   | 139/211 [00:00<00:00, 4529.06it/s, Materializing param=encoder.layers.8.feed_forward.intermediate_dense.bias]
# Loading weights:  66%|██████▋   | 140/211 [00:00<00:00, 4548.40it/s, Materializing param=encoder.layers.8.feed_forward.intermediate_dense.weight]
# Loading weights:  66%|██████▋   | 140/211 [00:00<00:00, 4541.01it/s, Materializing param=encoder.layers.8.feed_forward.intermediate_dense.weight]
# Loading weights:  67%|██████▋   | 141/211 [00:00<00:00, 4560.68it/s, Materializing param=encoder.layers.8.feed_forward.output_dense.bias]
# Loading weights:  67%|██████▋   | 141/211 [00:00<00:00, 4553.37it/s, Materializing param=encoder.layers.8.feed_forward.output_dense.bias]
# Loading weights:  67%|██████▋   | 142/211 [00:00<00:00, 4572.78it/s, Materializing param=encoder.layers.8.feed_forward.output_dense.weight]
# Loading weights:  67%|██████▋   | 142/211 [00:00<00:00, 4565.46it/s, Materializing param=encoder.layers.8.feed_forward.output_dense.weight]
# Loading weights:  68%|██████▊   | 143/211 [00:00<00:00, 4584.99it/s, Materializing param=encoder.layers.8.final_layer_norm.bias]
# Loading weights:  68%|██████▊   | 143/211 [00:00<00:00, 4569.52it/s, Materializing param=encoder.layers.8.final_layer_norm.bias]
# Loading weights:  68%|██████▊   | 144/211 [00:00<00:00, 4585.19it/s, Materializing param=encoder.layers.8.final_layer_norm.weight]
# Loading weights:  68%|██████▊   | 144/211 [00:00<00:00, 4577.72it/s, Materializing param=encoder.layers.8.final_layer_norm.weight]
# Loading weights:  69%|██████▊   | 145/211 [00:00<00:00, 4596.51it/s, Materializing param=encoder.layers.8.layer_norm.bias]
# Loading weights:  69%|██████▊   | 145/211 [00:00<00:00, 4589.30it/s, Materializing param=encoder.layers.8.layer_norm.bias]
# Loading weights:  69%|██████▉   | 146/211 [00:00<00:00, 4608.22it/s, Materializing param=encoder.layers.8.layer_norm.weight]
# Loading weights:  69%|██████▉   | 146/211 [00:00<00:00, 4601.19it/s, Materializing param=encoder.layers.8.layer_norm.weight]
# Loading weights:  70%|██████▉   | 147/211 [00:00<00:00, 4620.35it/s, Materializing param=encoder.layers.9.attention.k_proj.bias]
# Loading weights:  70%|██████▉   | 147/211 [00:00<00:00, 4613.23it/s, Materializing param=encoder.layers.9.attention.k_proj.bias]
# Loading weights:  70%|███████   | 148/211 [00:00<00:00, 4631.79it/s, Materializing param=encoder.layers.9.attention.k_proj.weight]
# Loading weights:  70%|███████   | 148/211 [00:00<00:00, 4624.65it/s, Materializing param=encoder.layers.9.attention.k_proj.weight]
# Loading weights:  71%|███████   | 149/211 [00:00<00:00, 4643.51it/s, Materializing param=encoder.layers.9.attention.out_proj.bias]
# Loading weights:  71%|███████   | 149/211 [00:00<00:00, 4636.41it/s, Materializing param=encoder.layers.9.attention.out_proj.bias]
# Loading weights:  71%|███████   | 150/211 [00:00<00:00, 4652.55it/s, Materializing param=encoder.layers.9.attention.out_proj.weight]
# Loading weights:  71%|███████   | 150/211 [00:00<00:00, 4644.96it/s, Materializing param=encoder.layers.9.attention.out_proj.weight]
# Loading weights:  72%|███████▏  | 151/211 [00:00<00:00, 4655.71it/s, Materializing param=encoder.layers.9.attention.q_proj.bias]
# Loading weights:  72%|███████▏  | 151/211 [00:00<00:00, 4647.17it/s, Materializing param=encoder.layers.9.attention.q_proj.bias]
# Loading weights:  72%|███████▏  | 152/211 [00:00<00:00, 4663.00it/s, Materializing param=encoder.layers.9.attention.q_proj.weight]
# Loading weights:  72%|███████▏  | 152/211 [00:00<00:00, 4654.66it/s, Materializing param=encoder.layers.9.attention.q_proj.weight]
# Loading weights:  73%|███████▎  | 153/211 [00:00<00:00, 4670.48it/s, Materializing param=encoder.layers.9.attention.v_proj.bias]
# Loading weights:  73%|███████▎  | 153/211 [00:00<00:00, 4662.34it/s, Materializing param=encoder.layers.9.attention.v_proj.bias]
# Loading weights:  73%|███████▎  | 154/211 [00:00<00:00, 4678.06it/s, Materializing param=encoder.layers.9.attention.v_proj.weight]
# Loading weights:  73%|███████▎  | 154/211 [00:00<00:00, 4669.87it/s, Materializing param=encoder.layers.9.attention.v_proj.weight]
# Loading weights:  73%|███████▎  | 155/211 [00:00<00:00, 4685.50it/s, Materializing param=encoder.layers.9.feed_forward.intermediate_dense.bias]
# Loading weights:  73%|███████▎  | 155/211 [00:00<00:00, 4677.14it/s, Materializing param=encoder.layers.9.feed_forward.intermediate_dense.bias]
# Loading weights:  74%|███████▍  | 156/211 [00:00<00:00, 4689.93it/s, Materializing param=encoder.layers.9.feed_forward.intermediate_dense.weight]
# Loading weights:  74%|███████▍  | 156/211 [00:00<00:00, 4681.04it/s, Materializing param=encoder.layers.9.feed_forward.intermediate_dense.weight]
# Loading weights:  74%|███████▍  | 157/211 [00:00<00:00, 4694.42it/s, Materializing param=encoder.layers.9.feed_forward.output_dense.bias]
# Loading weights:  74%|███████▍  | 157/211 [00:00<00:00, 4684.34it/s, Materializing param=encoder.layers.9.feed_forward.output_dense.bias]
# Loading weights:  75%|███████▍  | 158/211 [00:00<00:00, 4699.03it/s, Materializing param=encoder.layers.9.feed_forward.output_dense.weight]
# Loading weights:  75%|███████▍  | 158/211 [00:00<00:00, 4692.01it/s, Materializing param=encoder.layers.9.feed_forward.output_dense.weight]
# Loading weights:  75%|███████▌  | 159/211 [00:00<00:00, 4709.27it/s, Materializing param=encoder.layers.9.final_layer_norm.bias]
# Loading weights:  75%|███████▌  | 159/211 [00:00<00:00, 4702.47it/s, Materializing param=encoder.layers.9.final_layer_norm.bias]
# Loading weights:  76%|███████▌  | 160/211 [00:00<00:00, 4719.89it/s, Materializing param=encoder.layers.9.final_layer_norm.weight]
# Loading weights:  76%|███████▌  | 160/211 [00:00<00:00, 4713.00it/s, Materializing param=encoder.layers.9.final_layer_norm.weight]
# Loading weights:  76%|███████▋  | 161/211 [00:00<00:00, 4730.46it/s, Materializing param=encoder.layers.9.layer_norm.bias]
# Loading weights:  76%|███████▋  | 161/211 [00:00<00:00, 4723.78it/s, Materializing param=encoder.layers.9.layer_norm.bias]
# Loading weights:  77%|███████▋  | 162/211 [00:00<00:00, 4741.21it/s, Materializing param=encoder.layers.9.layer_norm.weight]
# Loading weights:  77%|███████▋  | 162/211 [00:00<00:00, 4732.82it/s, Materializing param=encoder.layers.9.layer_norm.weight]
# Loading weights:  77%|███████▋  | 163/211 [00:00<00:00, 4749.67it/s, Materializing param=encoder.layers.10.attention.k_proj.bias]
# Loading weights:  77%|███████▋  | 163/211 [00:00<00:00, 4741.92it/s, Materializing param=encoder.layers.10.attention.k_proj.bias]
# Loading weights:  78%|███████▊  | 164/211 [00:00<00:00, 4758.21it/s, Materializing param=encoder.layers.10.attention.k_proj.weight]
# Loading weights:  78%|███████▊  | 164/211 [00:00<00:00, 4751.41it/s, Materializing param=encoder.layers.10.attention.k_proj.weight]
# Loading weights:  78%|███████▊  | 165/211 [00:00<00:00, 4768.29it/s, Materializing param=encoder.layers.10.attention.out_proj.bias]
# Loading weights:  78%|███████▊  | 165/211 [00:00<00:00, 4761.60it/s, Materializing param=encoder.layers.10.attention.out_proj.bias]
# Loading weights:  79%|███████▊  | 166/211 [00:00<00:00, 4778.19it/s, Materializing param=encoder.layers.10.attention.out_proj.weight]
# Loading weights:  79%|███████▊  | 166/211 [00:00<00:00, 4771.35it/s, Materializing param=encoder.layers.10.attention.out_proj.weight]
# Loading weights:  79%|███████▉  | 167/211 [00:00<00:00, 4787.85it/s, Materializing param=encoder.layers.10.attention.q_proj.bias]
# Loading weights:  79%|███████▉  | 167/211 [00:00<00:00, 4781.22it/s, Materializing param=encoder.layers.10.attention.q_proj.bias]
# Loading weights:  80%|███████▉  | 168/211 [00:00<00:00, 4797.90it/s, Materializing param=encoder.layers.10.attention.q_proj.weight]
# Loading weights:  80%|███████▉  | 168/211 [00:00<00:00, 4791.24it/s, Materializing param=encoder.layers.10.attention.q_proj.weight]
# Loading weights:  80%|████████  | 169/211 [00:00<00:00, 4807.96it/s, Materializing param=encoder.layers.10.attention.v_proj.bias]
# Loading weights:  80%|████████  | 169/211 [00:00<00:00, 4801.38it/s, Materializing param=encoder.layers.10.attention.v_proj.bias]
# Loading weights:  81%|████████  | 170/211 [00:00<00:00, 4806.42it/s, Materializing param=encoder.layers.10.attention.v_proj.weight]
# Loading weights:  81%|████████  | 170/211 [00:00<00:00, 4799.20it/s, Materializing param=encoder.layers.10.attention.v_proj.weight]
# Loading weights:  81%|████████  | 171/211 [00:00<00:00, 4814.79it/s, Materializing param=encoder.layers.10.feed_forward.intermediate_dense.bias]
# Loading weights:  81%|████████  | 171/211 [00:00<00:00, 4807.85it/s, Materializing param=encoder.layers.10.feed_forward.intermediate_dense.bias]
# Loading weights:  82%|████████▏ | 172/211 [00:00<00:00, 4822.97it/s, Materializing param=encoder.layers.10.feed_forward.intermediate_dense.weight]
# Loading weights:  82%|████████▏ | 172/211 [00:00<00:00, 4816.08it/s, Materializing param=encoder.layers.10.feed_forward.intermediate_dense.weight]
# Loading weights:  82%|████████▏ | 173/211 [00:00<00:00, 4832.05it/s, Materializing param=encoder.layers.10.feed_forward.output_dense.bias]
# Loading weights:  82%|████████▏ | 173/211 [00:00<00:00, 4825.43it/s, Materializing param=encoder.layers.10.feed_forward.output_dense.bias]
# Loading weights:  82%|████████▏ | 174/211 [00:00<00:00, 4841.35it/s, Materializing param=encoder.layers.10.feed_forward.output_dense.weight]
# Loading weights:  82%|████████▏ | 174/211 [00:00<00:00, 4834.68it/s, Materializing param=encoder.layers.10.feed_forward.output_dense.weight]
# Loading weights:  83%|████████▎ | 175/211 [00:00<00:00, 4850.89it/s, Materializing param=encoder.layers.10.final_layer_norm.bias]
# Loading weights:  83%|████████▎ | 175/211 [00:00<00:00, 4844.46it/s, Materializing param=encoder.layers.10.final_layer_norm.bias]
# Loading weights:  83%|████████▎ | 176/211 [00:00<00:00, 4853.94it/s, Materializing param=encoder.layers.10.final_layer_norm.weight]
# Loading weights:  83%|████████▎ | 176/211 [00:00<00:00, 4845.98it/s, Materializing param=encoder.layers.10.final_layer_norm.weight]
# Loading weights:  84%|████████▍ | 177/211 [00:00<00:00, 4858.97it/s, Materializing param=encoder.layers.10.layer_norm.bias]
# Loading weights:  84%|████████▍ | 177/211 [00:00<00:00, 4852.36it/s, Materializing param=encoder.layers.10.layer_norm.bias]
# Loading weights:  84%|████████▍ | 178/211 [00:00<00:00, 4867.81it/s, Materializing param=encoder.layers.10.layer_norm.weight]
# ...
# Train:  13%|█▎        | 8/61 [00:10<00:47,  1.12it/s, acc=0.991, loss=0.0185]
# Train:  15%|█▍        | 9/61 [00:10<01:03,  1.22s/it, acc=0.991, loss=0.0185]
# Train:  15%|█▍        | 9/61 [00:11<01:03,  1.22s/it, acc=0.992, loss=0.0175]Train step 10/61 | loss=0.0175 | acc=0.9917
#
# Train:  16%|█▋        | 10/61 [00:11<00:47,  1.07it/s, acc=0.992, loss=0.0175]
# Train:  16%|█▋        | 10/61 [00:12<00:47,  1.07it/s, acc=0.992, loss=0.0416]
# Train:  18%|█▊        | 11/61 [00:12<00:57,  1.14s/it, acc=0.992, loss=0.0416]
# Train:  18%|█▊        | 11/61 [00:12<00:57,  1.14s/it, acc=0.993, loss=0.035]
# Train:  20%|█▉        | 12/61 [00:12<00:43,  1.13it/s, acc=0.993, loss=0.035]
# Train:  20%|█▉        | 12/61 [00:14<00:43,  1.13it/s, acc=0.994, loss=0.0262]
# Train:  21%|██▏       | 13/61 [00:14<00:55,  1.16s/it, acc=0.994, loss=0.0262]
# Train:  21%|██▏       | 13/61 [00:15<00:55,  1.16s/it, acc=0.994, loss=0.077]
# Train:  23%|██▎       | 14/61 [00:15<00:41,  1.12it/s, acc=0.994, loss=0.077]
# Train:  23%|██▎       | 14/61 [00:17<00:41,  1.12it/s, acc=0.994, loss=0.0575]
# Train:  25%|██▍       | 15/61 [00:17<01:00,  1.31s/it, acc=0.994, loss=0.0575]
# Train:  25%|██▍       | 15/61 [00:17<01:00,  1.31s/it, acc=0.995, loss=0.0179]
# Train:  26%|██▌       | 16/61 [00:17<00:45,  1.00s/it, acc=0.995, loss=0.0179]
# Train:  26%|██▌       | 16/61 [00:19<00:45,  1.00s/it, acc=0.995, loss=0.0464]
# Train:  28%|██▊       | 17/61 [00:19<00:55,  1.26s/it, acc=0.995, loss=0.0464]
# Train:  28%|██▊       | 17/61 [00:19<00:55,  1.26s/it, acc=0.991, loss=0.107]
# Train:  30%|██▉       | 18/61 [00:19<00:41,  1.03it/s, acc=0.991, loss=0.107]
# Train:  30%|██▉       | 18/61 [00:21<00:41,  1.03it/s, acc=0.991, loss=0.0671]
# Train:  31%|███       | 19/61 [00:21<00:52,  1.26s/it, acc=0.991, loss=0.0671]
# Train:  31%|███       | 19/61 [00:21<00:52,  1.26s/it, acc=0.992, loss=0.0677]Train step 20/61 | loss=0.0677 | acc=0.9917
#
# Train:  33%|███▎      | 20/61 [00:21<00:39,  1.04it/s, acc=0.992, loss=0.0677]
# Train:  33%|███▎      | 20/61 [00:23<00:39,  1.04it/s, acc=0.992, loss=0.0521]
# Train:  34%|███▍      | 21/61 [00:23<00:47,  1.20s/it, acc=0.992, loss=0.0521]
# Train:  34%|███▍      | 21/61 [00:23<00:47,  1.20s/it, acc=0.992, loss=0.112]
# Train:  36%|███▌      | 22/61 [00:23<00:36,  1.08it/s, acc=0.992, loss=0.112]
# Train:  36%|███▌      | 22/61 [00:25<00:36,  1.08it/s, acc=0.993, loss=0.0165]
# Train:  38%|███▊      | 23/61 [00:25<00:46,  1.24s/it, acc=0.993, loss=0.0165]
# Train:  38%|███▊      | 23/61 [00:26<00:46,  1.24s/it, acc=0.993, loss=0.0252]
# Train:  39%|███▉      | 24/61 [00:26<00:35,  1.05it/s, acc=0.993, loss=0.0252]
# Train:  39%|███▉      | 24/61 [00:27<00:35,  1.05it/s, acc=0.993, loss=0.111]
# Train:  41%|████      | 25/61 [00:27<00:42,  1.17s/it, acc=0.993, loss=0.111]
# Train:  41%|████      | 25/61 [00:28<00:42,  1.17s/it, acc=0.994, loss=0.0134]
# Train:  43%|████▎     | 26/61 [00:28<00:31,  1.11it/s, acc=0.994, loss=0.0134]
# Train:  43%|████▎     | 26/61 [00:30<00:31,  1.11it/s, acc=0.991, loss=0.0863]
# Train:  44%|████▍     | 27/61 [00:30<00:40,  1.19s/it, acc=0.991, loss=0.0863]
# Train:  44%|████▍     | 27/61 [00:30<00:40,  1.19s/it, acc=0.991, loss=0.0423]
# Train:  46%|████▌     | 28/61 [00:30<00:30,  1.09it/s, acc=0.991, loss=0.0423]
# Train:  46%|████▌     | 28/61 [00:32<00:30,  1.09it/s, acc=0.989, loss=0.0772]
# Train:  48%|████▊     | 29/61 [00:32<00:37,  1.18s/it, acc=0.989, loss=0.0772]
# Train:  48%|████▊     | 29/61 [00:32<00:37,  1.18s/it, acc=0.989, loss=0.0714]Train step 30/61 | loss=0.0714 | acc=0.9889
#
# Train:  49%|████▉     | 30/61 [00:32<00:28,  1.09it/s, acc=0.989, loss=0.0714]
# Train:  49%|████▉     | 30/61 [00:34<00:28,  1.09it/s, acc=0.989, loss=0.0121]
# Train:  51%|█████     | 31/61 [00:34<00:37,  1.26s/it, acc=0.989, loss=0.0121]
# Train:  51%|█████     | 31/61 [00:34<00:37,  1.26s/it, acc=0.99, loss=0.0627]
# Train:  52%|█████▏    | 32/61 [00:34<00:28,  1.03it/s, acc=0.99, loss=0.0627]
# Train:  52%|█████▏    | 32/61 [00:36<00:28,  1.03it/s, acc=0.99, loss=0.0508]
# Train:  54%|█████▍    | 33/61 [00:36<00:34,  1.25s/it, acc=0.99, loss=0.0508]
# Train:  54%|█████▍    | 33/61 [00:36<00:34,  1.25s/it, acc=0.99, loss=0.0242]
# Train:  56%|█████▌    | 34/61 [00:36<00:25,  1.04it/s, acc=0.99, loss=0.0242]
# Train:  56%|█████▌    | 34/61 [00:39<00:25,  1.04it/s, acc=0.99, loss=0.0204]
# Train:  57%|█████▋    | 35/61 [00:39<00:33,  1.29s/it, acc=0.99, loss=0.0204]
# Train:  57%|█████▋    | 35/61 [00:39<00:33,  1.29s/it, acc=0.991, loss=0.0206]
# Train:  59%|█████▉    | 36/61 [00:39<00:24,  1.01it/s, acc=0.991, loss=0.0206]
# Train:  59%|█████▉    | 36/61 [00:41<00:24,  1.01it/s, acc=0.991, loss=0.0561]
# Train:  61%|██████    | 37/61 [00:41<00:29,  1.22s/it, acc=0.991, loss=0.0561]
# Train:  61%|██████    | 37/61 [00:41<00:29,  1.22s/it, acc=0.991, loss=0.0326]
# Train:  62%|██████▏   | 38/61 [00:41<00:21,  1.06it/s, acc=0.991, loss=0.0326]
# Train:  62%|██████▏   | 38/61 [00:43<00:21,  1.06it/s, acc=0.991, loss=0.0311]
# Train:  64%|██████▍   | 39/61 [00:43<00:26,  1.18s/it, acc=0.991, loss=0.0311]
# Train:  64%|██████▍   | 39/61 [00:43<00:26,  1.18s/it, acc=0.992, loss=0.0615]Train step 40/61 | loss=0.0615 | acc=0.9917
#
# Train:  66%|██████▌   | 40/61 [00:43<00:19,  1.09it/s, acc=0.992, loss=0.0615]
# Train:  66%|██████▌   | 40/61 [00:45<00:19,  1.09it/s, acc=0.992, loss=0.046]
# Train:  67%|██████▋   | 41/61 [00:45<00:23,  1.18s/it, acc=0.992, loss=0.046]
# Train:  67%|██████▋   | 41/61 [00:45<00:23,  1.18s/it, acc=0.992, loss=0.0224]
# Train:  69%|██████▉   | 42/61 [00:45<00:17,  1.10it/s, acc=0.992, loss=0.0224]
# Train:  69%|██████▉   | 42/61 [00:47<00:17,  1.10it/s, acc=0.992, loss=0.076]
# Train:  70%|███████   | 43/61 [00:47<00:21,  1.21s/it, acc=0.992, loss=0.076]
# Train:  70%|███████   | 43/61 [00:47<00:21,  1.21s/it, acc=0.992, loss=0.048]
# Train:  72%|███████▏  | 44/61 [00:47<00:15,  1.07it/s, acc=0.992, loss=0.048]
# Train:  72%|███████▏  | 44/61 [00:49<00:15,  1.07it/s, acc=0.991, loss=0.335]
# Train:  74%|███████▍  | 45/61 [00:49<00:19,  1.24s/it, acc=0.991, loss=0.335]
# Train:  74%|███████▍  | 45/61 [00:49<00:19,  1.24s/it, acc=0.991, loss=0.0362]
# Train:  75%|███████▌  | 46/61 [00:49<00:14,  1.05it/s, acc=0.991, loss=0.0362]
# Train:  75%|███████▌  | 46/61 [00:51<00:14,  1.05it/s, acc=0.991, loss=0.0172]
# Train:  77%|███████▋  | 47/61 [00:51<00:17,  1.24s/it, acc=0.991, loss=0.0172]
# Train:  77%|███████▋  | 47/61 [00:52<00:17,  1.24s/it, acc=0.991, loss=0.0317]
# Train:  79%|███████▊  | 48/61 [00:52<00:12,  1.05it/s, acc=0.991, loss=0.0317]
# Train:  79%|███████▊  | 48/61 [00:54<00:12,  1.05it/s, acc=0.99, loss=0.149]
# Train:  80%|████████  | 49/61 [00:54<00:15,  1.27s/it, acc=0.99, loss=0.149]
# Train:  80%|████████  | 49/61 [00:54<00:15,  1.27s/it, acc=0.99, loss=0.0293]Train step 50/61 | loss=0.0293 | acc=0.9900
#
# Train:  82%|████████▏ | 50/61 [00:54<00:10,  1.03it/s, acc=0.99, loss=0.0293]
# Train:  82%|████████▏ | 50/61 [00:56<00:10,  1.03it/s, acc=0.989, loss=0.245]
# Train:  84%|████████▎ | 51/61 [00:56<00:11,  1.19s/it, acc=0.989, loss=0.245]
# Train:  84%|████████▎ | 51/61 [00:56<00:11,  1.19s/it, acc=0.987, loss=0.167]
# Train:  85%|████████▌ | 52/61 [00:56<00:08,  1.09it/s, acc=0.987, loss=0.167]
# Train:  85%|████████▌ | 52/61 [00:58<00:08,  1.09it/s, acc=0.987, loss=0.0444]
# Train:  87%|████████▋ | 53/61 [00:58<00:10,  1.30s/it, acc=0.987, loss=0.0444]
# Train:  87%|████████▋ | 53/61 [00:58<00:10,  1.30s/it, acc=0.988, loss=0.0235]
# Train:  89%|████████▊ | 54/61 [00:58<00:06,  1.01it/s, acc=0.988, loss=0.0235]
# Train:  89%|████████▊ | 54/61 [01:00<00:06,  1.01it/s, acc=0.988, loss=0.0518]
# Train:  90%|█████████ | 55/61 [01:00<00:07,  1.29s/it, acc=0.988, loss=0.0518]
# Train:  90%|█████████ | 55/61 [01:01<00:07,  1.29s/it, acc=0.988, loss=0.0778]
# Train:  92%|█████████▏| 56/61 [01:01<00:04,  1.01it/s, acc=0.988, loss=0.0778]
# Train:  92%|█████████▏| 56/61 [01:02<00:04,  1.01it/s, acc=0.987, loss=0.0805]
# Train:  93%|█████████▎| 57/61 [01:02<00:04,  1.22s/it, acc=0.987, loss=0.0805]
# Train:  93%|█████████▎| 57/61 [01:03<00:04,  1.22s/it, acc=0.987, loss=0.0254]
# Train:  95%|█████████▌| 58/61 [01:03<00:02,  1.07it/s, acc=0.987, loss=0.0254]
# Train:  95%|█████████▌| 58/61 [01:04<00:02,  1.07it/s, acc=0.987, loss=0.017]
# Train:  97%|█████████▋| 59/61 [01:04<00:02,  1.20s/it, acc=0.987, loss=0.017]
# Train:  97%|█████████▋| 59/61 [01:05<00:02,  1.20s/it, acc=0.988, loss=0.0182]Train step 60/61 | loss=0.0182 | acc=0.9875
#
# Train:  98%|█████████▊| 60/61 [01:05<00:00,  1.09it/s, acc=0.988, loss=0.0182]
# Train:  98%|█████████▊| 60/61 [01:05<00:00,  1.09it/s, acc=0.988, loss=0.0285]Train step 61/61 | loss=0.0285 | acc=0.9876
#
# Train: 100%|██████████| 61/61 [01:05<00:00,  1.21it/s, acc=0.988, loss=0.0285]
#
#
# Val:   0%|          | 0/10 [00:00<?, ?it/s]Val step 1/10 | loss=0.0758 | acc=1.0000
#
# Val:  10%|█         | 1/10 [00:02<00:21,  2.43s/it]
# Val:  20%|██        | 2/10 [00:02<00:09,  1.16s/it]
# Val:  30%|███       | 3/10 [00:04<00:09,  1.37s/it]
# Val:  40%|████      | 4/10 [00:04<00:05,  1.06it/s]
# Val:  50%|█████     | 5/10 [00:06<00:06,  1.33s/it]
# Val:  60%|██████    | 6/10 [00:06<00:03,  1.03it/s]
# Val:  70%|███████   | 7/10 [00:09<00:04,  1.36s/it]
# Val:  80%|████████  | 8/10 [00:09<00:02,  1.01s/it]
# Val:  90%|█████████ | 9/10 [00:10<00:01,  1.20s/it]Val step 10/10 | loss=0.2662 | acc=0.9167
#
# Val: 100%|██████████| 10/10 [00:11<00:00,  1.09it/s]
#
# Epoch 12/12 | Train Loss: 0.0626 | Train Acc: 0.9876 | Val Loss: 0.1751 | Val Acc: 0.9167
# Best validation accuracy: 0.9333
#
# Export train_embeddings:   0%|          | 0/61 [00:00<?, ?it/s]
# Export train_embeddings:   2%|▏         | 1/61 [00:02<02:38,  2.65s/it]
# Export train_embeddings:   3%|▎         | 2/61 [00:03<01:24,  1.43s/it]
# Export train_embeddings:   5%|▍         | 3/61 [00:04<01:26,  1.49s/it]
# Export train_embeddings:   7%|▋         | 4/61 [00:05<01:04,  1.13s/it]
# Export train_embeddings:   8%|▊         | 5/61 [00:07<01:20,  1.44s/it]
# Export train_embeddings:  10%|▉         | 6/61 [00:07<01:03,  1.15s/it]
# Export train_embeddings:  11%|█▏        | 7/61 [00:09<01:11,  1.32s/it]
# Export train_embeddings:  13%|█▎        | 8/61 [00:10<00:57,  1.09s/it]
# Export train_embeddings:  15%|█▍        | 9/61 [00:12<01:09,  1.34s/it]
# Export train_embeddings:  16%|█▋        | 10/61 [00:12<00:56,  1.11s/it]
# Export train_embeddings:  18%|█▊        | 11/61 [00:14<01:03,  1.26s/it]
# Export train_embeddings:  20%|█▉        | 12/61 [00:14<00:51,  1.06s/it]
# Export train_embeddings:  21%|██▏       | 13/61 [00:16<00:59,  1.23s/it]
# Export train_embeddings:  23%|██▎       | 14/61 [00:17<00:48,  1.04s/it]
# Export train_embeddings:  25%|██▍       | 15/61 [00:18<00:56,  1.22s/it]
# Export train_embeddings:  26%|██▌       | 16/61 [00:19<00:46,  1.03s/it]
# Export train_embeddings:  28%|██▊       | 17/61 [00:21<00:54,  1.23s/it]
# Export train_embeddings:  30%|██▉       | 18/61 [00:21<00:44,  1.04s/it]
# Export train_embeddings:  31%|███       | 19/61 [00:23<00:51,  1.23s/it]
# Export train_embeddings:  33%|███▎      | 20/61 [00:23<00:42,  1.04s/it]
# Export train_embeddings:  34%|███▍      | 21/61 [00:25<00:47,  1.18s/it]
# Export train_embeddings:  36%|███▌      | 22/61 [00:26<00:39,  1.01s/it]
# Export train_embeddings:  38%|███▊      | 23/61 [00:27<00:47,  1.24s/it]
# Export train_embeddings:  39%|███▉      | 24/61 [00:28<00:38,  1.04s/it]
# Export train_embeddings:  41%|████      | 25/61 [00:29<00:42,  1.19s/it]
# Export train_embeddings:  43%|████▎     | 26/61 [00:30<00:35,  1.01s/it]
# Export train_embeddings:  44%|████▍     | 27/61 [00:32<00:41,  1.22s/it]
# Export train_embeddings:  46%|████▌     | 28/61 [00:32<00:33,  1.03s/it]
# Export train_embeddings:  48%|████▊     | 29/61 [00:34<00:40,  1.26s/it]
# Export train_embeddings:  49%|████▉     | 30/61 [00:35<00:32,  1.05s/it]
# Export train_embeddings:  51%|█████     | 31/61 [00:36<00:37,  1.24s/it]
# Export train_embeddings:  52%|█████▏    | 32/61 [00:37<00:30,  1.04s/it]
# Export train_embeddings:  54%|█████▍    | 33/61 [00:38<00:33,  1.20s/it]
# Export train_embeddings:  56%|█████▌    | 34/61 [00:39<00:27,  1.01s/it]
# Export train_embeddings:  57%|█████▋    | 35/61 [00:41<00:31,  1.20s/it]
# Export train_embeddings:  59%|█████▉    | 36/61 [00:41<00:25,  1.01s/it]
# Export train_embeddings:  61%|██████    | 37/61 [00:43<00:28,  1.19s/it]
# Export train_embeddings:  62%|██████▏   | 38/61 [00:43<00:23,  1.00s/it]
# Export train_embeddings:  64%|██████▍   | 39/61 [00:45<00:25,  1.16s/it]
# Export train_embeddings:  66%|██████▌   | 40/61 [00:46<00:20,  1.02it/s]
# Export train_embeddings:  67%|██████▋   | 41/61 [00:47<00:23,  1.17s/it]
# Export train_embeddings:  69%|██████▉   | 42/61 [00:48<00:18,  1.01it/s]
# Export train_embeddings:  70%|███████   | 43/61 [00:49<00:22,  1.23s/it]
# Export train_embeddings:  72%|███████▏  | 44/61 [00:50<00:17,  1.03s/it]
# Export train_embeddings:  74%|███████▍  | 45/61 [00:52<00:21,  1.33s/it]
# Export train_embeddings:  75%|███████▌  | 46/61 [00:53<00:16,  1.10s/it]
# Export train_embeddings:  77%|███████▋  | 47/61 [00:55<00:18,  1.33s/it]
# Export train_embeddings:  79%|███████▊  | 48/61 [00:55<00:14,  1.10s/it]
# Export train_embeddings:  80%|████████  | 49/61 [00:57<00:16,  1.34s/it]
# Export train_embeddings:  82%|████████▏ | 50/61 [00:58<00:12,  1.11s/it]
# Export train_embeddings:  84%|████████▎ | 51/61 [01:00<00:13,  1.37s/it]
# Export train_embeddings:  85%|████████▌ | 52/61 [01:00<00:10,  1.13s/it]
# Export train_embeddings:  87%|████████▋ | 53/61 [01:02<00:10,  1.26s/it]
# Export train_embeddings:  89%|████████▊ | 54/61 [01:02<00:07,  1.05s/it]
# Export train_embeddings:  90%|█████████ | 55/61 [01:04<00:07,  1.27s/it]
# Export train_embeddings:  92%|█████████▏| 56/61 [01:05<00:05,  1.06s/it]
# Export train_embeddings:  93%|█████████▎| 57/61 [01:06<00:04,  1.22s/it]
# Export train_embeddings:  95%|█████████▌| 58/61 [01:07<00:03,  1.02s/it]
# Export train_embeddings:  97%|█████████▋| 59/61 [01:08<00:02,  1.20s/it]
# Export train_embeddings:  98%|█████████▊| 60/61 [01:09<00:01,  1.01s/it]
# Export train_embeddings: 100%|██████████| 61/61 [01:09<00:00,  1.24it/s]
#
#
# Export val_embeddings:   0%|          | 0/10 [00:00<?, ?it/s]
# Export val_embeddings:  10%|█         | 1/10 [00:02<00:24,  2.71s/it]
# Export val_embeddings:  20%|██        | 2/10 [00:03<00:11,  1.45s/it]
# Export val_embeddings:  30%|███       | 3/10 [00:05<00:11,  1.58s/it]
# Export val_embeddings:  40%|████      | 4/10 [00:05<00:07,  1.18s/it]
# Export val_embeddings:  50%|█████     | 5/10 [00:07<00:06,  1.36s/it]
# Export val_embeddings:  60%|██████    | 6/10 [00:07<00:04,  1.09s/it]
# Export val_embeddings:  70%|███████   | 7/10 [00:09<00:03,  1.26s/it]
# Export val_embeddings:  80%|████████  | 8/10 [00:10<00:02,  1.04s/it]
# Export val_embeddings:  90%|█████████ | 9/10 [00:11<00:01,  1.16s/it]
# Export val_embeddings: 100%|██████████| 10/10 [00:12<00:00,  1.02it/s]
#
#
# Export test_embeddings:   0%|          | 0/11 [00:00<?, ?it/s]
# Export test_embeddings:   9%|▉         | 1/11 [00:02<00:26,  2.62s/it]
# Export test_embeddings:  18%|█▊        | 2/11 [00:03<00:12,  1.42s/it]
# Export test_embeddings:  27%|██▋       | 3/11 [00:04<00:11,  1.39s/it]
# Export test_embeddings:  36%|███▋      | 4/11 [00:05<00:07,  1.07s/it]
# Export test_embeddings:  45%|████▌     | 5/11 [00:06<00:07,  1.21s/it]
# Export test_embeddings:  55%|█████▍    | 6/11 [00:07<00:04,  1.00it/s]
# Export test_embeddings:  64%|██████▎   | 7/11 [00:08<00:04,  1.15s/it]
# Export test_embeddings:  73%|███████▎  | 8/11 [00:09<00:02,  1.03it/s]
# Export test_embeddings:  82%|████████▏ | 9/11 [00:10<00:02,  1.12s/it]
# Export test_embeddings:  91%|█████████ | 10/11 [00:11<00:00,  1.05it/s]
# Export test_embeddings: 100%|██████████| 11/11 [00:11<00:00,  1.37it/s]
#
# Saved metrics to: /kaggle/working/outputs_audio/metrics.pt
# Command finished in 1023.5s with exit code 0

# %%
audio_out_dir = Path(AUDIO_CONFIG["output_dir"])
print("Audio output dir exists:", audio_out_dir.exists())
if audio_out_dir.exists():
    for p in sorted(audio_out_dir.glob("*")):
        print(" -", p.name)

audio_metrics_path = audio_out_dir / "metrics.pt"
if audio_metrics_path.exists():
    audio_metrics = torch.load(audio_metrics_path, map_location="cpu")
    print("\nAudio Best validation accuracy:", audio_metrics.get("best_val_acc"))
    print("Audio Split sizes:", {k: audio_metrics.get(k) for k in ["num_train", "num_val", "num_test"]})
else:
    print("Audio metrics.pt not found")
# Out:
# Audio output dir exists: True
#  - metrics.pt
#  - test_embeddings.pt
#  - train_embeddings.pt
#  - val_embeddings.pt
#  - wav2vec2_base_deepfake_best.pt
#
# Audio Best validation accuracy: 0.9333333333333333
# Audio Split sizes: {'num_train': 726, 'num_val': 120, 'num_test': 124}

# %% [markdown]
# ## Late Fusion Setup
#
# Load embeddings from both video and audio models for fusion experiments.

# %%
video_embed_path = out_dir / "val_embeddings.pt"
audio_embed_path = audio_out_dir / "val_embeddings.pt"

if video_embed_path.exists() and audio_embed_path.exists():
    video_data = torch.load(video_embed_path, map_location="cpu")
    audio_data = torch.load(audio_embed_path, map_location="cpu")
    
    print("Video embeddings shape:", video_data["embeddings"].shape)
    print("Audio embeddings shape:", audio_data["embeddings"].shape)
    print("Video embedding dim (for fusion):", video_data["embeddings"].shape[1])
    print("Audio embedding dim (for fusion):", audio_data["embeddings"].shape[1])
    print("\nTotal embedding dims for fusion: {} + {} = {}".format(
        video_data["embeddings"].shape[1],
        audio_data["embeddings"].shape[1],
        video_data["embeddings"].shape[1] + audio_data["embeddings"].shape[1]
    ))
else:
    print("One or both embedding files not found.")
    if not video_embed_path.exists():
        print("Video:", video_embed_path)
    if not audio_embed_path.exists():
        print("Audio:", audio_embed_path)
# Out:
# Video embeddings shape: torch.Size([120, 768])
# Audio embeddings shape: torch.Size([120, 768])
# Video embedding dim (for fusion): 768
# Audio embedding dim (for fusion): 768
#
# Total embedding dims for fusion: 768 + 768 = 1536

# %%
all_outputs_zip = Path(CONFIG["working_dir"]) / "all_deepfake_outputs.zip"
if out_dir.exists() or audio_out_dir.exists():
    # !zip -r -q {all_outputs_zip} {out_dir} {audio_out_dir}
    print("Created comprehensive zip:", all_outputs_zip)
else:
    print("No output directories found.")
# Out:
# Created comprehensive zip: /kaggle/working/all_deepfake_outputs.zip

# %% [markdown]
# ---
#
# # Two-Head + 4-Class Multimodal Fusion
#
# This section trains a multimodal model on frozen video/audio embeddings with:
# - Video authenticity head (fake vs real)
# - Audio authenticity head (fake vs real)
# - Derived four-class prediction (FF, FR, RF, RR)
#
# It includes frequency-aware filtering, cross-modality attention, progress bars, and checkpoint resume logic.
#
# ## Setup Fusion Config

# %%
# Sanity check: verify embedding label semantics and provenance before two-head fusion training
video_train_path = Path(FUSION_CONFIG["video_train_embed"])
audio_train_path = Path(FUSION_CONFIG["audio_train_embed"])

if not video_train_path.exists() or not audio_train_path.exists():
    print("Embedding files are missing. Run video/audio embedding export first.")
else:
    v_data = torch.load(video_train_path, map_location="cpu")
    a_data = torch.load(audio_train_path, map_location="cpu")

    required_keys = ["labels", "paths", "av_type", "split_strategy"]
    missing_v = [k for k in required_keys if k not in v_data]
    missing_a = [k for k in required_keys if k not in a_data]
    if missing_v or missing_a:
        print("Missing keys in embeddings.")
        print("Video missing:", missing_v)
        print("Audio missing:", missing_a)
        print("Warning: these embeddings look old. Regenerate them after the subject_id split update.")
    else:
        if v_data.get("split_strategy") != "subject_id" or a_data.get("split_strategy") != "subject_id":
            print("Warning: embeddings were not exported with subject_id split metadata. Regenerate them to avoid leakage.")
        else:
            print("Embedding provenance check PASSED: subject_id split metadata found.")

        v_path_to_idx = {p: i for i, p in enumerate(v_data["paths"])}
        matched = []
        for a_idx, p in enumerate(a_data["paths"]):
            v_idx = v_path_to_idx.get(p)
            if v_idx is not None:
                matched.append((v_idx, a_idx))

        if not matched:
            print("No matched paths between video/audio embeddings.")
        else:
            v_idx = [x[0] for x in matched]
            a_idx = [x[1] for x in matched]

            v_labels = torch.as_tensor(v_data["labels"])[v_idx].long().numpy()
            a_labels = torch.as_tensor(a_data["labels"])[a_idx].long().numpy()
            av_types_v = [v_data["av_type"][i] for i in v_idx]
            av_types_a = [a_data["av_type"][i] for i in a_idx]

            if av_types_v != av_types_a:
                print("Warning: av_type mismatch between aligned video/audio embeddings.")

            expected_v = np.array([1 if av in {"FF", "FR"} else 0 for av in av_types_v], dtype=np.int64)
            expected_a = np.array([1 if av in {"FF", "RF"} else 0 for av in av_types_v], dtype=np.int64)

            v_ok = float((v_labels == expected_v).mean())
            a_ok = float((a_labels == expected_a).mean())

            print(f"Matched samples: {len(matched)}")
            print(f"Video label semantic match (fake video=1 for FF/FR): {v_ok:.4f}")
            print(f"Audio label semantic match (fake audio=1 for FF/RF): {a_ok:.4f}")
            print("Video label counts [real_video(0), fake_video(1)]:", np.bincount(v_labels, minlength=2).tolist())
            print("Audio label counts [real_audio(0), fake_audio(1)]:", np.bincount(a_labels, minlength=2).tolist())

            if v_ok < 0.999 or a_ok < 0.999:
                print("\nAction: regenerate embeddings by re-running video and audio training/export cells.")
            else:
                print("\nEmbedding semantics check PASSED. Safe to run two-head fusion training.")
# Out:
# Fusion config:
# {
#   "script_name": "train_fusion_two_head_multimodal.py",
#   "video_train_embed": "/kaggle/working/outputs/train_embeddings.pt",
#   "audio_train_embed": "/kaggle/working/outputs_audio/train_embeddings.pt",
#   "video_val_embed": "/kaggle/working/outputs/val_embeddings.pt",
#   "audio_val_embed": "/kaggle/working/outputs_audio/val_embeddings.pt",
#   "video_test_embed": "/kaggle/working/outputs/test_embeddings.pt",
#   "audio_test_embed": "/kaggle/working/outputs_audio/test_embeddings.pt",
#   "output_dir": "/kaggle/working/outputs_fusion_two_head",
#   "epochs": 24,
#   "batch_size": 192,
#   "lr": 0.0007,
#   "weight_decay": 0.01,
#   "num_workers": 2,
#   "d_model": 256,
#   "num_attn_heads": 8,
#   "dropout": 0.2,
#   "contrastive_weight": 0.05,
#   "grad_clip_norm": 1.0,
#   "early_stop_patience": 8,
#   "resume": true,
#   "force_retrain": false
# }

# %%
# Sanity check: verify embedding label semantics before two-head fusion training
video_train_path = Path(FUSION_CONFIG["video_train_embed"])
audio_train_path = Path(FUSION_CONFIG["audio_train_embed"])

if not video_train_path.exists() or not audio_train_path.exists():
    print("Embedding files are missing. Run video/audio embedding export first.")
else:
    v_data = torch.load(video_train_path, map_location="cpu")
    a_data = torch.load(audio_train_path, map_location="cpu")

    required_keys = ["labels", "paths", "av_type"]
    missing_v = [k for k in required_keys if k not in v_data]
    missing_a = [k for k in required_keys if k not in a_data]
    if missing_v or missing_a:
        print("Missing keys in embeddings.")
        print("Video missing:", missing_v)
        print("Audio missing:", missing_a)
    else:
        v_path_to_idx = {p: i for i, p in enumerate(v_data["paths"])}
        matched = []
        for a_idx, p in enumerate(a_data["paths"]):
            v_idx = v_path_to_idx.get(p)
            if v_idx is not None:
                matched.append((v_idx, a_idx))

        if not matched:
            print("No matched paths between video/audio embeddings.")
        else:
            v_idx = [x[0] for x in matched]
            a_idx = [x[1] for x in matched]

            v_labels = torch.as_tensor(v_data["labels"])[v_idx].long().numpy()
            a_labels = torch.as_tensor(a_data["labels"])[a_idx].long().numpy()
            av_types_v = [v_data["av_type"][i] for i in v_idx]
            av_types_a = [a_data["av_type"][i] for i in a_idx]

            if av_types_v != av_types_a:
                print("Warning: av_type mismatch between aligned video/audio embeddings.")

            expected_v = np.array([1 if av in {"FF", "FR"} else 0 for av in av_types_v], dtype=np.int64)
            expected_a = np.array([1 if av in {"FF", "RF"} else 0 for av in av_types_v], dtype=np.int64)

            v_ok = float((v_labels == expected_v).mean())
            a_ok = float((a_labels == expected_a).mean())

            print(f"Matched samples: {len(matched)}")
            print(f"Video label semantic match (fake video=1 for FF/FR): {v_ok:.4f}")
            print(f"Audio label semantic match (fake audio=1 for FF/RF): {a_ok:.4f}")
            print("Video label counts [real_video(0), fake_video(1)]:", np.bincount(v_labels, minlength=2).tolist())
            print("Audio label counts [real_audio(0), fake_audio(1)]:", np.bincount(a_labels, minlength=2).tolist())

            if v_ok < 0.999 or a_ok < 0.999:
                print("\nAction: regenerate embeddings by re-running video and audio training/export cells.")
            else:
                print("\nEmbedding semantics check PASSED. Safe to run two-head fusion training.")
# Out:
# Matched samples: 726
# Video label semantic match (fake video=1 for FF/FR): 1.0000
# Audio label semantic match (fake audio=1 for FF/RF): 1.0000
# Video label counts [real_video(0), fake_video(1)]: [364, 362]
# Audio label counts [real_audio(0), fake_audio(1)]: [363, 363]
#
# Embedding semantics check PASSED. Safe to run two-head fusion training.

# %%
fusion_working_script = Path(CONFIG["working_dir"]) / FUSION_CONFIG["script_name"]

fusion_script_candidates = list(Path("/kaggle/input").rglob(FUSION_CONFIG["script_name"]))
if fusion_script_candidates:
    latest_script = max(fusion_script_candidates, key=lambda p: p.stat().st_mtime)
    shutil.copy2(latest_script, fusion_working_script)
    print("Refreshed fusion script from:", latest_script)
elif not fusion_working_script.exists():
    raise FileNotFoundError(f"{FUSION_CONFIG['script_name']} not found in /kaggle/input")

print("Fusion training script path:", fusion_working_script)
print("Script exists:", fusion_working_script.exists())
# Out:
# Refreshed fusion script from: /kaggle/input/datasets/mahirashab/essential-scripts/train_fusion_two_head_multimodal.py
# Fusion training script path: /kaggle/working/train_fusion_two_head_multimodal.py
# Script exists: True

# %%
fusion_done = (Path(FUSION_CONFIG["output_dir"]) / "test_metrics.pt").exists()
if fusion_done and not FUSION_CONFIG.get("force_retrain", False):
    print("Fusion artifacts already found. Skipping training cell.")
else:
    fusion_cmd = [
        "python", "-u", "/kaggle/working/train_fusion_two_head_multimodal.py",
        "--video-train-embed", FUSION_CONFIG["video_train_embed"],
        "--audio-train-embed", FUSION_CONFIG["audio_train_embed"],
        "--video-val-embed", FUSION_CONFIG["video_val_embed"],
        "--audio-val-embed", FUSION_CONFIG["audio_val_embed"],
        "--video-test-embed", FUSION_CONFIG["video_test_embed"],
        "--audio-test-embed", FUSION_CONFIG["audio_test_embed"],
        "--output-dir", FUSION_CONFIG["output_dir"],
        "--epochs", str(FUSION_CONFIG["epochs"]),
        "--batch-size", str(FUSION_CONFIG["batch_size"]),
        "--lr", str(FUSION_CONFIG["lr"]),
        "--weight-decay", str(FUSION_CONFIG["weight_decay"]),
        "--num-workers", str(FUSION_CONFIG["num_workers"]),
        "--d-model", str(FUSION_CONFIG["d_model"]),
        "--num-attn-heads", str(FUSION_CONFIG["num_attn_heads"]),
        "--dropout", str(FUSION_CONFIG["dropout"]),
        "--contrastive-weight", str(FUSION_CONFIG["contrastive_weight"]),
        "--grad-clip-norm", str(FUSION_CONFIG["grad_clip_norm"]),
        "--early-stop-patience", str(FUSION_CONFIG["early_stop_patience"]),
    ]
    if FUSION_CONFIG.get("resume", True):
        fusion_cmd.append("--resume")

    run_streaming_command(fusion_cmd)
# Out:
# Running: python -u /kaggle/working/train_fusion_two_head_multimodal.py --video-train-embed /kaggle/working/outputs/train_embeddings.pt --audio-train-embed /kaggle/working/outputs_audio/train_embeddings.pt --video-val-embed /kaggle/working/outputs/val_embeddings.pt --audio-val-embed /kaggle/working/outputs_audio/val_embeddings.pt --video-test-embed /kaggle/working/outputs/test_embeddings.pt --audio-test-embed /kaggle/working/outputs_audio/test_embeddings.pt --output-dir /kaggle/working/outputs_fusion_two_head --epochs 24 --batch-size 192 --lr 0.0007 --weight-decay 0.01 --num-workers 2 --d-model 256 --num-attn-heads 8 --dropout 0.2 --contrastive-weight 0.05 --grad-clip-norm 1.0 --early-stop-patience 8 --resume
# Using device: cuda
# Loading and aligning embeddings...
# Train: 726 | Val: 120 | Test: 124
# /kaggle/working/train_fusion_two_head_multimodal.py:648: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler(enabled=device.type == "cuda")
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:01<?, ?it/s, c4_acc=0.2865, loss=2.8732, lr=7.00e-04]Train step 1/4 | loss=2.8732 | c4_acc=0.2865 | parts={'loss_video': 0.4684886932373047, 'loss_audio': 0.7423641085624695, 'loss_four': 1.3908437490463257, 'loss_contrast': 5.4296979904174805}
#
# Train:  25%|██▌       | 1/4 [00:01<00:03,  1.13s/it, c4_acc=0.2865, loss=2.8732, lr=7.00e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  25%|██▌       | 1/4 [00:01<00:03,  1.13s/it, c4_acc=0.4453, loss=2.7161, lr=6.99e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  25%|██▌       | 1/4 [00:01<00:03,  1.13s/it, c4_acc=0.4913, loss=2.7932, lr=6.98e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  25%|██▌       | 1/4 [00:01<00:03,  1.13s/it, c4_acc=0.5455, loss=1.6266, lr=6.97e-04]Train step 4/4 | loss=1.6266 | c4_acc=0.5455 | parts={'loss_video': 0.01779993623495102, 'loss_audio': 0.5210856199264526, 'loss_four': 0.8473665118217468, 'loss_contrast': 4.80712890625}
#
#
#
# Val:   0%|          | 0/1 [00:00<?, ?it/s]Val step 1/1
#
# Val: 100%|██████████| 1/1 [00:00<00:00,  9.48it/s]
#
# Epoch 01/24 | train_loss=2.5529 | train_c4_acc=0.5455 | val_loss=1.1582 | val_c4_acc=0.8167 | val_c4_f1=0.8142
# Saved new best checkpoint at epoch 1 to /kaggle/working/outputs_fusion_two_head/best_checkpoint.pt
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=0.7917, loss=1.4431, lr=6.95e-04]Train step 1/4 | loss=1.4431 | c4_acc=0.7917 | parts={'loss_video': 0.012091368436813354, 'loss_audio': 0.5142685770988464, 'loss_four': 0.6706530451774597, 'loss_contrast': 4.921483039855957}
# /kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=0.8281, loss=1.3573, lr=6.93e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=0.8455, loss=0.9362, lr=6.91e-04]
# Train:  75%|███████▌  | 3/4 [00:00<00:00, 28.58it/s, c4_acc=0.8455, loss=0.9362, lr=6.91e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  75%|███████▌  | 3/4 [00:00<00:00, 28.58it/s, c4_acc=0.8623, loss=0.7679, lr=6.88e-04]Train step 4/4 | loss=0.7679 | c4_acc=0.8623 | parts={'loss_video': 0.007433255668729544, 'loss_audio': 0.24753011763095856, 'loss_four': 0.29988646507263184, 'loss_contrast': 4.261504173278809}
#
#
#
# Val:   0%|          | 0/1 [00:00<?, ?it/s]Val step 1/1
#
#
# Epoch 02/24 | train_loss=1.1468 | train_c4_acc=0.8623 | val_loss=0.5651 | val_c4_acc=0.9000 | val_c4_f1=0.9000
# Saved new best checkpoint at epoch 2 to /kaggle/working/outputs_fusion_two_head/best_checkpoint.pt
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=0.9115, loss=0.6535, lr=6.85e-04]Train step 1/4 | loss=0.6535 | c4_acc=0.9115 | parts={'loss_video': 0.007992814294993877, 'loss_audio': 0.2100595235824585, 'loss_four': 0.2185097485780716, 'loss_contrast': 4.3390398025512695}
# /kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=0.9349, loss=0.5690, lr=6.81e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=0.9358, loss=0.5503, lr=6.78e-04]
# Train:  75%|███████▌  | 3/4 [00:00<00:00, 28.15it/s, c4_acc=0.9358, loss=0.5503, lr=6.78e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  75%|███████▌  | 3/4 [00:00<00:00, 28.15it/s, c4_acc=0.9435, loss=0.4515, lr=6.73e-04]Train step 4/4 | loss=0.4515 | c4_acc=0.9435 | parts={'loss_video': 0.005384782329201698, 'loss_audio': 0.1469428539276123, 'loss_four': 0.10579926520586014, 'loss_contrast': 3.8672916889190674}
#
#
#
# Val:   0%|          | 0/1 [00:00<?, ?it/s]Val step 1/1
#
#
# Epoch 03/24 | train_loss=0.5621 | train_c4_acc=0.9435 | val_loss=0.3363 | val_c4_acc=0.9583 | val_c4_f1=0.9583
# Saved new best checkpoint at epoch 3 to /kaggle/working/outputs_fusion_two_head/best_checkpoint.pt
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=0.9792, loss=0.3915, lr=6.69e-04]Train step 1/4 | loss=0.3915 | c4_acc=0.9792 | parts={'loss_video': 0.005127216223627329, 'loss_audio': 0.1017027497291565, 'loss_four': 0.08557242155075073, 'loss_contrast': 3.9819540977478027}
# /kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=0.9714, loss=0.3918, lr=6.64e-04]
# Train:  50%|█████     | 2/4 [00:00<00:00, 18.89it/s, c4_acc=0.9714, loss=0.3918, lr=6.64e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  50%|█████     | 2/4 [00:00<00:00, 18.89it/s, c4_acc=0.9740, loss=0.3349, lr=6.59e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  50%|█████     | 2/4 [00:00<00:00, 18.89it/s, c4_acc=0.9766, loss=0.2968, lr=6.53e-04]Train step 4/4 | loss=0.2968 | c4_acc=0.9766 | parts={'loss_video': 0.0031827990896999836, 'loss_audio': 0.065888911485672, 'loss_four': 0.0464852973818779, 'loss_contrast': 3.6257290840148926}
#
#
#
# Val:   0%|          | 0/1 [00:00<?, ?it/s]Val step 1/1
#
#
# Epoch 04/24 | train_loss=0.3570 | train_c4_acc=0.9766 | val_loss=0.1774 | val_c4_acc=0.9667 | val_c4_f1=0.9667
# Saved new best checkpoint at epoch 4 to /kaggle/working/outputs_fusion_two_head/best_checkpoint.pt
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=0.9792, loss=0.3051, lr=6.47e-04]Train step 1/4 | loss=0.3051 | c4_acc=0.9792 | parts={'loss_video': 0.0026222392916679382, 'loss_audio': 0.0577484555542469, 'loss_four': 0.05289405211806297, 'loss_contrast': 3.836395263671875}
# /kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=0.9818, loss=0.2960, lr=6.41e-04]
# Train:  50%|█████     | 2/4 [00:00<00:00, 18.15it/s, c4_acc=0.9818, loss=0.2960, lr=6.41e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  50%|█████     | 2/4 [00:00<00:00, 18.15it/s, c4_acc=0.9861, loss=0.2746, lr=6.34e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  50%|█████     | 2/4 [00:00<00:00, 18.15it/s, c4_acc=0.9890, loss=0.2158, lr=6.28e-04]Train step 4/4 | loss=0.2158 | c4_acc=0.9890 | parts={'loss_video': 0.0024083296302706003, 'loss_audio': 0.028599580749869347, 'loss_four': 0.00925449375063181, 'loss_contrast': 3.5107617378234863}
#
#
#
# Val:   0%|          | 0/1 [00:00<?, ?it/s]Val step 1/1
#
#
# Epoch 05/24 | train_loss=0.2762 | train_c4_acc=0.9890 | val_loss=0.1969 | val_c4_acc=0.9750 | val_c4_f1=0.9750
# Saved new best checkpoint at epoch 5 to /kaggle/working/outputs_fusion_two_head/best_checkpoint.pt
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=1.0000, loss=0.2124, lr=6.21e-04]Train step 1/4 | loss=0.2124 | c4_acc=1.0000 | parts={'loss_video': 0.0021007638424634933, 'loss_audio': 0.019376084208488464, 'loss_four': 0.003685773117467761, 'loss_contrast': 3.7445778846740723}
# /kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=0.9948, loss=0.2439, lr=6.13e-04]
# Train:  50%|█████     | 2/4 [00:00<00:00, 19.07it/s, c4_acc=0.9948, loss=0.2439, lr=6.13e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  50%|█████     | 2/4 [00:00<00:00, 19.07it/s, c4_acc=0.9948, loss=0.2460, lr=6.05e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  50%|█████     | 2/4 [00:00<00:00, 19.07it/s, c4_acc=0.9945, loss=0.2586, lr=5.97e-04]Train step 4/4 | loss=0.2586 | c4_acc=0.9945 | parts={'loss_video': 0.0014964333968237042, 'loss_audio': 0.054322510957717896, 'loss_four': 0.0334295853972435, 'loss_contrast': 3.3869757652282715}
#
#
#
# Val:   0%|          | 0/1 [00:00<?, ?it/s]Val step 1/1
#
#
# Epoch 06/24 | train_loss=0.2391 | train_c4_acc=0.9945 | val_loss=0.1097 | val_c4_acc=0.9750 | val_c4_f1=0.9750
# Saved new best checkpoint at epoch 6 to /kaggle/working/outputs_fusion_two_head/best_checkpoint.pt
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=1.0000, loss=0.2167, lr=5.89e-04]Train step 1/4 | loss=0.2167 | c4_acc=1.0000 | parts={'loss_video': 0.0014084192225709558, 'loss_audio': 0.02592775784432888, 'loss_four': 0.008227691985666752, 'loss_contrast': 3.6222128868103027}
# /kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=0.9896, loss=0.2557, lr=5.81e-04]
# Train:  50%|█████     | 2/4 [00:00<00:00, 19.54it/s, c4_acc=0.9896, loss=0.2557, lr=5.81e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  50%|█████     | 2/4 [00:00<00:00, 19.54it/s, c4_acc=0.9913, loss=0.2127, lr=5.72e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  50%|█████     | 2/4 [00:00<00:00, 19.54it/s, c4_acc=0.9931, loss=0.1855, lr=5.63e-04]Train step 4/4 | loss=0.1855 | c4_acc=0.9931 | parts={'loss_video': 0.0009694870095700026, 'loss_audio': 0.014051949605345726, 'loss_four': 0.002644237596541643, 'loss_contrast': 3.3567872047424316}
#
#
#
# Val:   0%|          | 0/1 [00:00<?, ?it/s]Val step 1/1
#
#
# Epoch 07/24 | train_loss=0.2195 | train_c4_acc=0.9931 | val_loss=0.0688 | val_c4_acc=0.9833 | val_c4_f1=0.9833
# Saved new best checkpoint at epoch 7 to /kaggle/working/outputs_fusion_two_head/best_checkpoint.pt
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=0.9896, loss=0.2241, lr=5.54e-04]Train step 1/4 | loss=0.2241 | c4_acc=0.9896 | parts={'loss_video': 0.0009392648935317993, 'loss_audio': 0.024068517610430717, 'loss_four': 0.02454235590994358, 'loss_contrast': 3.4916329383850098}
# /kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=0.9948, loss=0.1968, lr=5.44e-04]
# Train:  50%|█████     | 2/4 [00:00<00:00, 19.37it/s, c4_acc=0.9948, loss=0.1968, lr=5.44e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  50%|█████     | 2/4 [00:00<00:00, 19.37it/s, c4_acc=0.9948, loss=0.2032, lr=5.35e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  50%|█████     | 2/4 [00:00<00:00, 19.37it/s, c4_acc=0.9945, loss=0.1963, lr=5.25e-04]Train step 4/4 | loss=0.1963 | c4_acc=0.9945 | parts={'loss_video': 0.0007955670589581132, 'loss_audio': 0.021926457062363625, 'loss_four': 0.011400214396417141, 'loss_contrast': 3.243010997772217}
#
#
#
# Val:   0%|          | 0/1 [00:00<?, ?it/s]Val step 1/1
#
#
# Epoch 08/24 | train_loss=0.2056 | train_c4_acc=0.9945 | val_loss=0.0661 | val_c4_acc=0.9833 | val_c4_f1=0.9833
# No val F1 improvement for 1 epoch(s)
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=1.0000, loss=0.1801, lr=5.15e-04]Train step 1/4 | loss=0.1801 | c4_acc=1.0000 | parts={'loss_video': 0.0006913468241691589, 'loss_audio': 0.00888481829315424, 'loss_four': 0.0008160974830389023, 'loss_contrast': 3.3935344219207764}
# /kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=1.0000, loss=0.1895, lr=5.05e-04]
# Train:  50%|█████     | 2/4 [00:00<00:00, 19.73it/s, c4_acc=1.0000, loss=0.1895, lr=5.05e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  50%|█████     | 2/4 [00:00<00:00, 19.73it/s, c4_acc=0.9983, loss=0.1999, lr=4.94e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  50%|█████     | 2/4 [00:00<00:00, 19.73it/s, c4_acc=0.9986, loss=0.1711, lr=4.84e-04]Train step 4/4 | loss=0.1711 | c4_acc=0.9986 | parts={'loss_video': 0.0006718293880112469, 'loss_audio': 0.01523016020655632, 'loss_four': 0.0024612434208393097, 'loss_contrast': 3.0537989139556885}
#
#
#
# Val:   0%|          | 0/1 [00:00<?, ?it/s]Val step 1/1
#
#
# Epoch 09/24 | train_loss=0.1860 | train_c4_acc=0.9986 | val_loss=0.0547 | val_c4_acc=0.9917 | val_c4_f1=0.9917
# Saved new best checkpoint at epoch 9 to /kaggle/working/outputs_fusion_two_head/best_checkpoint.pt
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=1.0000, loss=0.1824, lr=4.73e-04]Train step 1/4 | loss=0.1824 | c4_acc=1.0000 | parts={'loss_video': 0.000599520280957222, 'loss_audio': 0.014109698124229908, 'loss_four': 0.005194893106818199, 'loss_contrast': 3.2494378089904785}
# /kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=1.0000, loss=0.1713, lr=4.63e-04]
# Train:  50%|█████     | 2/4 [00:00<00:00, 18.72it/s, c4_acc=1.0000, loss=0.1713, lr=4.63e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  50%|█████     | 2/4 [00:00<00:00, 18.72it/s, c4_acc=1.0000, loss=0.1687, lr=4.52e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  50%|█████     | 2/4 [00:00<00:00, 18.72it/s, c4_acc=0.9986, loss=0.1817, lr=4.41e-04]Train step 4/4 | loss=0.1817 | c4_acc=0.9986 | parts={'loss_video': 0.0005510711926035583, 'loss_audio': 0.022250080481171608, 'loss_four': 0.017085134983062744, 'loss_contrast': 2.836686134338379}
#
#
#
# Val:   0%|          | 0/1 [00:00<?, ?it/s]Val step 1/1
#
#
# Epoch 10/24 | train_loss=0.1757 | train_c4_acc=0.9986 | val_loss=0.0570 | val_c4_acc=0.9833 | val_c4_f1=0.9833
# No val F1 improvement for 1 epoch(s)
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=1.0000, loss=0.1683, lr=4.29e-04]Train step 1/4 | loss=0.1683 | c4_acc=1.0000 | parts={'loss_video': 0.000511790334712714, 'loss_audio': 0.008042342029511929, 'loss_four': 0.0013547049602493644, 'loss_contrast': 3.1669998168945312}
# /kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=1.0000, loss=0.1645, lr=4.18e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=0.9983, loss=0.1807, lr=4.07e-04]
# Train:  75%|███████▌  | 3/4 [00:00<00:00, 27.10it/s, c4_acc=0.9983, loss=0.1807, lr=4.07e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  75%|███████▌  | 3/4 [00:00<00:00, 27.10it/s, c4_acc=0.9986, loss=0.1472, lr=3.96e-04]Train step 4/4 | loss=0.1472 | c4_acc=0.9986 | parts={'loss_video': 0.0004980603698641062, 'loss_audio': 0.005022392142564058, 'loss_four': 0.0010269737103953958, 'loss_contrast': 2.8127734661102295}
#
#
#
# Val:   0%|          | 0/1 [00:00<?, ?it/s]Val step 1/1
#
#
# Epoch 11/24 | train_loss=0.1662 | train_c4_acc=0.9986 | val_loss=0.0301 | val_c4_acc=1.0000 | val_c4_f1=1.0000
# Saved new best checkpoint at epoch 11 to /kaggle/working/outputs_fusion_two_head/best_checkpoint.pt
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=0.9948, loss=0.1630, lr=3.84e-04]Train step 1/4 | loss=0.1630 | c4_acc=0.9948 | parts={'loss_video': 0.0005242675542831421, 'loss_audio': 0.006451037246733904, 'loss_four': 0.006575154140591621, 'loss_contrast': 2.988433837890625}
# /kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=0.9974, loss=0.1521, lr=3.73e-04]
# Train:  50%|█████     | 2/4 [00:00<00:00, 18.86it/s, c4_acc=0.9974, loss=0.1521, lr=3.73e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  50%|█████     | 2/4 [00:00<00:00, 18.86it/s, c4_acc=0.9965, loss=0.1612, lr=3.61e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  50%|█████     | 2/4 [00:00<00:00, 18.86it/s, c4_acc=0.9972, loss=0.1442, lr=3.50e-04]Train step 4/4 | loss=0.1442 | c4_acc=0.9972 | parts={'loss_video': 0.0005167746567167342, 'loss_audio': 0.010543505661189556, 'loss_four': 0.0036610197275877, 'loss_contrast': 2.589750289916992}
#
#
#
# Val:   0%|          | 0/1 [00:00<?, ?it/s]Val step 1/1
#
#
# Epoch 12/24 | train_loss=0.1557 | train_c4_acc=0.9972 | val_loss=0.0256 | val_c4_acc=1.0000 | val_c4_f1=1.0000
# No val F1 improvement for 1 epoch(s)
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=1.0000, loss=0.1516, lr=3.39e-04]Train step 1/4 | loss=0.1516 | c4_acc=1.0000 | parts={'loss_video': 0.0004912316799163818, 'loss_audio': 0.008420638740062714, 'loss_four': 0.0022704440634697676, 'loss_contrast': 2.8077826499938965}
# /kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=0.9974, loss=0.1531, lr=3.27e-04]
# Train:  50%|█████     | 2/4 [00:00<00:00, 19.55it/s, c4_acc=0.9974, loss=0.1531, lr=3.27e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  50%|█████     | 2/4 [00:00<00:00, 19.55it/s, c4_acc=0.9983, loss=0.1467, lr=3.16e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  50%|█████     | 2/4 [00:00<00:00, 19.55it/s, c4_acc=0.9986, loss=0.1389, lr=3.04e-04]Train step 4/4 | loss=0.1389 | c4_acc=0.9986 | parts={'loss_video': 0.0004902895307168365, 'loss_audio': 0.010552708059549332, 'loss_four': 0.008200581185519695, 'loss_contrast': 2.3936638832092285}
#
#
#
# Val:   0%|          | 0/1 [00:00<?, ?it/s]Val step 1/1
#
#
# Epoch 13/24 | train_loss=0.1481 | train_c4_acc=0.9986 | val_loss=0.0234 | val_c4_acc=1.0000 | val_c4_f1=1.0000
# No val F1 improvement for 2 epoch(s)
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=1.0000, loss=0.1466, lr=2.93e-04]Train step 1/4 | loss=0.1466 | c4_acc=1.0000 | parts={'loss_video': 0.0004902593791484833, 'loss_audio': 0.007388690020889044, 'loss_four': 0.0031573884189128876, 'loss_contrast': 2.7104744911193848}
# /kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=1.0000, loss=0.1493, lr=2.82e-04]
# Train:  50%|█████     | 2/4 [00:00<00:00, 18.55it/s, c4_acc=1.0000, loss=0.1493, lr=2.82e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  50%|█████     | 2/4 [00:00<00:00, 18.55it/s, c4_acc=1.0000, loss=0.1438, lr=2.71e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  50%|█████     | 2/4 [00:00<00:00, 18.55it/s, c4_acc=1.0000, loss=0.1274, lr=2.59e-04]Train step 4/4 | loss=0.1274 | c4_acc=1.0000 | parts={'loss_video': 0.0004938379861414433, 'loss_audio': 0.005025413818657398, 'loss_four': 0.0012234870810061693, 'loss_contrast': 2.4134082794189453}
#
#
#
# Val:   0%|          | 0/1 [00:00<?, ?it/s]Val step 1/1
#
#
# Epoch 14/24 | train_loss=0.1426 | train_c4_acc=1.0000 | val_loss=0.0265 | val_c4_acc=1.0000 | val_c4_f1=1.0000
# No val F1 improvement for 3 epoch(s)
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=1.0000, loss=0.1380, lr=2.48e-04]Train step 1/4 | loss=0.1380 | c4_acc=1.0000 | parts={'loss_video': 0.0005078744143247604, 'loss_audio': 0.005455872043967247, 'loss_four': 0.001831966103054583, 'loss_contrast': 2.604106903076172}
# /kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=1.0000, loss=0.1372, lr=2.37e-04]
# Train:  50%|█████     | 2/4 [00:00<00:00, 19.42it/s, c4_acc=1.0000, loss=0.1372, lr=2.37e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  50%|█████     | 2/4 [00:00<00:00, 19.42it/s, c4_acc=1.0000, loss=0.1443, lr=2.27e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  50%|█████     | 2/4 [00:00<00:00, 19.42it/s, c4_acc=1.0000, loss=0.1212, lr=2.16e-04]Train step 4/4 | loss=0.1212 | c4_acc=1.0000 | parts={'loss_video': 0.0004800701281055808, 'loss_audio': 0.005945682525634766, 'loss_four': 0.002471639309078455, 'loss_contrast': 2.245987892150879}
#
#
#
# Val:   0%|          | 0/1 [00:00<?, ?it/s]Val step 1/1
#
#
# Epoch 15/24 | train_loss=0.1360 | train_c4_acc=1.0000 | val_loss=0.0250 | val_c4_acc=1.0000 | val_c4_f1=1.0000
# No val F1 improvement for 4 epoch(s)
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=1.0000, loss=0.1459, lr=2.06e-04]Train step 1/4 | loss=0.1459 | c4_acc=1.0000 | parts={'loss_video': 0.0004648963513318449, 'loss_audio': 0.013992316089570522, 'loss_four': 0.0064812577329576015, 'loss_contrast': 2.4994895458221436}
# /kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=1.0000, loss=0.1337, lr=1.95e-04]
# Train:  50%|█████     | 2/4 [00:00<00:00, 19.49it/s, c4_acc=1.0000, loss=0.1337, lr=1.95e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  50%|█████     | 2/4 [00:00<00:00, 19.49it/s, c4_acc=1.0000, loss=0.1274, lr=1.85e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  50%|█████     | 2/4 [00:00<00:00, 19.49it/s, c4_acc=1.0000, loss=0.1178, lr=1.75e-04]Train step 4/4 | loss=0.1178 | c4_acc=1.0000 | parts={'loss_video': 0.0004463330842554569, 'loss_audio': 0.0069420225918293, 'loss_four': 0.0022594586480408907, 'loss_contrast': 2.1629247665405273}
#
#
#
# Val:   0%|          | 0/1 [00:00<?, ?it/s]Val step 1/1
#
#
# Epoch 16/24 | train_loss=0.1320 | train_c4_acc=1.0000 | val_loss=0.0198 | val_c4_acc=1.0000 | val_c4_f1=1.0000
# No val F1 improvement for 5 epoch(s)
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=1.0000, loss=0.1284, lr=1.65e-04]Train step 1/4 | loss=0.1284 | c4_acc=1.0000 | parts={'loss_video': 0.0004729845968540758, 'loss_audio': 0.004692172631621361, 'loss_four': 0.0032859407365322113, 'loss_contrast': 2.398991823196411}
# /kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=1.0000, loss=0.1319, lr=1.56e-04]
# Train:  50%|█████     | 2/4 [00:00<00:00, 18.68it/s, c4_acc=1.0000, loss=0.1319, lr=1.56e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  50%|█████     | 2/4 [00:00<00:00, 18.68it/s, c4_acc=1.0000, loss=0.1245, lr=1.46e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  50%|█████     | 2/4 [00:00<00:00, 18.68it/s, c4_acc=1.0000, loss=0.1188, lr=1.37e-04]Train step 4/4 | loss=0.1188 | c4_acc=1.0000 | parts={'loss_video': 0.0005076781962998211, 'loss_audio': 0.007176550105214119, 'loss_four': 0.0025517011526972055, 'loss_contrast': 2.1719532012939453}
#
#
#
# Val:   0%|          | 0/1 [00:00<?, ?it/s]Val step 1/1
#
#
# Epoch 17/24 | train_loss=0.1263 | train_c4_acc=1.0000 | val_loss=0.0182 | val_c4_acc=1.0000 | val_c4_f1=1.0000
# No val F1 improvement for 6 epoch(s)
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=1.0000, loss=0.1310, lr=1.28e-04]Train step 1/4 | loss=0.1310 | c4_acc=1.0000 | parts={'loss_video': 0.00048226365470327437, 'loss_audio': 0.008574499748647213, 'loss_four': 0.005194950848817825, 'loss_contrast': 2.3346736431121826}
# /kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=1.0000, loss=0.1284, lr=1.19e-04]
# Train:  50%|█████     | 2/4 [00:00<00:00, 19.46it/s, c4_acc=1.0000, loss=0.1284, lr=1.19e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  50%|█████     | 2/4 [00:00<00:00, 19.46it/s, c4_acc=1.0000, loss=0.1247, lr=1.11e-04]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  50%|█████     | 2/4 [00:00<00:00, 19.46it/s, c4_acc=1.0000, loss=0.1138, lr=1.03e-04]Train step 4/4 | loss=0.1138 | c4_acc=1.0000 | parts={'loss_video': 0.000469529622932896, 'loss_audio': 0.0058186594396829605, 'loss_four': 0.0017060614190995693, 'loss_contrast': 2.1163330078125}
#
#
#
# Val:   0%|          | 0/1 [00:00<?, ?it/s]Val step 1/1
#
#
# Epoch 18/24 | train_loss=0.1251 | train_c4_acc=1.0000 | val_loss=0.0177 | val_c4_acc=1.0000 | val_c4_f1=1.0000
# No val F1 improvement for 7 epoch(s)
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=1.0000, loss=0.1216, lr=9.45e-05]Train step 1/4 | loss=0.1216 | c4_acc=1.0000 | parts={'loss_video': 0.0004888356779702008, 'loss_audio': 0.005401135887950659, 'loss_four': 0.0019281283020973206, 'loss_contrast': 2.276299476623535}
# /kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:   0%|          | 0/4 [00:00<?, ?it/s, c4_acc=1.0000, loss=0.1248, lr=8.69e-05]
# Train:  50%|█████     | 2/4 [00:00<00:00, 19.41it/s, c4_acc=1.0000, loss=0.1248, lr=8.69e-05]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  50%|█████     | 2/4 [00:00<00:00, 19.41it/s, c4_acc=1.0000, loss=0.1272, lr=7.94e-05]/kaggle/working/train_fusion_two_head_multimodal.py:371: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=device.type == "cuda"):
#
# Train:  50%|█████     | 2/4 [00:00<00:00, 19.41it/s, c4_acc=1.0000, loss=0.1100, lr=7.23e-05]Train step 4/4 | loss=0.1100 | c4_acc=1.0000 | parts={'loss_video': 0.0005132619407959282, 'loss_audio': 0.004433535039424896, 'loss_four': 0.0016454680589959025, 'loss_contrast': 2.068110466003418}
#
#
#
# Val:   0%|          | 0/1 [00:00<?, ?it/s]Val step 1/1
#
#
# Epoch 19/24 | train_loss=0.1215 | train_c4_acc=1.0000 | val_loss=0.0178 | val_c4_acc=1.0000 | val_c4_f1=1.0000
# No val F1 improvement for 8 epoch(s)
# Early stopping triggered.
# Loaded best checkpoint from epoch 11
# Evaluating on test split...
#
# Test:   0%|          | 0/1 [00:00<?, ?it/s]Test step 1/1
#
#
# === Test Metrics ===
# {
#   "loss": 0.33649927377700806,
#   "video_head_accuracy": 0.9838709677419355,
#   "audio_head_accuracy": 0.967741935483871,
#   "four_class_accuracy": 0.967741935483871,
#   "four_class_f1_macro": 0.967683059430767,
#   "four_class_confusion_matrix": [
#     [
#       28,
#       1,
#       2,
#       0
#     ],
#     [
#       0,
#       31,
#       0,
#       0
#     ],
#     [
#       0,
#       0,
#       31,
#       0
#     ],
#     [
#       0,
#       0,
#       1,
#       30
#     ]
#   ],
#   "best_val_f1_macro": 1.0,
#   "best_epoch": 11,
#   "class_names": [
#     "FF",
#     "FR",
#     "RF",
#     "RR"
#   ]
# }
# Saved: /kaggle/working/outputs_fusion_two_head/test_metrics.pt
# Saved: /kaggle/working/outputs_fusion_two_head/test_metrics.json
# Command finished in 12.1s with exit code 0

# %% [markdown]
# ## Evaluate Fusion Results
#
# Display test metrics for:
# - Video authenticity head accuracy
# - Audio authenticity head accuracy
# - Four-class (FF/FR/RF/RR) accuracy, macro F1, and confusion matrix

# %%
fusion_out_dir = Path(FUSION_CONFIG["output_dir"])
fusion_metrics_path = fusion_out_dir / "test_metrics.pt"
fusion_json_path = fusion_out_dir / "test_metrics.json"

if fusion_metrics_path.exists():
    fusion_metrics = torch.load(fusion_metrics_path, map_location="cpu")
    print("=== Two-Head Multimodal Test Results ===")
    print(f"Video Head Accuracy: {fusion_metrics['video_head_accuracy']:.4f}")
    print(f"Audio Head Accuracy: {fusion_metrics['audio_head_accuracy']:.4f}")
    print(f"4-Class Accuracy: {fusion_metrics['four_class_accuracy']:.4f}")
    print(f"4-Class Macro F1: {fusion_metrics['four_class_f1_macro']:.4f}")
    print(f"Best Val Macro F1: {fusion_metrics.get('best_val_f1_macro', float('nan')):.4f}")
    print(f"Best Epoch: {fusion_metrics.get('best_epoch', -1)}")

    print("\n4-Class Labels Order:", fusion_metrics.get("class_names", ["FF", "FR", "RF", "RR"]))
    print("4-Class Confusion Matrix:")
    cm = np.array(fusion_metrics["four_class_confusion_matrix"])
    print(cm)

    if fusion_json_path.exists():
        print("\nJSON metrics path:", fusion_json_path)
else:
    print("Test metrics not found. Run fusion training cell first.")
# Out:
# === Two-Head Multimodal Test Results ===
# Video Head Accuracy: 0.9839
# Audio Head Accuracy: 0.9677
# 4-Class Accuracy: 0.9677
# 4-Class Macro F1: 0.9677
# Best Val Macro F1: 1.0000
# Best Epoch: 11
#
# 4-Class Labels Order: ['FF', 'FR', 'RF', 'RR']
# 4-Class Confusion Matrix:
# [[28  1  2  0]
#  [ 0 31  0  0]
#  [ 0  0 31  0]
#  [ 0  0  1 30]]
#
# JSON metrics path: /kaggle/working/outputs_fusion_two_head/test_metrics.json

# %%
import zipfile


def zip_directory(source_dir: Path, zip_path: Path) -> Path:
    source_dir = Path(source_dir)
    zip_path = Path(zip_path)
    if not source_dir.exists():
        raise FileNotFoundError(f"Source directory not found: {source_dir}")
    if zip_path.exists():
        zip_path.unlink()
    archive_base = zip_path.with_suffix("")
    shutil.make_archive(str(archive_base), "zip", root_dir=source_dir.parent, base_dir=source_dir.name)
    return zip_path


def zip_multiple_directories(zip_path: Path, directories) -> Path:
    zip_path = Path(zip_path)
    if zip_path.exists():
        zip_path.unlink()
    with zipfile.ZipFile(zip_path, "w", compression=zipfile.ZIP_DEFLATED) as archive:
        for directory in directories:
            directory = Path(directory)
            if not directory.exists():
                continue
            for file_path in sorted(directory.rglob("*")):
                if file_path.is_file():
                    arcname = (Path(directory.name) / file_path.relative_to(directory)).as_posix()
                    archive.write(file_path, arcname=arcname)
    return zip_path


artifact_roots = [out_dir, audio_out_dir, fusion_out_dir]
manifest = []
for root in artifact_roots:
    if root.exists():
        files = sorted(root.glob("*"))
        print(f"Artifact folder: {root} ({len(files)} files)")
        for p in files:
            size_mb = round(p.stat().st_size / (1024 ** 2), 4)
            print(f" - {p.name} | {size_mb} MB")
            manifest.append({"folder": str(root), "file": p.name, "size_mb": size_mb})
    else:
        print(f"Artifact folder missing: {root}")

sample_manifest_path = SAMPLED_MANIFEST_PATH if SAMPLED_MANIFEST_PATH.exists() else None
manifest_path = Path(CONFIG["working_dir"]) / "artifact_manifest.json"
manifest_path.write_text(json.dumps(manifest, indent=2))

video_zip = zip_directory(out_dir, Path(CONFIG["working_dir"]) / "video_outputs.zip") if out_dir.exists() else None
audio_zip = zip_directory(audio_out_dir, Path(CONFIG["working_dir"]) / "audio_outputs.zip") if audio_out_dir.exists() else None
fusion_zip = zip_directory(fusion_out_dir, Path(CONFIG["working_dir"]) / "fusion_outputs.zip") if fusion_out_dir.exists() else None
bundle_items = [root for root in artifact_roots if root.exists()]
if sample_manifest_path is not None:
    bundle_items.append(sample_manifest_path)
combined_zip = Path(CONFIG["working_dir"]) / "all_deepfake_outputs.zip"
if bundle_items:
    if combined_zip.exists():
        combined_zip.unlink()
    with zipfile.ZipFile(combined_zip, "w", compression=zipfile.ZIP_DEFLATED) as archive:
        for item in bundle_items:
            item = Path(item)
            if item.is_dir():
                for file_path in sorted(item.rglob("*")):
                    if file_path.is_file():
                        arcname = (Path(item.name) / file_path.relative_to(item)).as_posix()
                        archive.write(file_path, arcname=arcname)
            else:
                archive.write(item, arcname=(Path("metadata") / item.name).as_posix())

bundle_manifest = {
    "video_zip": str(video_zip) if video_zip else None,
    "audio_zip": str(audio_zip) if audio_zip else None,
    "fusion_zip": str(fusion_zip) if fusion_zip else None,
    "combined_zip": str(combined_zip) if combined_zip.exists() else None,
    "manifest_path": str(manifest_path),
    "sample_manifest_path": str(sample_manifest_path) if sample_manifest_path else None,
}
(Path(CONFIG["working_dir"]) / "download_index.json").write_text(json.dumps(bundle_manifest, indent=2))
print("Saved artifact manifest to:", manifest_path)
print("Download bundle index saved to:", Path(CONFIG["working_dir"]) / "download_index.json")
print("Available archives:")
for key, value in bundle_manifest.items():
    if value:
        print(f" - {key}: {value}")
# Out:
# Artifact folder: /kaggle/working/outputs (5 files)
#  - convnext_tiny_deepfake_best.pt | 313.2003 MB
#  - metrics.pt | 0.0013 MB
#  - test_embeddings.pt | 0.3835 MB
#  - train_embeddings.pt | 2.2391 MB
#  - val_embeddings.pt | 0.3712 MB
# Artifact folder: /kaggle/working/outputs_audio (5 files)
#  - metrics.pt | 0.0013 MB
#  - test_embeddings.pt | 0.3835 MB
#  - train_embeddings.pt | 2.2391 MB
#  - val_embeddings.pt | 0.3712 MB
#  - wav2vec2_base_deepfake_best.pt | 362.3516 MB
# Artifact folder: /kaggle/working/outputs_fusion_two_head (4 files)
#  - best_checkpoint.pt | 12.1218 MB
#  - last_checkpoint.pt | 12.1218 MB
#  - test_metrics.json | 0.0005 MB
#  - test_metrics.pt | 0.0015 MB
# Saved artifact manifest to: /kaggle/working/artifact_manifest.json
# Download bundle index saved to: /kaggle/working/download_index.json
# Available archives:
#  - video_zip: /kaggle/working/video_outputs.zip
#  - audio_zip: /kaggle/working/audio_outputs.zip
#  - fusion_zip: /kaggle/working/fusion_outputs.zip
#  - combined_zip: /kaggle/working/all_deepfake_outputs.zip
#  - manifest_path: /kaggle/working/artifact_manifest.json
#  - sample_manifest_path: /kaggle/working/sampled_uniform_970_videos/sample_manifest.json

# %% [markdown]
# ## Single Video Inference (4-Class)
#
# Run this section after training (or after downloading trained checkpoints). It predicts:
# - Video head: real/fake video
# - Audio head: real/fake audio
# - Final 4-class label: FF, FR, RF, RR

# %%
INFER_CONFIG = {
    "script_name": "infer_two_head_multimodal.py",
    "video_path": "/kaggle/input/datasets/mahirashab/fakebdteen/FakeBDTeen/Boys/Fake_video + Real_Audio/Bangla/B05/FR1B05_09.mp4",  # set to your uploaded video path
    "fusion_checkpoint": str(Path(FUSION_CONFIG["output_dir"]) / "best_checkpoint.pt"),
    "output_json": "/kaggle/working/single_video_prediction.json",
    "num_frames": CONFIG.get("num_frames", 8),
    "image_size": CONFIG.get("image_size", 224),
    "clip_seconds": CONFIG.get("clip_seconds", 5),
    "audio_duration_sec": 10,
    "audio_sr": 16000,
    "ffmpeg_timeout": 45,
    "force_cpu": False,
}

print("Inference config:")
print(json.dumps(INFER_CONFIG, indent=2))
# Out:
# Inference config:
# {
#   "script_name": "infer_two_head_multimodal.py",
#   "video_path": "/kaggle/input/datasets/mahirashab/fakebdteen/FakeBDTeen/Boys/Fake_video + Real_Audio/Bangla/B05/FR1B05_09.mp4",
#   "fusion_checkpoint": "/kaggle/working/outputs_fusion_two_head/best_checkpoint.pt",
#   "output_json": "/kaggle/working/single_video_prediction.json",
#   "num_frames": 8,
#   "image_size": 224,
#   "clip_seconds": 6,
#   "audio_duration_sec": 10,
#   "audio_sr": 16000,
#   "ffmpeg_timeout": 45,
#   "force_cpu": false
# }

# %%
infer_working_script = Path(CONFIG["working_dir"]) / INFER_CONFIG["script_name"]

infer_script_candidates = list(Path("/kaggle/input").rglob(INFER_CONFIG["script_name"]))
if infer_script_candidates:
    latest_script = max(infer_script_candidates, key=lambda p: p.stat().st_mtime)
    shutil.copy2(latest_script, infer_working_script)
    print("Refreshed inference script from:", latest_script)
elif not infer_working_script.exists():
    raise FileNotFoundError(f"{INFER_CONFIG['script_name']} not found in /kaggle/input")

print("Inference script path:", infer_working_script)
print("Script exists:", infer_working_script.exists())
# Out:
# Refreshed inference script from: /kaggle/input/datasets/mahirashab/essential-scripts/infer_two_head_multimodal.py
# Inference script path: /kaggle/working/infer_two_head_multimodal.py
# Script exists: True

# %%
video_path = Path(INFER_CONFIG["video_path"])
checkpoint_path = Path(INFER_CONFIG["fusion_checkpoint"])

if not video_path.exists():
    print("Input video not found:", video_path)
    print("Upload or copy a video and set INFER_CONFIG['video_path'] correctly.")
elif not checkpoint_path.exists():
    print("Fusion checkpoint not found:", checkpoint_path)
    print("Run fusion training first or point to an existing checkpoint.")
else:
    infer_cmd = [
        "python", "-u", "/kaggle/working/infer_two_head_multimodal.py",
        "--video-path", str(video_path),
        "--fusion-checkpoint", str(checkpoint_path),
        "--output-json", INFER_CONFIG["output_json"],
        "--num-frames", str(INFER_CONFIG["num_frames"]),
        "--image-size", str(INFER_CONFIG["image_size"]),
        "--clip-seconds", str(INFER_CONFIG["clip_seconds"]),
        "--audio-duration-sec", str(INFER_CONFIG["audio_duration_sec"]),
        "--audio-sr", str(INFER_CONFIG["audio_sr"]),
        "--ffmpeg-timeout", str(INFER_CONFIG["ffmpeg_timeout"]),
    ]
    if INFER_CONFIG.get("force_cpu", False):
        infer_cmd.append("--force-cpu")

    run_streaming_command(infer_cmd)

    out_json = Path(INFER_CONFIG["output_json"])
    if out_json.exists():
        print("\nSaved prediction JSON:", out_json)
        print(out_json.read_text())
# Out:
# Running: python -u /kaggle/working/infer_two_head_multimodal.py --video-path /kaggle/input/datasets/mahirashab/fakebdteen/FakeBDTeen/Boys/Fake_video + Real_Audio/Bangla/B05/FR1B05_09.mp4 --fusion-checkpoint /kaggle/working/outputs_fusion_two_head/best_checkpoint.pt --output-json /kaggle/working/single_video_prediction.json --num-frames 8 --image-size 224 --clip-seconds 6 --audio-duration-sec 10 --audio-sr 16000 --ffmpeg-timeout 45
# Using device: cuda
# Loading pretrained backbones...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#
# Loading weights:   0%|          | 0/211 [00:00<?, ?it/s]
# Loading weights:   0%|          | 1/211 [00:00<00:00, 10512.04it/s, Materializing param=encoder.layer_norm.bias]
# Loading weights:   0%|          | 1/211 [00:00<00:00, 4766.25it/s, Materializing param=encoder.layer_norm.bias]
# Loading weights:   1%|          | 2/211 [00:00<00:00, 4531.93it/s, Materializing param=encoder.layer_norm.weight]
# Loading weights:   1%|          | 2/211 [00:00<00:00, 962.55it/s, Materializing param=encoder.layer_norm.weight]
# Loading weights:   1%|▏         | 3/211 [00:00<00:00, 925.08it/s, Materializing param=encoder.layers.0.attention.k_proj.bias]
# Loading weights:   1%|▏         | 3/211 [00:00<00:00, 761.95it/s, Materializing param=encoder.layers.0.attention.k_proj.bias]
# Loading weights:   2%|▏         | 4/211 [00:00<00:00, 896.46it/s, Materializing param=encoder.layers.0.attention.k_proj.weight]
# Loading weights:   2%|▏         | 4/211 [00:00<00:00, 821.97it/s, Materializing param=encoder.layers.0.attention.k_proj.weight]
# Loading weights:   2%|▏         | 5/211 [00:00<00:00, 890.40it/s, Materializing param=encoder.layers.0.attention.out_proj.bias]
# Loading weights:   2%|▏         | 5/211 [00:00<00:00, 850.08it/s, Materializing param=encoder.layers.0.attention.out_proj.bias]
# Loading weights:   3%|▎         | 6/211 [00:00<00:00, 971.99it/s, Materializing param=encoder.layers.0.attention.out_proj.weight]
# Loading weights:   3%|▎         | 6/211 [00:00<00:00, 960.49it/s, Materializing param=encoder.layers.0.attention.out_proj.weight]
# Loading weights:   3%|▎         | 7/211 [00:00<00:00, 1100.45it/s, Materializing param=encoder.layers.0.attention.q_proj.bias]
# Loading weights:   3%|▎         | 7/211 [00:00<00:00, 1090.56it/s, Materializing param=encoder.layers.0.attention.q_proj.bias]
# Loading weights:   4%|▍         | 8/211 [00:00<00:00, 1227.93it/s, Materializing param=encoder.layers.0.attention.q_proj.weight]
# Loading weights:   4%|▍         | 8/211 [00:00<00:00, 1217.95it/s, Materializing param=encoder.layers.0.attention.q_proj.weight]
# Loading weights:   4%|▍         | 9/211 [00:00<00:00, 1337.99it/s, Materializing param=encoder.layers.0.attention.v_proj.bias]
# Loading weights:   4%|▍         | 9/211 [00:00<00:00, 1325.21it/s, Materializing param=encoder.layers.0.attention.v_proj.bias]
# Loading weights:   5%|▍         | 10/211 [00:00<00:00, 1451.77it/s, Materializing param=encoder.layers.0.attention.v_proj.weight]
# Loading weights:   5%|▍         | 10/211 [00:00<00:00, 1441.09it/s, Materializing param=encoder.layers.0.attention.v_proj.weight]
# Loading weights:   5%|▌         | 11/211 [00:00<00:00, 1562.97it/s, Materializing param=encoder.layers.0.feed_forward.intermediate_dense.bias]
# Loading weights:   5%|▌         | 11/211 [00:00<00:00, 1551.41it/s, Materializing param=encoder.layers.0.feed_forward.intermediate_dense.bias]
# Loading weights:   6%|▌         | 12/211 [00:00<00:00, 1670.82it/s, Materializing param=encoder.layers.0.feed_forward.intermediate_dense.weight]
# Loading weights:   6%|▌         | 12/211 [00:00<00:00, 1658.76it/s, Materializing param=encoder.layers.0.feed_forward.intermediate_dense.weight]
# Loading weights:   6%|▌         | 13/211 [00:00<00:00, 1774.93it/s, Materializing param=encoder.layers.0.feed_forward.output_dense.bias]
# Loading weights:   6%|▌         | 13/211 [00:00<00:00, 1762.54it/s, Materializing param=encoder.layers.0.feed_forward.output_dense.bias]
# Loading weights:   7%|▋         | 14/211 [00:00<00:00, 1874.31it/s, Materializing param=encoder.layers.0.feed_forward.output_dense.weight]
# Loading weights:   7%|▋         | 14/211 [00:00<00:00, 1861.42it/s, Materializing param=encoder.layers.0.feed_forward.output_dense.weight]
# Loading weights:   7%|▋         | 15/211 [00:00<00:00, 1966.26it/s, Materializing param=encoder.layers.0.final_layer_norm.bias]
# Loading weights:   7%|▋         | 15/211 [00:00<00:00, 1951.32it/s, Materializing param=encoder.layers.0.final_layer_norm.bias]
# Loading weights:   8%|▊         | 16/211 [00:00<00:00, 2056.22it/s, Materializing param=encoder.layers.0.final_layer_norm.weight]
# Loading weights:   8%|▊         | 16/211 [00:00<00:00, 2042.83it/s, Materializing param=encoder.layers.0.final_layer_norm.weight]
# Loading weights:   8%|▊         | 17/211 [00:00<00:00, 2146.33it/s, Materializing param=encoder.layers.0.layer_norm.bias]
# Loading weights:   8%|▊         | 17/211 [00:00<00:00, 2133.10it/s, Materializing param=encoder.layers.0.layer_norm.bias]
# Loading weights:   9%|▊         | 18/211 [00:00<00:00, 2232.27it/s, Materializing param=encoder.layers.0.layer_norm.weight]
# Loading weights:   9%|▊         | 18/211 [00:00<00:00, 2218.62it/s, Materializing param=encoder.layers.0.layer_norm.weight]
# Loading weights:   9%|▉         | 19/211 [00:00<00:00, 2317.36it/s, Materializing param=encoder.layers.1.attention.k_proj.bias]
# Loading weights:   9%|▉         | 19/211 [00:00<00:00, 2303.70it/s, Materializing param=encoder.layers.1.attention.k_proj.bias]
# Loading weights:   9%|▉         | 20/211 [00:00<00:00, 2399.28it/s, Materializing param=encoder.layers.1.attention.k_proj.weight]
# Loading weights:   9%|▉         | 20/211 [00:00<00:00, 2385.16it/s, Materializing param=encoder.layers.1.attention.k_proj.weight]
# Loading weights:  10%|▉         | 21/211 [00:00<00:00, 2476.74it/s, Materializing param=encoder.layers.1.attention.out_proj.bias]
# Loading weights:  10%|▉         | 21/211 [00:00<00:00, 2462.13it/s, Materializing param=encoder.layers.1.attention.out_proj.bias]
# Loading weights:  10%|█         | 22/211 [00:00<00:00, 2548.81it/s, Materializing param=encoder.layers.1.attention.out_proj.weight]
# Loading weights:  10%|█         | 22/211 [00:00<00:00, 2533.28it/s, Materializing param=encoder.layers.1.attention.out_proj.weight]
# Loading weights:  11%|█         | 23/211 [00:00<00:00, 2620.37it/s, Materializing param=encoder.layers.1.attention.q_proj.bias]
# Loading weights:  11%|█         | 23/211 [00:00<00:00, 2605.51it/s, Materializing param=encoder.layers.1.attention.q_proj.bias]
# Loading weights:  11%|█▏        | 24/211 [00:00<00:00, 2691.96it/s, Materializing param=encoder.layers.1.attention.q_proj.weight]
# Loading weights:  11%|█▏        | 24/211 [00:00<00:00, 2677.14it/s, Materializing param=encoder.layers.1.attention.q_proj.weight]
# Loading weights:  12%|█▏        | 25/211 [00:00<00:00, 2759.92it/s, Materializing param=encoder.layers.1.attention.v_proj.bias]
# Loading weights:  12%|█▏        | 25/211 [00:00<00:00, 2745.11it/s, Materializing param=encoder.layers.1.attention.v_proj.bias]
# Loading weights:  12%|█▏        | 26/211 [00:00<00:00, 2828.18it/s, Materializing param=encoder.layers.1.attention.v_proj.weight]
# Loading weights:  12%|█▏        | 26/211 [00:00<00:00, 2812.79it/s, Materializing param=encoder.layers.1.attention.v_proj.weight]
# Loading weights:  13%|█▎        | 27/211 [00:00<00:00, 2893.36it/s, Materializing param=encoder.layers.1.feed_forward.intermediate_dense.bias]
# Loading weights:  13%|█▎        | 27/211 [00:00<00:00, 2877.48it/s, Materializing param=encoder.layers.1.feed_forward.intermediate_dense.bias]
# Loading weights:  13%|█▎        | 28/211 [00:00<00:00, 2955.59it/s, Materializing param=encoder.layers.1.feed_forward.intermediate_dense.weight]
# Loading weights:  13%|█▎        | 28/211 [00:00<00:00, 2939.76it/s, Materializing param=encoder.layers.1.feed_forward.intermediate_dense.weight]
# Loading weights:  14%|█▎        | 29/211 [00:00<00:00, 3012.55it/s, Materializing param=encoder.layers.1.feed_forward.output_dense.bias]
# Loading weights:  14%|█▎        | 29/211 [00:00<00:00, 2995.41it/s, Materializing param=encoder.layers.1.feed_forward.output_dense.bias]
# Loading weights:  14%|█▍        | 30/211 [00:00<00:00, 3068.25it/s, Materializing param=encoder.layers.1.feed_forward.output_dense.weight]
# Loading weights:  14%|█▍        | 30/211 [00:00<00:00, 3052.03it/s, Materializing param=encoder.layers.1.feed_forward.output_dense.weight]
# Loading weights:  15%|█▍        | 31/211 [00:00<00:00, 3125.34it/s, Materializing param=encoder.layers.1.final_layer_norm.bias]
# Loading weights:  15%|█▍        | 31/211 [00:00<00:00, 3109.57it/s, Materializing param=encoder.layers.1.final_layer_norm.bias]
# Loading weights:  15%|█▌        | 32/211 [00:00<00:00, 3180.36it/s, Materializing param=encoder.layers.1.final_layer_norm.weight]
# Loading weights:  15%|█▌        | 32/211 [00:00<00:00, 3164.99it/s, Materializing param=encoder.layers.1.final_layer_norm.weight]
# Loading weights:  16%|█▌        | 33/211 [00:00<00:00, 3236.95it/s, Materializing param=encoder.layers.1.layer_norm.bias]
# Loading weights:  16%|█▌        | 33/211 [00:00<00:00, 3221.73it/s, Materializing param=encoder.layers.1.layer_norm.bias]
# Loading weights:  16%|█▌        | 34/211 [00:00<00:00, 3292.84it/s, Materializing param=encoder.layers.1.layer_norm.weight]
# Loading weights:  16%|█▌        | 34/211 [00:00<00:00, 3277.70it/s, Materializing param=encoder.layers.1.layer_norm.weight]
# Loading weights:  17%|█▋        | 35/211 [00:00<00:00, 3347.64it/s, Materializing param=encoder.layers.2.attention.k_proj.bias]
# Loading weights:  17%|█▋        | 35/211 [00:00<00:00, 3332.29it/s, Materializing param=encoder.layers.2.attention.k_proj.bias]
# Loading weights:  17%|█▋        | 36/211 [00:00<00:00, 3388.35it/s, Materializing param=encoder.layers.2.attention.k_proj.weight]
# Loading weights:  17%|█▋        | 36/211 [00:00<00:00, 3365.84it/s, Materializing param=encoder.layers.2.attention.k_proj.weight]
# Loading weights:  18%|█▊        | 37/211 [00:00<00:00, 3416.76it/s, Materializing param=encoder.layers.2.attention.out_proj.bias]
# Loading weights:  18%|█▊        | 37/211 [00:00<00:00, 3397.76it/s, Materializing param=encoder.layers.2.attention.out_proj.bias]
# Loading weights:  18%|█▊        | 38/211 [00:00<00:00, 3457.57it/s, Materializing param=encoder.layers.2.attention.out_proj.weight]
# Loading weights:  18%|█▊        | 38/211 [00:00<00:00, 3437.36it/s, Materializing param=encoder.layers.2.attention.out_proj.weight]
# Loading weights:  18%|█▊        | 39/211 [00:00<00:00, 3496.30it/s, Materializing param=encoder.layers.2.attention.q_proj.bias]
# Loading weights:  18%|█▊        | 39/211 [00:00<00:00, 3478.75it/s, Materializing param=encoder.layers.2.attention.q_proj.bias]
# Loading weights:  19%|█▉        | 40/211 [00:00<00:00, 3537.63it/s, Materializing param=encoder.layers.2.attention.q_proj.weight]
# Loading weights:  19%|█▉        | 40/211 [00:00<00:00, 3520.41it/s, Materializing param=encoder.layers.2.attention.q_proj.weight]
# Loading weights:  19%|█▉        | 41/211 [00:00<00:00, 3578.31it/s, Materializing param=encoder.layers.2.attention.v_proj.bias]
# Loading weights:  19%|█▉        | 41/211 [00:00<00:00, 3560.97it/s, Materializing param=encoder.layers.2.attention.v_proj.bias]
# Loading weights:  20%|█▉        | 42/211 [00:00<00:00, 3613.11it/s, Materializing param=encoder.layers.2.attention.v_proj.weight]
# Loading weights:  20%|█▉        | 42/211 [00:00<00:00, 3595.34it/s, Materializing param=encoder.layers.2.attention.v_proj.weight]
# Loading weights:  20%|██        | 43/211 [00:00<00:00, 3649.29it/s, Materializing param=encoder.layers.2.feed_forward.intermediate_dense.bias]
# Loading weights:  20%|██        | 43/211 [00:00<00:00, 3630.99it/s, Materializing param=encoder.layers.2.feed_forward.intermediate_dense.bias]
# Loading weights:  21%|██        | 44/211 [00:00<00:00, 3681.20it/s, Materializing param=encoder.layers.2.feed_forward.intermediate_dense.weight]
# Loading weights:  21%|██        | 44/211 [00:00<00:00, 3658.06it/s, Materializing param=encoder.layers.2.feed_forward.intermediate_dense.weight]
# Loading weights:  21%|██▏       | 45/211 [00:00<00:00, 3714.04it/s, Materializing param=encoder.layers.2.feed_forward.output_dense.bias]
# Loading weights:  21%|██▏       | 45/211 [00:00<00:00, 3698.61it/s, Materializing param=encoder.layers.2.feed_forward.output_dense.bias]
# Loading weights:  22%|██▏       | 46/211 [00:00<00:00, 3754.02it/s, Materializing param=encoder.layers.2.feed_forward.output_dense.weight]
# Loading weights:  22%|██▏       | 46/211 [00:00<00:00, 3732.96it/s, Materializing param=encoder.layers.2.feed_forward.output_dense.weight]
# Loading weights:  22%|██▏       | 47/211 [00:00<00:00, 3786.13it/s, Materializing param=encoder.layers.2.final_layer_norm.bias]
# Loading weights:  22%|██▏       | 47/211 [00:00<00:00, 3770.27it/s, Materializing param=encoder.layers.2.final_layer_norm.bias]
# Loading weights:  23%|██▎       | 48/211 [00:00<00:00, 3823.00it/s, Materializing param=encoder.layers.2.final_layer_norm.weight]
# Loading weights:  23%|██▎       | 48/211 [00:00<00:00, 3796.25it/s, Materializing param=encoder.layers.2.final_layer_norm.weight]
# Loading weights:  23%|██▎       | 49/211 [00:00<00:00, 3833.99it/s, Materializing param=encoder.layers.2.layer_norm.bias]
# Loading weights:  23%|██▎       | 49/211 [00:00<00:00, 3817.82it/s, Materializing param=encoder.layers.2.layer_norm.bias]
# Loading weights:  24%|██▎       | 50/211 [00:00<00:00, 3867.86it/s, Materializing param=encoder.layers.2.layer_norm.weight]
# Loading weights:  24%|██▎       | 50/211 [00:00<00:00, 3852.37it/s, Materializing param=encoder.layers.2.layer_norm.weight]
# Loading weights:  24%|██▍       | 51/211 [00:00<00:00, 3892.94it/s, Materializing param=encoder.layers.3.attention.k_proj.bias]
# Loading weights:  24%|██▍       | 51/211 [00:00<00:00, 3876.23it/s, Materializing param=encoder.layers.3.attention.k_proj.bias]
# Loading weights:  25%|██▍       | 52/211 [00:00<00:00, 3922.52it/s, Materializing param=encoder.layers.3.attention.k_proj.weight]
# Loading weights:  25%|██▍       | 52/211 [00:00<00:00, 3905.94it/s, Materializing param=encoder.layers.3.attention.k_proj.weight]
# Loading weights:  25%|██▌       | 53/211 [00:00<00:00, 3950.56it/s, Materializing param=encoder.layers.3.attention.out_proj.bias]
# Loading weights:  25%|██▌       | 53/211 [00:00<00:00, 3935.25it/s, Materializing param=encoder.layers.3.attention.out_proj.bias]
# Loading weights:  26%|██▌       | 54/211 [00:00<00:00, 3980.25it/s, Materializing param=encoder.layers.3.attention.out_proj.weight]
# Loading weights:  26%|██▌       | 54/211 [00:00<00:00, 3962.01it/s, Materializing param=encoder.layers.3.attention.out_proj.weight]
# Loading weights:  26%|██▌       | 55/211 [00:00<00:00, 4008.32it/s, Materializing param=encoder.layers.3.attention.q_proj.bias]
# Loading weights:  26%|██▌       | 55/211 [00:00<00:00, 3987.67it/s, Materializing param=encoder.layers.3.attention.q_proj.bias]
# Loading weights:  27%|██▋       | 56/211 [00:00<00:00, 4033.19it/s, Materializing param=encoder.layers.3.attention.q_proj.weight]
# Loading weights:  27%|██▋       | 56/211 [00:00<00:00, 4018.01it/s, Materializing param=encoder.layers.3.attention.q_proj.weight]
# Loading weights:  27%|██▋       | 57/211 [00:00<00:00, 4061.14it/s, Materializing param=encoder.layers.3.attention.v_proj.bias]
# Loading weights:  27%|██▋       | 57/211 [00:00<00:00, 4045.82it/s, Materializing param=encoder.layers.3.attention.v_proj.bias]
# Loading weights:  27%|██▋       | 58/211 [00:00<00:00, 4090.01it/s, Materializing param=encoder.layers.3.attention.v_proj.weight]
# Loading weights:  27%|██▋       | 58/211 [00:00<00:00, 4075.00it/s, Materializing param=encoder.layers.3.attention.v_proj.weight]
# Loading weights:  28%|██▊       | 59/211 [00:00<00:00, 4117.95it/s, Materializing param=encoder.layers.3.feed_forward.intermediate_dense.bias]
# Loading weights:  28%|██▊       | 59/211 [00:00<00:00, 4102.11it/s, Materializing param=encoder.layers.3.feed_forward.intermediate_dense.bias]
# Loading weights:  28%|██▊       | 60/211 [00:00<00:00, 4144.50it/s, Materializing param=encoder.layers.3.feed_forward.intermediate_dense.weight]
# Loading weights:  28%|██▊       | 60/211 [00:00<00:00, 4129.00it/s, Materializing param=encoder.layers.3.feed_forward.intermediate_dense.weight]
# Loading weights:  29%|██▉       | 61/211 [00:00<00:00, 4159.53it/s, Materializing param=encoder.layers.3.feed_forward.output_dense.bias]
# Loading weights:  29%|██▉       | 61/211 [00:00<00:00, 4142.09it/s, Materializing param=encoder.layers.3.feed_forward.output_dense.bias]
# Loading weights:  29%|██▉       | 62/211 [00:00<00:00, 4179.41it/s, Materializing param=encoder.layers.3.feed_forward.output_dense.weight]
# Loading weights:  29%|██▉       | 62/211 [00:00<00:00, 4160.55it/s, Materializing param=encoder.layers.3.feed_forward.output_dense.weight]
# Loading weights:  30%|██▉       | 63/211 [00:00<00:00, 4201.24it/s, Materializing param=encoder.layers.3.final_layer_norm.bias]
# Loading weights:  30%|██▉       | 63/211 [00:00<00:00, 4182.42it/s, Materializing param=encoder.layers.3.final_layer_norm.bias]
# Loading weights:  30%|███       | 64/211 [00:00<00:00, 4224.60it/s, Materializing param=encoder.layers.3.final_layer_norm.weight]
# Loading weights:  30%|███       | 64/211 [00:00<00:00, 4210.88it/s, Materializing param=encoder.layers.3.final_layer_norm.weight]
# Loading weights:  31%|███       | 65/211 [00:00<00:00, 4252.86it/s, Materializing param=encoder.layers.3.layer_norm.bias]
# Loading weights:  31%|███       | 65/211 [00:00<00:00, 4239.50it/s, Materializing param=encoder.layers.3.layer_norm.bias]
# Loading weights:  31%|███▏      | 66/211 [00:00<00:00, 4281.42it/s, Materializing param=encoder.layers.3.layer_norm.weight]
# Loading weights:  31%|███▏      | 66/211 [00:00<00:00, 4268.09it/s, Materializing param=encoder.layers.3.layer_norm.weight]
# Loading weights:  32%|███▏      | 67/211 [00:00<00:00, 4307.06it/s, Materializing param=encoder.layers.4.attention.k_proj.bias]
# Loading weights:  32%|███▏      | 67/211 [00:00<00:00, 4293.44it/s, Materializing param=encoder.layers.4.attention.k_proj.bias]
# Loading weights:  32%|███▏      | 68/211 [00:00<00:00, 4319.44it/s, Materializing param=encoder.layers.4.attention.k_proj.weight]
# Loading weights:  32%|███▏      | 68/211 [00:00<00:00, 4304.84it/s, Materializing param=encoder.layers.4.attention.k_proj.weight]
# Loading weights:  33%|███▎      | 69/211 [00:00<00:00, 4344.15it/s, Materializing param=encoder.layers.4.attention.out_proj.bias]
# Loading weights:  33%|███▎      | 69/211 [00:00<00:00, 4330.56it/s, Materializing param=encoder.layers.4.attention.out_proj.bias]
# Loading weights:  33%|███▎      | 70/211 [00:00<00:00, 4367.90it/s, Materializing param=encoder.layers.4.attention.out_proj.weight]
# Loading weights:  33%|███▎      | 70/211 [00:00<00:00, 4354.16it/s, Materializing param=encoder.layers.4.attention.out_proj.weight]
# Loading weights:  34%|███▎      | 71/211 [00:00<00:00, 4392.85it/s, Materializing param=encoder.layers.4.attention.q_proj.bias]
# Loading weights:  34%|███▎      | 71/211 [00:00<00:00, 4379.67it/s, Materializing param=encoder.layers.4.attention.q_proj.bias]
# Loading weights:  34%|███▍      | 72/211 [00:00<00:00, 4418.29it/s, Materializing param=encoder.layers.4.attention.q_proj.weight]
# Loading weights:  34%|███▍      | 72/211 [00:00<00:00, 4405.14it/s, Materializing param=encoder.layers.4.attention.q_proj.weight]
# Loading weights:  35%|███▍      | 73/211 [00:00<00:00, 4443.63it/s, Materializing param=encoder.layers.4.attention.v_proj.bias]
# Loading weights:  35%|███▍      | 73/211 [00:00<00:00, 4430.71it/s, Materializing param=encoder.layers.4.attention.v_proj.bias]
# Loading weights:  35%|███▌      | 74/211 [00:00<00:00, 4468.64it/s, Materializing param=encoder.layers.4.attention.v_proj.weight]
# Loading weights:  35%|███▌      | 74/211 [00:00<00:00, 4444.45it/s, Materializing param=encoder.layers.4.attention.v_proj.weight]
# Loading weights:  36%|███▌      | 75/211 [00:00<00:00, 4469.95it/s, Materializing param=encoder.layers.4.feed_forward.intermediate_dense.bias]
# Loading weights:  36%|███▌      | 75/211 [00:00<00:00, 4450.91it/s, Materializing param=encoder.layers.4.feed_forward.intermediate_dense.bias]
# Loading weights:  36%|███▌      | 76/211 [00:00<00:00, 4484.37it/s, Materializing param=encoder.layers.4.feed_forward.intermediate_dense.weight]
# Loading weights:  36%|███▌      | 76/211 [00:00<00:00, 4468.53it/s, Materializing param=encoder.layers.4.feed_forward.intermediate_dense.weight]
# Loading weights:  36%|███▋      | 77/211 [00:00<00:00, 4501.77it/s, Materializing param=encoder.layers.4.feed_forward.output_dense.bias]
# Loading weights:  36%|███▋      | 77/211 [00:00<00:00, 4487.69it/s, Materializing param=encoder.layers.4.feed_forward.output_dense.bias]
# Loading weights:  37%|███▋      | 78/211 [00:00<00:00, 4521.85it/s, Materializing param=encoder.layers.4.feed_forward.output_dense.weight]
# Loading weights:  37%|███▋      | 78/211 [00:00<00:00, 4508.02it/s, Materializing param=encoder.layers.4.feed_forward.output_dense.weight]
# Loading weights:  37%|███▋      | 79/211 [00:00<00:00, 4541.47it/s, Materializing param=encoder.layers.4.final_layer_norm.bias]
# Loading weights:  37%|███▋      | 79/211 [00:00<00:00, 4527.63it/s, Materializing param=encoder.layers.4.final_layer_norm.bias]
# Loading weights:  38%|███▊      | 80/211 [00:00<00:00, 4560.76it/s, Materializing param=encoder.layers.4.final_layer_norm.weight]
# Loading weights:  38%|███▊      | 80/211 [00:00<00:00, 4547.23it/s, Materializing param=encoder.layers.4.final_layer_norm.weight]
# Loading weights:  38%|███▊      | 81/211 [00:00<00:00, 4571.29it/s, Materializing param=encoder.layers.4.layer_norm.bias]
# Loading weights:  38%|███▊      | 81/211 [00:00<00:00, 4557.19it/s, Materializing param=encoder.layers.4.layer_norm.bias]
# Loading weights:  39%|███▉      | 82/211 [00:00<00:00, 4590.67it/s, Materializing param=encoder.layers.4.layer_norm.weight]
# Loading weights:  39%|███▉      | 82/211 [00:00<00:00, 4577.84it/s, Materializing param=encoder.layers.4.layer_norm.weight]
# Loading weights:  39%|███▉      | 83/211 [00:00<00:00, 4611.93it/s, Materializing param=encoder.layers.5.attention.k_proj.bias]
# Loading weights:  39%|███▉      | 83/211 [00:00<00:00, 4597.80it/s, Materializing param=encoder.layers.5.attention.k_proj.bias]
# Loading weights:  40%|███▉      | 84/211 [00:00<00:00, 4630.51it/s, Materializing param=encoder.layers.5.attention.k_proj.weight]
# Loading weights:  40%|███▉      | 84/211 [00:00<00:00, 4617.76it/s, Materializing param=encoder.layers.5.attention.k_proj.weight]
# Loading weights:  40%|████      | 85/211 [00:00<00:00, 4650.91it/s, Materializing param=encoder.layers.5.attention.out_proj.bias]
# Loading weights:  40%|████      | 85/211 [00:00<00:00, 4638.45it/s, Materializing param=encoder.layers.5.attention.out_proj.bias]
# Loading weights:  41%|████      | 86/211 [00:00<00:00, 4671.50it/s, Materializing param=encoder.layers.5.attention.out_proj.weight]
# Loading weights:  41%|████      | 86/211 [00:00<00:00, 4658.89it/s, Materializing param=encoder.layers.5.attention.out_proj.weight]
# Loading weights:  41%|████      | 87/211 [00:00<00:00, 4691.68it/s, Materializing param=encoder.layers.5.attention.q_proj.bias]
# Loading weights:  41%|████      | 87/211 [00:00<00:00, 4679.34it/s, Materializing param=encoder.layers.5.attention.q_proj.bias]
# Loading weights:  42%|████▏     | 88/211 [00:00<00:00, 4707.53it/s, Materializing param=encoder.layers.5.attention.q_proj.weight]
# Loading weights:  42%|████▏     | 88/211 [00:00<00:00, 4695.14it/s, Materializing param=encoder.layers.5.attention.q_proj.weight]
# Loading weights:  42%|████▏     | 89/211 [00:00<00:00, 4726.19it/s, Materializing param=encoder.layers.5.attention.v_proj.bias]
# Loading weights:  42%|████▏     | 89/211 [00:00<00:00, 4713.24it/s, Materializing param=encoder.layers.5.attention.v_proj.bias]
# Loading weights:  43%|████▎     | 90/211 [00:00<00:00, 4744.39it/s, Materializing param=encoder.layers.5.attention.v_proj.weight]
# Loading weights:  43%|████▎     | 90/211 [00:00<00:00, 4730.36it/s, Materializing param=encoder.layers.5.attention.v_proj.weight]
# Loading weights:  43%|████▎     | 91/211 [00:00<00:00, 4761.08it/s, Materializing param=encoder.layers.5.feed_forward.intermediate_dense.bias]
# Loading weights:  43%|████▎     | 91/211 [00:00<00:00, 4748.29it/s, Materializing param=encoder.layers.5.feed_forward.intermediate_dense.bias]
# Loading weights:  44%|████▎     | 92/211 [00:00<00:00, 4777.76it/s, Materializing param=encoder.layers.5.feed_forward.intermediate_dense.weight]
# Loading weights:  44%|████▎     | 92/211 [00:00<00:00, 4765.02it/s, Materializing param=encoder.layers.5.feed_forward.intermediate_dense.weight]
# Loading weights:  44%|████▍     | 93/211 [00:00<00:00, 4795.38it/s, Materializing param=encoder.layers.5.feed_forward.output_dense.bias]
# Loading weights:  44%|████▍     | 93/211 [00:00<00:00, 4783.09it/s, Materializing param=encoder.layers.5.feed_forward.output_dense.bias]
# Loading weights:  45%|████▍     | 94/211 [00:00<00:00, 4811.92it/s, Materializing param=encoder.layers.5.feed_forward.output_dense.weight]
# Loading weights:  45%|████▍     | 94/211 [00:00<00:00, 4799.62it/s, Materializing param=encoder.layers.5.feed_forward.output_dense.weight]
# Loading weights:  45%|████▌     | 95/211 [00:00<00:00, 4811.90it/s, Materializing param=encoder.layers.5.final_layer_norm.bias]
# Loading weights:  45%|████▌     | 95/211 [00:00<00:00, 4797.53it/s, Materializing param=encoder.layers.5.final_layer_norm.bias]
# Loading weights:  45%|████▌     | 96/211 [00:00<00:00, 4823.58it/s, Materializing param=encoder.layers.5.final_layer_norm.weight]
# Loading weights:  45%|████▌     | 96/211 [00:00<00:00, 4811.25it/s, Materializing param=encoder.layers.5.final_layer_norm.weight]
# Loading weights:  46%|████▌     | 97/211 [00:00<00:00, 4838.58it/s, Materializing param=encoder.layers.5.layer_norm.bias]
# Loading weights:  46%|████▌     | 97/211 [00:00<00:00, 4826.70it/s, Materializing param=encoder.layers.5.layer_norm.bias]
# Loading weights:  46%|████▋     | 98/211 [00:00<00:00, 4855.67it/s, Materializing param=encoder.layers.5.layer_norm.weight]
# Loading weights:  46%|████▋     | 98/211 [00:00<00:00, 4843.88it/s, Materializing param=encoder.layers.5.layer_norm.weight]
# Loading weights:  47%|████▋     | 99/211 [00:00<00:00, 4873.21it/s, Materializing param=encoder.layers.6.attention.k_proj.bias]
# Loading weights:  47%|████▋     | 99/211 [00:00<00:00, 4857.36it/s, Materializing param=encoder.layers.6.attention.k_proj.bias]
# Loading weights:  47%|████▋     | 100/211 [00:00<00:00, 4884.37it/s, Materializing param=encoder.layers.6.attention.k_proj.weight]
# Loading weights:  47%|████▋     | 100/211 [00:00<00:00, 4871.77it/s, Materializing param=encoder.layers.6.attention.k_proj.weight]
# Loading weights:  48%|████▊     | 101/211 [00:00<00:00, 4894.74it/s, Materializing param=encoder.layers.6.attention.out_proj.bias]
# Loading weights:  48%|████▊     | 101/211 [00:00<00:00, 4879.79it/s, Materializing param=encoder.layers.6.attention.out_proj.bias]
# Loading weights:  48%|████▊     | 102/211 [00:00<00:00, 4906.41it/s, Materializing param=encoder.layers.6.attention.out_proj.weight]
# Loading weights:  48%|████▊     | 102/211 [00:00<00:00, 4886.90it/s, Materializing param=encoder.layers.6.attention.out_proj.weight]
# Loading weights:  49%|████▉     | 103/211 [00:00<00:00, 4913.99it/s, Materializing param=encoder.layers.6.attention.q_proj.bias]
# Loading weights:  49%|████▉     | 103/211 [00:00<00:00, 4901.06it/s, Materializing param=encoder.layers.6.attention.q_proj.bias]
# Loading weights:  49%|████▉     | 104/211 [00:00<00:00, 4922.61it/s, Materializing param=encoder.layers.6.attention.q_proj.weight]
# Loading weights:  49%|████▉     | 104/211 [00:00<00:00, 4910.37it/s, Materializing param=encoder.layers.6.attention.q_proj.weight]
# Loading weights:  50%|████▉     | 105/211 [00:00<00:00, 4935.91it/s, Materializing param=encoder.layers.6.attention.v_proj.bias]
# Loading weights:  50%|████▉     | 105/211 [00:00<00:00, 4923.77it/s, Materializing param=encoder.layers.6.attention.v_proj.bias]
# Loading weights:  50%|█████     | 106/211 [00:00<00:00, 4947.71it/s, Materializing param=encoder.layers.6.attention.v_proj.weight]
# Loading weights:  50%|█████     | 106/211 [00:00<00:00, 4935.41it/s, Materializing param=encoder.layers.6.attention.v_proj.weight]
# Loading weights:  51%|█████     | 107/211 [00:00<00:00, 4961.04it/s, Materializing param=encoder.layers.6.feed_forward.intermediate_dense.bias]
# Loading weights:  51%|█████     | 107/211 [00:00<00:00, 4945.62it/s, Materializing param=encoder.layers.6.feed_forward.intermediate_dense.bias]
# Loading weights:  51%|█████     | 108/211 [00:00<00:00, 4967.27it/s, Materializing param=encoder.layers.6.feed_forward.intermediate_dense.weight]
# Loading weights:  51%|█████     | 108/211 [00:00<00:00, 4954.99it/s, Materializing param=encoder.layers.6.feed_forward.intermediate_dense.weight]
# Loading weights:  52%|█████▏    | 109/211 [00:00<00:00, 4980.65it/s, Materializing param=encoder.layers.6.feed_forward.output_dense.bias]
# Loading weights:  52%|█████▏    | 109/211 [00:00<00:00, 4969.28it/s, Materializing param=encoder.layers.6.feed_forward.output_dense.bias]
# Loading weights:  52%|█████▏    | 110/211 [00:00<00:00, 4992.73it/s, Materializing param=encoder.layers.6.feed_forward.output_dense.weight]
# Loading weights:  52%|█████▏    | 110/211 [00:00<00:00, 4981.30it/s, Materializing param=encoder.layers.6.feed_forward.output_dense.weight]
# Loading weights:  53%|█████▎    | 111/211 [00:00<00:00, 5004.97it/s, Materializing param=encoder.layers.6.final_layer_norm.bias]
# Loading weights:  53%|█████▎    | 111/211 [00:00<00:00, 4993.06it/s, Materializing param=encoder.layers.6.final_layer_norm.bias]
# Loading weights:  53%|█████▎    | 112/211 [00:00<00:00, 5018.13it/s, Materializing param=encoder.layers.6.final_layer_norm.weight]
# Loading weights:  53%|█████▎    | 112/211 [00:00<00:00, 5007.27it/s, Materializing param=encoder.layers.6.final_layer_norm.weight]
# Loading weights:  54%|█████▎    | 113/211 [00:00<00:00, 5033.31it/s, Materializing param=encoder.layers.6.layer_norm.bias]
# Loading weights:  54%|█████▎    | 113/211 [00:00<00:00, 5022.69it/s, Materializing param=encoder.layers.6.layer_norm.bias]
# Loading weights:  54%|█████▍    | 114/211 [00:00<00:00, 5048.52it/s, Materializing param=encoder.layers.6.layer_norm.weight]
# Loading weights:  54%|█████▍    | 114/211 [00:00<00:00, 5033.80it/s, Materializing param=encoder.layers.6.layer_norm.weight]
# Loading weights:  55%|█████▍    | 115/211 [00:00<00:00, 5058.84it/s, Materializing param=encoder.layers.7.attention.k_proj.bias]
# Loading weights:  55%|█████▍    | 115/211 [00:00<00:00, 5047.46it/s, Materializing param=encoder.layers.7.attention.k_proj.bias]
# Loading weights:  55%|█████▍    | 116/211 [00:00<00:00, 5071.76it/s, Materializing param=encoder.layers.7.attention.k_proj.weight]
# Loading weights:  55%|█████▍    | 116/211 [00:00<00:00, 5060.90it/s, Materializing param=encoder.layers.7.attention.k_proj.weight]
# Loading weights:  55%|█████▌    | 117/211 [00:00<00:00, 5084.90it/s, Materializing param=encoder.layers.7.attention.out_proj.bias]
# Loading weights:  55%|█████▌    | 117/211 [00:00<00:00, 5074.07it/s, Materializing param=encoder.layers.7.attention.out_proj.bias]
# Loading weights:  56%|█████▌    | 118/211 [00:00<00:00, 5098.83it/s, Materializing param=encoder.layers.7.attention.out_proj.weight]
# Loading weights:  56%|█████▌    | 118/211 [00:00<00:00, 5087.92it/s, Materializing param=encoder.layers.7.attention.out_proj.weight]
# Loading weights:  56%|█████▋    | 119/211 [00:00<00:00, 5112.12it/s, Materializing param=encoder.layers.7.attention.q_proj.bias]
# Loading weights:  56%|█████▋    | 119/211 [00:00<00:00, 5101.31it/s, Materializing param=encoder.layers.7.attention.q_proj.bias]
# Loading weights:  57%|█████▋    | 120/211 [00:00<00:00, 5125.27it/s, Materializing param=encoder.layers.7.attention.q_proj.weight]
# Loading weights:  57%|█████▋    | 120/211 [00:00<00:00, 5114.23it/s, Materializing param=encoder.layers.7.attention.q_proj.weight]
# Loading weights:  57%|█████▋    | 121/211 [00:00<00:00, 5137.53it/s, Materializing param=encoder.layers.7.attention.v_proj.bias]
# Loading weights:  57%|█████▋    | 121/211 [00:00<00:00, 5126.73it/s, Materializing param=encoder.layers.7.attention.v_proj.bias]
# Loading weights:  58%|█████▊    | 122/211 [00:00<00:00, 5131.47it/s, Materializing param=encoder.layers.7.attention.v_proj.weight]
# Loading weights:  58%|█████▊    | 122/211 [00:00<00:00, 5119.56it/s, Materializing param=encoder.layers.7.attention.v_proj.weight]
# Loading weights:  58%|█████▊    | 123/211 [00:00<00:00, 5141.67it/s, Materializing param=encoder.layers.7.feed_forward.intermediate_dense.bias]
# Loading weights:  58%|█████▊    | 123/211 [00:00<00:00, 5130.62it/s, Materializing param=encoder.layers.7.feed_forward.intermediate_dense.bias]
# Loading weights:  59%|█████▉    | 124/211 [00:00<00:00, 5151.58it/s, Materializing param=encoder.layers.7.feed_forward.intermediate_dense.weight]
# Loading weights:  59%|█████▉    | 124/211 [00:00<00:00, 5140.13it/s, Materializing param=encoder.layers.7.feed_forward.intermediate_dense.weight]
# Loading weights:  59%|█████▉    | 125/211 [00:00<00:00, 5162.14it/s, Materializing param=encoder.layers.7.feed_forward.output_dense.bias]
# Loading weights:  59%|█████▉    | 125/211 [00:00<00:00, 5151.39it/s, Materializing param=encoder.layers.7.feed_forward.output_dense.bias]
# Loading weights:  60%|█████▉    | 126/211 [00:00<00:00, 5173.84it/s, Materializing param=encoder.layers.7.feed_forward.output_dense.weight]
# Loading weights:  60%|█████▉    | 126/211 [00:00<00:00, 5161.87it/s, Materializing param=encoder.layers.7.feed_forward.output_dense.weight]
# Loading weights:  60%|██████    | 127/211 [00:00<00:00, 5184.35it/s, Materializing param=encoder.layers.7.final_layer_norm.bias]
# Loading weights:  60%|██████    | 127/211 [00:00<00:00, 5173.93it/s, Materializing param=encoder.layers.7.final_layer_norm.bias]
# Loading weights:  61%|██████    | 128/211 [00:00<00:00, 5193.53it/s, Materializing param=encoder.layers.7.final_layer_norm.weight]
# Loading weights:  61%|██████    | 128/211 [00:00<00:00, 5182.55it/s, Materializing param=encoder.layers.7.final_layer_norm.weight]
# Loading weights:  61%|██████    | 129/211 [00:00<00:00, 5204.30it/s, Materializing param=encoder.layers.7.layer_norm.bias]
# Loading weights:  61%|██████    | 129/211 [00:00<00:00, 5193.96it/s, Materializing param=encoder.layers.7.layer_norm.bias]
# Loading weights:  62%|██████▏   | 130/211 [00:00<00:00, 5216.40it/s, Materializing param=encoder.layers.7.layer_norm.weight]
# Loading weights:  62%|██████▏   | 130/211 [00:00<00:00, 5206.24it/s, Materializing param=encoder.layers.7.layer_norm.weight]
# Loading weights:  62%|██████▏   | 131/211 [00:00<00:00, 5227.22it/s, Materializing param=encoder.layers.8.attention.k_proj.bias]
# Loading weights:  62%|██████▏   | 131/211 [00:00<00:00, 5216.75it/s, Materializing param=encoder.layers.8.attention.k_proj.bias]
# Loading weights:  63%|██████▎   | 132/211 [00:00<00:00, 5238.12it/s, Materializing param=encoder.layers.8.attention.k_proj.weight]
# Loading weights:  63%|██████▎   | 132/211 [00:00<00:00, 5227.58it/s, Materializing param=encoder.layers.8.attention.k_proj.weight]
# Loading weights:  63%|██████▎   | 133/211 [00:00<00:00, 5248.75it/s, Materializing param=encoder.layers.8.attention.out_proj.bias]
# Loading weights:  63%|██████▎   | 133/211 [00:00<00:00, 5238.30it/s, Materializing param=encoder.layers.8.attention.out_proj.bias]
# Loading weights:  64%|██████▎   | 134/211 [00:00<00:00, 5259.22it/s, Materializing param=encoder.layers.8.attention.out_proj.weight]
# Loading weights:  64%|██████▎   | 134/211 [00:00<00:00, 5248.80it/s, Materializing param=encoder.layers.8.attention.out_proj.weight]
# Loading weights:  64%|██████▍   | 135/211 [00:00<00:00, 5267.12it/s, Materializing param=encoder.layers.8.attention.q_proj.bias]
# Loading weights:  64%|██████▍   | 135/211 [00:00<00:00, 5256.61it/s, Materializing param=encoder.layers.8.attention.q_proj.bias]
# Loading weights:  64%|██████▍   | 136/211 [00:00<00:00, 5276.29it/s, Materializing param=encoder.layers.8.attention.q_proj.weight]
# Loading weights:  64%|██████▍   | 136/211 [00:00<00:00, 5265.72it/s, Materializing param=encoder.layers.8.attention.q_proj.weight]
# Loading weights:  65%|██████▍   | 137/211 [00:00<00:00, 5286.78it/s, Materializing param=encoder.layers.8.attention.v_proj.bias]
# Loading weights:  65%|██████▍   | 137/211 [00:00<00:00, 5276.63it/s, Materializing param=encoder.layers.8.attention.v_proj.bias]
# Loading weights:  65%|██████▌   | 138/211 [00:00<00:00, 5294.87it/s, Materializing param=encoder.layers.8.attention.v_proj.weight]
# Loading weights:  65%|██████▌   | 138/211 [00:00<00:00, 5280.19it/s, Materializing param=encoder.layers.8.attention.v_proj.weight]
# Loading weights:  66%|██████▌   | 139/211 [00:00<00:00, 5299.64it/s, Materializing param=encoder.layers.8.feed_forward.intermediate_dense.bias]
# Loading weights:  66%|██████▌   | 139/211 [00:00<00:00, 5288.44it/s, Materializing param=encoder.layers.8.feed_forward.intermediate_dense.bias]
# Loading weights:  66%|██████▋   | 140/211 [00:00<00:00, 5307.28it/s, Materializing param=encoder.layers.8.feed_forward.intermediate_dense.weight]
# Loading weights:  66%|██████▋   | 140/211 [00:00<00:00, 5296.22it/s, Materializing param=encoder.layers.8.feed_forward.intermediate_dense.weight]
# Loading weights:  67%|██████▋   | 141/211 [00:00<00:00, 5314.88it/s, Materializing param=encoder.layers.8.feed_forward.output_dense.bias]
# Loading weights:  67%|██████▋   | 141/211 [00:00<00:00, 5303.87it/s, Materializing param=encoder.layers.8.feed_forward.output_dense.bias]
# Loading weights:  67%|██████▋   | 142/211 [00:00<00:00, 5315.41it/s, Materializing param=encoder.layers.8.feed_forward.output_dense.weight]
# Loading weights:  67%|██████▋   | 142/211 [00:00<00:00, 5300.74it/s, Materializing param=encoder.layers.8.feed_forward.output_dense.weight]
# Loading weights:  68%|██████▊   | 143/211 [00:00<00:00, 5314.09it/s, Materializing param=encoder.layers.8.final_layer_norm.bias]
# Loading weights:  68%|██████▊   | 143/211 [00:00<00:00, 5302.81it/s, Materializing param=encoder.layers.8.final_layer_norm.bias]
# Loading weights:  68%|██████▊   | 144/211 [00:00<00:00, 5318.74it/s, Materializing param=encoder.layers.8.final_layer_norm.weight]
# Loading weights:  68%|██████▊   | 144/211 [00:00<00:00, 5307.43it/s, Materializing param=encoder.layers.8.final_layer_norm.weight]
# Loading weights:  69%|██████▊   | 145/211 [00:00<00:00, 5325.05it/s, Materializing param=encoder.layers.8.layer_norm.bias]
# Loading weights:  69%|██████▊   | 145/211 [00:00<00:00, 5313.98it/s, Materializing param=encoder.layers.8.layer_norm.bias]
# Loading weights:  69%|██████▉   | 146/211 [00:00<00:00, 5331.67it/s, Materializing param=encoder.layers.8.layer_norm.weight]
# Loading weights:  69%|██████▉   | 146/211 [00:00<00:00, 5320.82it/s, Materializing param=encoder.layers.8.layer_norm.weight]
# Loading weights:  70%|██████▉   | 147/211 [00:00<00:00, 5336.96it/s, Materializing param=encoder.layers.9.attention.k_proj.bias]
# Loading weights:  70%|██████▉   | 147/211 [00:00<00:00, 5326.95it/s, Materializing param=encoder.layers.9.attention.k_proj.bias]
# Loading weights:  70%|███████   | 148/211 [00:00<00:00, 5341.78it/s, Materializing param=encoder.layers.9.attention.k_proj.weight]
# Loading weights:  70%|███████   | 148/211 [00:00<00:00, 5330.99it/s, Materializing param=encoder.layers.9.attention.k_proj.weight]
# Loading weights:  71%|███████   | 149/211 [00:00<00:00, 5348.69it/s, Materializing param=encoder.layers.9.attention.out_proj.bias]
# Loading weights:  71%|███████   | 149/211 [00:00<00:00, 5338.59it/s, Materializing param=encoder.layers.9.attention.out_proj.bias]
# Loading weights:  71%|███████   | 150/211 [00:00<00:00, 5355.48it/s, Materializing param=encoder.layers.9.attention.out_proj.weight]
# Loading weights:  71%|███████   | 150/211 [00:00<00:00, 5345.11it/s, Materializing param=encoder.layers.9.attention.out_proj.weight]
# Loading weights:  72%|███████▏  | 151/211 [00:00<00:00, 5361.83it/s, Materializing param=encoder.layers.9.attention.q_proj.bias]
# Loading weights:  72%|███████▏  | 151/211 [00:00<00:00, 5352.32it/s, Materializing param=encoder.layers.9.attention.q_proj.bias]
# Loading weights:  72%|███████▏  | 152/211 [00:00<00:00, 5371.56it/s, Materializing param=encoder.layers.9.attention.q_proj.weight]
# Loading weights:  72%|███████▏  | 152/211 [00:00<00:00, 5362.03it/s, Materializing param=encoder.layers.9.attention.q_proj.weight]
# Loading weights:  73%|███████▎  | 153/211 [00:00<00:00, 5380.78it/s, Materializing param=encoder.layers.9.attention.v_proj.bias]
# Loading weights:  73%|███████▎  | 153/211 [00:00<00:00, 5365.17it/s, Materializing param=encoder.layers.9.attention.v_proj.bias]
# Loading weights:  73%|███████▎  | 154/211 [00:00<00:00, 5384.08it/s, Materializing param=encoder.layers.9.attention.v_proj.weight]
# Loading weights:  73%|███████▎  | 154/211 [00:00<00:00, 5372.04it/s, Materializing param=encoder.layers.9.attention.v_proj.weight]
# Loading weights:  73%|███████▎  | 155/211 [00:00<00:00, 5390.15it/s, Materializing param=encoder.layers.9.feed_forward.intermediate_dense.bias]
# Loading weights:  73%|███████▎  | 155/211 [00:00<00:00, 5380.16it/s, Materializing param=encoder.layers.9.feed_forward.intermediate_dense.bias]
# Loading weights:  74%|███████▍  | 156/211 [00:00<00:00, 5397.90it/s, Materializing param=encoder.layers.9.feed_forward.intermediate_dense.weight]
# Loading weights:  74%|███████▍  | 156/211 [00:00<00:00, 5388.25it/s, Materializing param=encoder.layers.9.feed_forward.intermediate_dense.weight]
# Loading weights:  74%|███████▍  | 157/211 [00:00<00:00, 5404.76it/s, Materializing param=encoder.layers.9.feed_forward.output_dense.bias]
# Loading weights:  74%|███████▍  | 157/211 [00:00<00:00, 5395.02it/s, Materializing param=encoder.layers.9.feed_forward.output_dense.bias]
# Loading weights:  75%|███████▍  | 158/211 [00:00<00:00, 5412.89it/s, Materializing param=encoder.layers.9.feed_forward.output_dense.weight]
# Loading weights:  75%|███████▍  | 158/211 [00:00<00:00, 5403.40it/s, Materializing param=encoder.layers.9.feed_forward.output_dense.weight]
# Loading weights:  75%|███████▌  | 159/211 [00:00<00:00, 5421.24it/s, Materializing param=encoder.layers.9.final_layer_norm.bias]
# Loading weights:  75%|███████▌  | 159/211 [00:00<00:00, 5411.83it/s, Materializing param=encoder.layers.9.final_layer_norm.bias]
# Loading weights:  76%|███████▌  | 160/211 [00:00<00:00, 5429.78it/s, Materializing param=encoder.layers.9.final_layer_norm.weight]
# Loading weights:  76%|███████▌  | 160/211 [00:00<00:00, 5420.66it/s, Materializing param=encoder.layers.9.final_layer_norm.weight]
# Loading weights:  76%|███████▋  | 161/211 [00:00<00:00, 5438.86it/s, Materializing param=encoder.layers.9.layer_norm.bias]
# Loading weights:  76%|███████▋  | 161/211 [00:00<00:00, 5427.27it/s, Materializing param=encoder.layers.9.layer_norm.bias]
# Loading weights:  77%|███████▋  | 162/211 [00:00<00:00, 5444.66it/s, Materializing param=encoder.layers.9.layer_norm.weight]
# Loading weights:  77%|███████▋  | 162/211 [00:00<00:00, 5431.78it/s, Materializing param=encoder.layers.9.layer_norm.weight]
# Loading weights:  77%|███████▋  | 163/211 [00:00<00:00, 5448.45it/s, Materializing param=encoder.layers.10.attention.k_proj.bias]
# Loading weights:  77%|███████▋  | 163/211 [00:00<00:00, 5438.87it/s, Materializing param=encoder.layers.10.attention.k_proj.bias]
# Loading weights:  78%|███████▊  | 164/211 [00:00<00:00, 5453.89it/s, Materializing param=encoder.layers.10.attention.k_proj.weight]
# Loading weights:  78%|███████▊  | 164/211 [00:00<00:00, 5444.04it/s, Materializing param=encoder.layers.10.attention.k_proj.weight]
# Loading weights:  78%|███████▊  | 165/211 [00:00<00:00, 5460.26it/s, Materializing param=encoder.layers.10.attention.out_proj.bias]
# Loading weights:  78%|███████▊  | 165/211 [00:00<00:00, 5450.58it/s, Materializing param=encoder.layers.10.attention.out_proj.bias]
# Loading weights:  79%|███████▊  | 166/211 [00:00<00:00, 5466.69it/s, Materializing param=encoder.layers.10.attention.out_proj.weight]
# Loading weights:  79%|███████▊  | 166/211 [00:00<00:00, 5457.01it/s, Materializing param=encoder.layers.10.attention.out_proj.weight]
# Loading weights:  79%|███████▉  | 167/211 [00:00<00:00, 5473.03it/s, Materializing param=encoder.layers.10.attention.q_proj.bias]
# Loading weights:  79%|███████▉  | 167/211 [00:00<00:00, 5463.46it/s, Materializing param=encoder.layers.10.attention.q_proj.bias]
# Loading weights:  80%|███████▉  | 168/211 [00:00<00:00, 5477.04it/s, Materializing param=encoder.layers.10.attention.q_proj.weight]
# Loading weights:  80%|███████▉  | 168/211 [00:00<00:00, 5465.61it/s, Materializing param=encoder.layers.10.attention.q_proj.weight]
# Loading weights:  80%|████████  | 169/211 [00:00<00:00, 5481.82it/s, Materializing param=encoder.layers.10.attention.v_proj.bias]
# Loading weights:  80%|████████  | 169/211 [00:00<00:00, 5469.55it/s, Materializing param=encoder.layers.10.attention.v_proj.bias]
# Loading weights:  81%|████████  | 170/211 [00:00<00:00, 5483.89it/s, Materializing param=encoder.layers.10.attention.v_proj.weight]
# Loading weights:  81%|████████  | 170/211 [00:00<00:00, 5474.25it/s, Materializing param=encoder.layers.10.attention.v_proj.weight]
# Loading weights:  81%|████████  | 171/211 [00:00<00:00, 5491.06it/s, Materializing param=encoder.layers.10.feed_forward.intermediate_dense.bias]
# Loading weights:  81%|████████  | 171/211 [00:00<00:00, 5482.12it/s, Materializing param=encoder.layers.10.feed_forward.intermediate_dense.bias]
# Loading weights:  82%|████████▏ | 172/211 [00:00<00:00, 5494.82it/s, Materializing param=encoder.layers.10.feed_forward.intermediate_dense.weight]
# Loading weights:  82%|████████▏ | 172/211 [00:00<00:00, 5485.17it/s, Materializing param=encoder.layers.10.feed_forward.intermediate_dense.weight]
# Loading weights:  82%|████████▏ | 173/211 [00:00<00:00, 5500.62it/s, Materializing param=encoder.layers.10.feed_forward.output_dense.bias]
# Loading weights:  82%|████████▏ | 173/211 [00:00<00:00, 5491.21it/s, Materializing param=encoder.layers.10.feed_forward.output_dense.bias]
# Loading weights:  82%|████████▏ | 174/211 [00:00<00:00, 5505.21it/s, Materializing param=encoder.layers.10.feed_forward.output_dense.weight]
# Loading weights:  82%|████████▏ | 174/211 [00:00<00:00, 5493.52it/s, Materializing param=encoder.layers.10.feed_forward.output_dense.weight]
# Loading weights:  83%|████████▎ | 175/211 [00:00<00:00, 5508.05it/s, Materializing param=encoder.layers.10.final_layer_norm.bias]
# Loading weights:  83%|████████▎ | 175/211 [00:00<00:00, 5498.73it/s, Materializing param=encoder.layers.10.final_layer_norm.bias]
# Loading weights:  83%|████████▎ | 176/211 [00:00<00:00, 5514.12it/s, Materializing param=encoder.layers.10.final_layer_norm.weight]
# Loading weights:  83%|████████▎ | 176/211 [00:00<00:00, 5504.95it/s, Materializing param=encoder.layers.10.final_layer_norm.weight]
# Loading weights:  84%|████████▍ | 177/211 [00:00<00:00, 5518.74it/s, Materializing param=encoder.layers.10.layer_norm.bias]
# Loading weights:  84%|████████▍ | 177/211 [00:00<00:00, 5509.73it/s, Materializing param=encoder.layers.10.layer_norm.bias]
# Loading weights:  84%|████████▍ | 178/211 [00:00<00:00, 5525.32it/s, Materializing param=encoder.layers.10.layer_norm.weight]
# Loading weights:  84%|████████▍ | 178/211 [00:00<00:00, 5515.07it/s, Materializing param=encoder.layers.10.layer_norm.weight]
# Loading weights:  85%|████████▍ | 179/211 [00:00<00:00, 5531.75it/s, Materializing param=encoder.layers.11.attention.k_proj.bias]
# Loading weights:  85%|████████▍ | 179/211 [00:00<00:00, 5523.41it/s, Materializing param=encoder.layers.11.attention.k_proj.bias]
# Loading weights:  85%|████████▌ | 180/211 [00:00<00:00, 5539.64it/s, Materializing param=encoder.layers.11.attention.k_proj.weight]
# Loading weights:  85%|████████▌ | 180/211 [00:00<00:00, 5531.36it/s, Materializing param=encoder.layers.11.attention.k_proj.weight]
# Loading weights:  86%|████████▌ | 181/211 [00:00<00:00, 5545.10it/s, Materializing param=encoder.layers.11.attention.out_proj.bias]
# Loading weights:  86%|████████▌ | 181/211 [00:00<00:00, 5536.45it/s, Materializing param=encoder.layers.11.attention.out_proj.bias]
# Loading weights:  86%|████████▋ | 182/211 [00:00<00:00, 5551.53it/s, Materializing param=encoder.layers.11.attention.out_proj.weight]
# Loading weights:  86%|████████▋ | 182/211 [00:00<00:00, 5542.99it/s, Materializing param=encoder.layers.11.attention.out_proj.weight]
# Loading weights:  87%|████████▋ | 183/211 [00:00<00:00, 5558.47it/s, Materializing param=encoder.layers.11.attention.q_proj.bias]
# Loading weights:  87%|████████▋ | 183/211 [00:00<00:00, 5550.15it/s, Materializing param=encoder.layers.11.attention.q_proj.bias]
# Loading weights:  87%|████████▋ | 184/211 [00:00<00:00, 5564.46it/s, Materializing param=encoder.layers.11.attention.q_proj.weight]
# Loading weights:  87%|████████▋ | 184/211 [00:00<00:00, 5556.13it/s, Materializing param=encoder.layers.11.attention.q_proj.weight]
# Loading weights:  88%|████████▊ | 185/211 [00:00<00:00, 5571.48it/s, Materializing param=encoder.layers.11.attention.v_proj.bias]
# Loading weights:  88%|████████▊ | 185/211 [00:00<00:00, 5563.22it/s, Materializing param=encoder.layers.11.attention.v_proj.bias]
# Loading weights:  88%|████████▊ | 186/211 [00:00<00:00, 5578.89it/s, Materializing param=encoder.layers.11.attention.v_proj.weight]
# Loading weights:  88%|████████▊ | 186/211 [00:00<00:00, 5570.68it/s, Materializing param=encoder.layers.11.attention.v_proj.weight]
# Loading weights:  89%|████████▊ | 187/211 [00:00<00:00, 5586.07it/s, Materializing param=encoder.layers.11.feed_forward.intermediate_dense.bias]
# Loading weights:  89%|████████▊ | 187/211 [00:00<00:00, 5577.57it/s, Materializing param=encoder.layers.11.feed_forward.intermediate_dense.bias]
# Loading weights:  89%|████████▉ | 188/211 [00:00<00:00, 5590.74it/s, Materializing param=encoder.layers.11.feed_forward.intermediate_dense.weight]
# Loading weights:  89%|████████▉ | 188/211 [00:00<00:00, 5582.07it/s, Materializing param=encoder.layers.11.feed_forward.intermediate_dense.weight]
# Loading weights:  90%|████████▉ | 189/211 [00:00<00:00, 5593.63it/s, Materializing param=encoder.layers.11.feed_forward.output_dense.bias]
# Loading weights:  90%|████████▉ | 189/211 [00:00<00:00, 5584.57it/s, Materializing param=encoder.layers.11.feed_forward.output_dense.bias]
# Loading weights:  90%|█████████ | 190/211 [00:00<00:00, 5598.61it/s, Materializing param=encoder.layers.11.feed_forward.output_dense.weight]
# Loading weights:  90%|█████████ | 190/211 [00:00<00:00, 5588.09it/s, Materializing param=encoder.layers.11.feed_forward.output_dense.weight]
# Loading weights:  91%|█████████ | 191/211 [00:00<00:00, 5602.26it/s, Materializing param=encoder.layers.11.final_layer_norm.bias]
# Loading weights:  91%|█████████ | 191/211 [00:00<00:00, 5594.16it/s, Materializing param=encoder.layers.11.final_layer_norm.bias]
# Loading weights:  91%|█████████ | 192/211 [00:00<00:00, 5609.66it/s, Materializing param=encoder.layers.11.final_layer_norm.weight]
# Loading weights:  91%|█████████ | 192/211 [00:00<00:00, 5601.74it/s, Materializing param=encoder.layers.11.final_layer_norm.weight]
# Loading weights:  91%|█████████▏| 193/211 [00:00<00:00, 5617.32it/s, Materializing param=encoder.layers.11.layer_norm.bias]
# Loading weights:  91%|█████████▏| 193/211 [00:00<00:00, 5609.53it/s, Materializing param=encoder.layers.11.layer_norm.bias]
# Loading weights:  92%|█████████▏| 194/211 [00:00<00:00, 5625.03it/s, Materializing param=encoder.layers.11.layer_norm.weight]
# Loading weights:  92%|█████████▏| 194/211 [00:00<00:00, 5614.17it/s, Materializing param=encoder.layers.11.layer_norm.weight]
# Loading weights:  92%|█████████▏| 195/211 [00:00<00:00, 5617.02it/s, Materializing param=encoder.pos_conv_embed.conv.bias]
# Loading weights:  92%|█████████▏| 195/211 [00:00<00:00, 5606.36it/s, Materializing param=encoder.pos_conv_embed.conv.bias]
# Loading weights:  93%|█████████▎| 196/211 [00:00<00:00, 5619.24it/s, Materializing param=encoder.pos_conv_embed.conv.parametrizations.weight.original0]
# Loading weights:  93%|█████████▎| 196/211 [00:00<00:00, 5609.77it/s, Materializing param=encoder.pos_conv_embed.conv.parametrizations.weight.original0]
# Loading weights:  93%|█████████▎| 197/211 [00:00<00:00, 5622.05it/s, Materializing param=encoder.pos_conv_embed.conv.parametrizations.weight.original1]
# Loading weights:  93%|█████████▎| 197/211 [00:00<00:00, 5613.57it/s, Materializing param=encoder.pos_conv_embed.conv.parametrizations.weight.original1]
# Loading weights:  94%|█████████▍| 198/211 [00:00<00:00, 5627.15it/s, Materializing param=feature_extractor.conv_layers.0.conv.weight]
# Loading weights:  94%|█████████▍| 198/211 [00:00<00:00, 5619.08it/s, Materializing param=feature_extractor.conv_layers.0.conv.weight]
# Loading weights:  94%|█████████▍| 199/211 [00:00<00:00, 5632.90it/s, Materializing param=feature_extractor.conv_layers.0.layer_norm.bias]
# Loading weights:  94%|█████████▍| 199/211 [00:00<00:00, 5624.66it/s, Materializing param=feature_extractor.conv_layers.0.layer_norm.bias]
# Loading weights:  95%|█████████▍| 200/211 [00:00<00:00, 5638.68it/s, Materializing param=feature_extractor.conv_layers.0.layer_norm.weight]
# Loading weights:  95%|█████████▍| 200/211 [00:00<00:00, 5630.58it/s, Materializing param=feature_extractor.conv_layers.0.layer_norm.weight]
# Loading weights:  95%|█████████▌| 201/211 [00:00<00:00, 5638.33it/s, Materializing param=feature_extractor.conv_layers.1.conv.weight]
# Loading weights:  95%|█████████▌| 201/211 [00:00<00:00, 5627.38it/s, Materializing param=feature_extractor.conv_layers.1.conv.weight]
# Loading weights:  96%|█████████▌| 202/211 [00:00<00:00, 5637.88it/s, Materializing param=feature_extractor.conv_layers.2.conv.weight]
# Loading weights:  96%|█████████▌| 202/211 [00:00<00:00, 5629.64it/s, Materializing param=feature_extractor.conv_layers.2.conv.weight]
# Loading weights:  96%|█████████▌| 203/211 [00:00<00:00, 5643.22it/s, Materializing param=feature_extractor.conv_layers.3.conv.weight]
# Loading weights:  96%|█████████▌| 203/211 [00:00<00:00, 5634.45it/s, Materializing param=feature_extractor.conv_layers.3.conv.weight]
# Loading weights:  97%|█████████▋| 204/211 [00:00<00:00, 5645.32it/s, Materializing param=feature_extractor.conv_layers.4.conv.weight]
# Loading weights:  97%|█████████▋| 204/211 [00:00<00:00, 5636.99it/s, Materializing param=feature_extractor.conv_layers.4.conv.weight]
# Loading weights:  97%|█████████▋| 205/211 [00:00<00:00, 5648.99it/s, Materializing param=feature_extractor.conv_layers.5.conv.weight]
# Loading weights:  97%|█████████▋| 205/211 [00:00<00:00, 5641.32it/s, Materializing param=feature_extractor.conv_layers.5.conv.weight]
# Loading weights:  98%|█████████▊| 206/211 [00:00<00:00, 5655.51it/s, Materializing param=feature_extractor.conv_layers.6.conv.weight]
# Loading weights:  98%|█████████▊| 206/211 [00:00<00:00, 5647.93it/s, Materializing param=feature_extractor.conv_layers.6.conv.weight]
# Loading weights:  98%|█████████▊| 207/211 [00:00<00:00, 5662.21it/s, Materializing param=feature_projection.layer_norm.bias]
# Loading weights:  98%|█████████▊| 207/211 [00:00<00:00, 5654.73it/s, Materializing param=feature_projection.layer_norm.bias]
# Loading weights:  99%|█████████▊| 208/211 [00:00<00:00, 5658.46it/s, Materializing param=feature_projection.layer_norm.weight]
# Loading weights:  99%|█████████▊| 208/211 [00:00<00:00, 5650.43it/s, Materializing param=feature_projection.layer_norm.weight]
# Loading weights:  99%|█████████▉| 209/211 [00:00<00:00, 5664.13it/s, Materializing param=feature_projection.projection.bias]
# Loading weights:  99%|█████████▉| 209/211 [00:00<00:00, 5656.64it/s, Materializing param=feature_projection.projection.bias]
# Loading weights: 100%|█████████▉| 210/211 [00:00<00:00, 5669.73it/s, Materializing param=feature_projection.projection.weight]
# Loading weights: 100%|█████████▉| 210/211 [00:00<00:00, 5662.00it/s, Materializing param=feature_projection.projection.weight]
# Loading weights: 100%|██████████| 211/211 [00:00<00:00, 5676.16it/s, Materializing param=masked_spec_embed]
# Loading weights: 100%|██████████| 211/211 [00:00<00:00, 5668.78it/s, Materializing param=masked_spec_embed]
# Loading weights: 100%|██████████| 211/211 [00:00<00:00, 5652.30it/s, Materializing param=masked_spec_embed]
# Wav2Vec2Model LOAD REPORT from: facebook/wav2vec2-base
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# quantizer.weight_proj.bias   | UNEXPECTED |  |
# project_hid.weight           | UNEXPECTED |  |
# quantizer.codevectors        | UNEXPECTED |  |
# project_q.weight             | UNEXPECTED |  |
# project_hid.bias             | UNEXPECTED |  |
# quantizer.weight_proj.weight | UNEXPECTED |  |
# project_q.bias               | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Extracting video embedding...
# Extracting audio embedding...
# Loading fusion checkpoint and running prediction...
# {
#   "video_path": "/kaggle/input/datasets/mahirashab/fakebdteen/FakeBDTeen/Boys/Fake_video + Real_Audio/Bangla/B05/FR1B05_09.mp4",
#   "video_head": {
#     "pred_label": "fake_video",
#     "probs": {
#       "real_video": 0.20696265995502472,
#       "fake_video": 0.7930373549461365
#     }
#   },
#   "audio_head": {
#     "pred_label": "real_audio",
#     "probs": {
#       "real_audio": 0.9973408579826355,
#       "fake_audio": 0.002659144112840295
#     }
#   },
#   "four_class": {
#     "pred_index": 1,
#     "pred_label": "FR",
#     "probs": {
#       "FF": 0.001552379340864718,
#       "FR": 0.5721640586853027,
#       "RF": 0.0011395445326343179,
#       "RR": 0.4251440167427063
#     },
#     "derived_from_two_heads": "FR"
#   }
# }
# Saved result JSON to: /kaggle/working/single_video_prediction.json
# Command finished in 15.1s with exit code 0
#
# Saved prediction JSON: /kaggle/working/single_video_prediction.json
# {
#   "video_path": "/kaggle/input/datasets/mahirashab/fakebdteen/FakeBDTeen/Boys/Fake_video + Real_Audio/Bangla/B05/FR1B05_09.mp4",
#   "video_head": {
#     "pred_label": "fake_video",
#     "probs": {
#       "real_video": 0.20696265995502472,
#       "fake_video": 0.7930373549461365
#     }
#   },
#   "audio_head": {
#     "pred_label": "real_audio",
#     "probs": {
#       "real_audio": 0.9973408579826355,
#       "fake_audio": 0.002659144112840295
#     }
#   },
#   "four_class": {
#     "pred_index": 1,
#     "pred_label": "FR",
#     "probs": {
#       "FF": 0.001552379340864718,
#       "FR": 0.5721640586853027,
#       "RF": 0.0011395445326343179,
#       "RR": 0.4251440167427063
#     },
#     "derived_from_two_heads": "FR"
#   }
# }

# %%
from IPython.display import Markdown, display

report_lines = ["## Final Run Summary"]

video_metrics_path = out_dir / "metrics.pt"
audio_metrics_path = audio_out_dir / "metrics.pt"
fusion_metrics_path = fusion_out_dir / "test_metrics.pt"

if video_metrics_path.exists():
    video_metrics = torch.load(video_metrics_path, map_location="cpu")
    report_lines.append(f"- Video best validation accuracy: {video_metrics.get('best_val_acc', 'n/a')}")
    report_lines.append(
        f"- Video split sizes: train={video_metrics.get('num_train', 'n/a')}, val={video_metrics.get('num_val', 'n/a')}, test={video_metrics.get('num_test', 'n/a')}"
    )
else:
    report_lines.append("- Video metrics: not found")

if audio_metrics_path.exists():
    audio_metrics = torch.load(audio_metrics_path, map_location="cpu")
    report_lines.append(f"- Audio best validation accuracy: {audio_metrics.get('best_val_acc', 'n/a')}")
    report_lines.append(
        f"- Audio split sizes: train={audio_metrics.get('num_train', 'n/a')}, val={audio_metrics.get('num_val', 'n/a')}, test={audio_metrics.get('num_test', 'n/a')}"
    )
else:
    report_lines.append("- Audio metrics: not found")

if fusion_metrics_path.exists():
    fusion_metrics = torch.load(fusion_metrics_path, map_location="cpu")
    report_lines.append(f"- Fusion video-head accuracy: {fusion_metrics.get('video_head_accuracy', 'n/a')}")
    report_lines.append(f"- Fusion audio-head accuracy: {fusion_metrics.get('audio_head_accuracy', 'n/a')}")
    report_lines.append(f"- Fusion 4-class accuracy: {fusion_metrics.get('four_class_accuracy', 'n/a')}")
    report_lines.append(f"- Fusion 4-class macro F1: {fusion_metrics.get('four_class_f1_macro', 'n/a')}")
    report_lines.append(f"- Fusion best val macro F1: {fusion_metrics.get('best_val_f1_macro', 'n/a')}")
else:
    report_lines.append("- Fusion metrics: not found")

report_lines.append("## Download Paths")
for label, path in [
    ("Video outputs zip", Path(CONFIG["working_dir"]) / "video_outputs.zip"),
    ("Audio outputs zip", Path(CONFIG["working_dir"]) / "audio_outputs.zip"),
    ("Fusion outputs zip", Path(CONFIG["working_dir"]) / "fusion_outputs.zip"),
    ("Combined outputs zip", Path(CONFIG["working_dir"]) / "all_deepfake_outputs.zip"),
    ("Download index", Path(CONFIG["working_dir"]) / "download_index.json"),
]:
    if path.exists():
        report_lines.append(f"- {label}: {path}")
    else:
        report_lines.append(f"- {label}: not found")

display(Markdown("\n".join(report_lines)))
# Out:
# ## Final Run Summary
# - Video best validation accuracy: 1.0
# - Video split sizes: train=726, val=120, test=124
# - Audio best validation accuracy: 0.9333333333333333
# - Audio split sizes: train=726, val=120, test=124
# - Fusion video-head accuracy: 0.9838709677419355
# - Fusion audio-head accuracy: 0.967741935483871
# - Fusion 4-class accuracy: 0.967741935483871
# - Fusion 4-class macro F1: 0.967683059430767
# - Fusion best val macro F1: 1.0
# ## Download Paths
# - Video outputs zip: /kaggle/working/video_outputs.zip
# - Audio outputs zip: /kaggle/working/audio_outputs.zip
# - Fusion outputs zip: /kaggle/working/fusion_outputs.zip
# - Combined outputs zip: /kaggle/working/all_deepfake_outputs.zip
# - Download index: /kaggle/working/download_index.json
